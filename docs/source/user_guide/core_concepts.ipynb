# %% [markdown]
# # Core Concepts Illustrated Through a Simple Game
#
# This section of the user guide explains the core concepts of the library through playing a simple game. It also has references to other sections for more advanced use cases.

# %% [markdown]
# ## Defining the Game
#
# The first thing you might want to do is to define the game itself. By default, the {class}`~maverick.game.Game` class sets up a No-Limit Texas Hold'em game for you.
#
# ```{note}
# You can read about how to set up other poker variants with custom rulesets {doc}`here <games>`.
# ```

# %%
from maverick import Game

game = Game(small_blind=10, big_blind=20, max_hands=2)

# %% [markdown]
# ```{note}
# Here we defined the maximum number of hands as 2, but this is optional. With that being said, an upper limit on the number of hands always exists, even if you dont define it. Refer to the {doc}`API Reference <../api_reference>` to see the default values for the input parameters.
# ```
#
# ```{tip}
# It is recommended to always set a reasonable upper limit on the number of hands, especially if you use bots such as {class}`~maverick.players.foldbot.FoldBot` (as we do in the next section of this document).
# ```

# %% [markdown]
# The {class}`~maverick.game.Game` class is implemented as a state machine, which is a common design pattern. It has an attribute called `state`, which is an instance of {class}`~maverick.state.GameState`. The game maintains this state through events and state transitions.

# %%
game.state.stage
# Out:
# <GameStage.WAITING_FOR_PLAYERS: 1>

# %% [markdown]
# The which is an instance of {class}`~maverick.state.GameState` class inherited from PyDantic's {class}`~pydantic.main.BaseModel` class, hence it can be dumped to a dictionary:

# %%
game.state.model_dump()
# Out:
# {'uid': '04ff267ed43647b893410c28a5721b36',
#  'ts': 1774698391.2428951,
#  'stage': <GameStage.WAITING_FOR_PLAYERS: 1>,
#  'street': None,
#  'players': [],
#  'current_player_index': None,
#  'community_cards': (),
#  'pot': 0,
#  'current_bet': 0,
#  'min_bet': 0,
#  'last_raise_size': 0,
#  'small_blind': 10,
#  'big_blind': 20,
#  'ante': 0,
#  'hand_number': 0,
#  'button_position': None,
#  'small_blind_position': None,
#  'big_blind_position': None}

# %% [markdown]
# We will issue the print statement above to illustrate how the state of the game changes.

# %% [markdown]
# ## Defining the Players of the Game
#
# The library contains built-in players you can use as training opponents. For an exhaustive list of available built-in players, refer to {ref}`this <players_api_reference>` section of the API Reference. What you have to tell at the minimum when setting up a player is the player's `name`, and the amount of chips they start the game with. Among other things that might change during a game, the amount of chips (aka. stack) is part of the player's state.

# %%
from maverick.players import FoldBot, CallBot, AggressiveBot
from maverick import PlayerLike, PlayerState


players: list[PlayerLike] = [
    CallBot(name="CallBot"),
    AggressiveBot(name="AggroBot"),
    FoldBot(name="FoldBot"),
]

for player in players:
    game.add_player(player, state=PlayerState(stack=1000))

# %% [markdown]
# ```{note}
# You can read about how to implement custom players {doc}`here <custom_players>`.
# ```

# %% [markdown]
# Every implemented player class must adhere to the protocol defined by the {class}`~maverick.protocol.PlayerLike` class. Every instance of a player class has a `name`, a `uid`, and a `state`. The `state` attribute is an instance of {class}`~maverick.playerstate.PlayerState` and it captures all information of a player that might change during a game.
#
# > **Note (v0.8.0+):** `game.state.players` now returns a list of {class}`~maverick.playerstate.PlayerSnapshot` objects, not live `PlayerLike` instances. Each `PlayerSnapshot` exposes `uid`, `name`, and `state` but does not carry strategy logic. To access a player's strategy object, use `game._strategies[uid]`.

# %%
game.state.model_dump()
# Out:
# {'uid': '04ff267ed43647b893410c28a5721b36',
#  'ts': 1774698391.2428951,
#  'stage': <GameStage.READY: 2>,
#  'street': None,
#  'players': [{'uid': 'f896d25855234a058d640eac6fc7ad5b',
#    'name': 'CallBot',
#    'state': {'seat': 0,
#     'state_type': <PlayerStateType.ACTIVE: 1>,
#     'stack': 1000,
#     'holding': None,
#     'current_bet': 0,
#     'total_contributed': 0,
#     'acted_this_street': False}},
#   {'uid': '4cc505d1e1c548bdacb75f4366088c7c',
#    'name': 'AggroBot',
#    'state': {'seat': 1,
#     'state_type': <PlayerStateType.ACTIVE: 1>,
#     'stack': 1000,
#     'holding': None,
#     'current_bet': 0,
#     'total_contributed': 0,
#     'acted_this_street': False}},
#   {'uid': '04bf9610968b40e5a737c68396465ea5',
#    'name': 'FoldBot',
#    'state': {'seat': 2,
#     'state_type': <PlayerStateType.ACTIVE: 1>,
#     'stack': 1000,
#     'holding': None,
#     'current_bet': 0,
#     'total_contributed': 0,
#     'acted_this_street': False}}],
#  'current_player_index': None,
#  'community_cards': (),
#  'pot': 0,
#  'current_bet': 0,
#  'min_bet': 0,
#  'last_raise_size': 0,
#  'small_blind': 10,
#  'big_blind': 20,
#  'ante': 0,
#  'hand_number': 0,
#  'button_position': None,
#  'small_blind_position': None,
#  'big_blind_position': None}

# %% [markdown]
# ## Playing the Game
#
# The following cell kicks off the event flow of the game and finishes when the game has terminated. A game might terminate for a number of reasons:
#
# - there are not enough players to continue (because everyone got eliminated except one)
# - the number of hands reached the maximum number of hands defined at instantiation (current case)
#
# Before you start a game, you might want to configure logging, so you can inspect the event flow of the game without distractions.

# %%
import logging

# Configure logging such that we only get the log messages of the game
logging.basicConfig(level=logging.INFO, format="%(name)s: %(message)s", force=True)
logging.getLogger().setLevel(logging.WARNING)
logging.getLogger("maverick").setLevel(logging.INFO)

# %% [markdown]
# And now we can kick off the game.

# %%
# Start the game
game.start()
# Out:
# maverick: Game started.
#
# maverick: ============================== Hand 1 ==============================
#
# maverick: DEALING | Dealing hole cards. Button: CallBot
# maverick: DEALING | Posting small blind of 10 by player AggroBot. Remaining stack: 990
# maverick: DEALING | Posting big blind of 20 by player FoldBot. Remaining stack: 980
# maverick: PRE_FLOP | Player CallBot calls with amount 20. Remaining stack: 980.
# maverick: PRE_FLOP | Current pot: 50 | Current bet: 20
# maverick: PRE_FLOP | Player AggroBot raises by 30 chips to total bet 40. Remaining stack: 960.
# maverick: PRE_FLOP | Current pot: 80 | Current bet: 40
# maverick: PRE_FLOP | Player FoldBot folds.
# maverick: PRE_FLOP | Current pot: 80 | Current bet: 40
# maverick: PRE_FLOP | Player CallBot calls with amount 20. Remaining stack: 960.
# maverick: PRE_FLOP | Current pot: 100 | Current bet: 40
# maverick: PRE_FLOP | Betting round complete
#
# maverick: FLOP | Dealt flop. Community cards: ['7♠', '7♥', '8♥']
# maverick: FLOP | Player AggroBot bets amount 40. Remaining stack: 920.
# maverick: FLOP | Current pot: 140 | Current bet: 40
# maverick: FLOP | Player CallBot calls with amount 40. Remaining stack: 920.
# maverick: FLOP | Current pot: 180 | Current bet: 40
# maverick: FLOP | Betting round complete
#
# maverick: TURN | Dealt turn. Community cards: ['7♠', '7♥', '8♥', '4♠']
# maverick: TURN | Player AggroBot bets amount 40. Remaining stack: 880.
# maverick: TURN | Current pot: 220 | Current bet: 40
# maverick: TURN | Player CallBot calls with amount 40. Remaining stack: 880.
# maverick: TURN | Current pot: 260 | Current bet: 40
# maverick: TURN | Betting round complete
#
# maverick: RIVER | Dealt river. Community cards: ['7♠', '7♥', '8♥', '4♠', '10♣']
# maverick: RIVER | Player AggroBot bets amount 40. Remaining stack: 840.
# maverick: RIVER | Current pot: 300 | Current bet: 40
# maverick: RIVER | Player CallBot calls with amount 40. Remaining stack: 840.
# maverick: RIVER | Current pot: 340 | Current bet: 40
# maverick: RIVER | Betting round complete
#
# maverick: SHOWDOWN | Player CallBot has holding 2♠ 5♥ at showdown,
# maverick: SHOWDOWN | Player CallBot has hand PAIR with cards ['5♥', '7♠', '7♥', '8♥', '10♣'] (score: 207.10081)
# maverick: SHOWDOWN | Player AggroBot has holding K♥ 10♠ at showdown,
# maverick: SHOWDOWN | Player AggroBot has hand TWO_PAIR with cards ['K♥', '10♠', '7♠', '7♥', '10♣'] (score: 310.0713)
# maverick: SHOWDOWN | Player AggroBot wins 340 from the pot.
# maverick: SHOWDOWN | Showdown complete
#
# maverick: Hand ended
#
# maverick: ============================== Hand 2 ==============================
#
# maverick: DEALING | Dealing hole cards. Button: AggroBot
# maverick: DEALING | Posting small blind of 10 by player FoldBot. Remaining stack: 970
# maverick: DEALING | Posting big blind of 20 by player CallBot. Remaining stack: 820
# maverick: PRE_FLOP | Player AggroBot raises by 40 chips to total bet 40. Remaining stack: 1140.
# maverick: PRE_FLOP | Current pot: 70 | Current bet: 40
# maverick: PRE_FLOP | Player FoldBot folds.
# maverick: PRE_FLOP | Current pot: 70 | Current bet: 40
# maverick: PRE_FLOP | Player CallBot calls with amount 20. Remaining stack: 800.
# maverick: PRE_FLOP | Current pot: 90 | Current bet: 40
# maverick: PRE_FLOP | Betting round complete
#
# maverick: FLOP | Dealt flop. Community cards: ['8♥', 'J♣', 'A♥']
# maverick: FLOP | Player CallBot checks.
# maverick: FLOP | Current pot: 90 | Current bet: 0
# maverick: FLOP | Player AggroBot bets amount 40. Remaining stack: 1100.
# maverick: FLOP | Current pot: 130 | Current bet: 40
# maverick: FLOP | Player CallBot calls with amount 40. Remaining stack: 760.
# maverick: FLOP | Current pot: 170 | Current bet: 40
# maverick: FLOP | Betting round complete
#
# maverick: TURN | Dealt turn. Community cards: ['8♥', 'J♣', 'A♥', 'K♣']
# maverick: TURN | Player CallBot checks.
# maverick: TURN | Current pot: 170 | Current bet: 0
# maverick: TURN | Player AggroBot bets amount 40. Remaining stack: 1060.
# maverick: TURN | Current pot: 210 | Current bet: 40
# maverick: TURN | Player CallBot calls with amount 40. Remaining stack: 720.
# maverick: TURN | Current pot: 250 | Current bet: 40
# maverick: TURN | Betting round complete
#
# maverick: RIVER | Dealt river. Community cards: ['8♥', 'J♣', 'A♥', 'K♣', '5♠']
# maverick: RIVER | Player CallBot checks.
# maverick: RIVER | Current pot: 250 | Current bet: 0
# maverick: RIVER | Player AggroBot bets amount 40. Remaining stack: 1020.
# maverick: RIVER | Current pot: 290 | Current bet: 40
# maverick: RIVER | Player CallBot calls with amount 40. Remaining stack: 680.
# maverick: RIVER | Current pot: 330 | Current bet: 40
# maverick: RIVER | Betting round complete
#
# maverick: SHOWDOWN | Player CallBot has holding 4♠ A♣ at showdown,
# maverick: SHOWDOWN | Player CallBot has hand PAIR with cards ['A♣', '8♥', 'J♣', 'A♥', 'K♣'] (score: 214.13111)
# maverick: SHOWDOWN | Player AggroBot has holding 10♦ 7♣ at showdown,
# maverick: SHOWDOWN | Player AggroBot has hand HIGH_CARD with cards ['10♦', '8♥', 'J♣', 'A♥', 'K♣'] (score: 100.14131)
# maverick: SHOWDOWN | Player CallBot wins 330 from the pot.
# maverick: SHOWDOWN | Showdown complete
#
# maverick: Hand ended
#
# maverick: Reached maximum number of hands, ending game.
# maverick: Game ended

# %%
game.state.model_dump()
# Out:
# {'uid': '04ff267ed43647b893410c28a5721b36',
#  'ts': 1774698391.2428951,
#  'stage': <GameStage.GAME_OVER: 11>,
#  'street': None,
#  'players': [{'uid': 'f896d25855234a058d640eac6fc7ad5b',
#    'name': 'CallBot',
#    'state': {'seat': 0,
#     'state_type': <PlayerStateType.ACTIVE: 1>,
#     'stack': 1010,
#     'holding': {'cards': [{'suit': <Suit.SPADES: 'S'>, 'rank': <Rank.FOUR: 4>},
#       {'suit': <Suit.CLUBS: 'C'>, 'rank': <Rank.ACE: 14>}]},
#     'current_bet': 0,
#     'total_contributed': 160,
#     'acted_this_street': False}},
#   {'uid': '4cc505d1e1c548bdacb75f4366088c7c',
#    'name': 'AggroBot',
#    'state': {'seat': 1,
#     'state_type': <PlayerStateType.ACTIVE: 1>,
#     'stack': 1020,
#     'holding': {'cards': [{'suit': <Suit.DIAMONDS: 'D'>,
#        'rank': <Rank.TEN: 10>},
#       {'suit': <Suit.CLUBS: 'C'>, 'rank': <Rank.SEVEN: 7>}]},
#     'current_bet': 0,
#     'total_contributed': 160,
#     'acted_this_street': False}},
#   {'uid': '04bf9610968b40e5a737c68396465ea5',
#    'name': 'FoldBot',
#    'state': {'seat': 2,
#     'state_type': <PlayerStateType.FOLDED: 2>,
#     'stack': 970,
#     'holding': {'cards': [{'suit': <Suit.DIAMONDS: 'D'>,
#        'rank': <Rank.FOUR: 4>},
#       {'suit': <Suit.SPADES: 'S'>, 'rank': <Rank.SEVEN: 7>}]},
#     'current_bet': 0,
#     'total_contributed': 10,
#     'acted_this_street': False}}],
#  'current_player_index': 0,
#  'community_cards': ({'suit': <Suit.HEARTS: 'H'>, 'rank': <Rank.EIGHT: 8>},
#   {'suit': <Suit.CLUBS: 'C'>, 'rank': <Rank.JACK: 11>},
#   {'suit': <Suit.HEARTS: 'H'>, 'rank': <Rank.ACE: 14>},
#   {'suit': <Suit.CLUBS: 'C'>, 'rank': <Rank.KING: 13>},
#   {'suit': <Suit.SPADES: 'S'>, 'rank': <Rank.FIVE: 5>}),
#  'pot': 0,
#  'current_bet': 0,
#  'min_bet': 20,
#  'last_raise_size': 0,
#  'small_blind': 10,
#  'big_blind': 20,
#  'ante': 0,
#  'hand_number': 2,
#  'button_position': 1,
#  'small_blind_position': 2,
#  'big_blind_position': 0}

# %% [markdown]
# ### How does it work?
#
# When you call `game.start()`, an event is added to the event queue of the game. When an event is added to the event queue, it usually results in a state transition and triggers downstream events and the cycle continues until the event queue is fully drained. Certain events require players to take action, and the players respond with an action. You will learn about these when you implement your first custom player here: {doc}`here <custom_players>`.

# %% [markdown]
# ## Inspecting the Results
#
# Every player has a state attribute, which is an instance of {class}`~maverick.playerstate.PlayerState`. You can use this class to print the actual stack of every player.
#
# `game.state.players` includes **all** players — including those who were eliminated during the game — so you can inspect the final state of every participant. Players who were knocked out have `state_type=PlayerStateType.ELIMINATED` and `stack=0`.
#
# To iterate only the players still eligible for the next hand use `game.state.get_active_players()`.

# %%
# Full player list — includes eliminated players
for snapshot in game.state.players:
    print(f"{snapshot.name} - Stack: {snapshot.state.stack} ({snapshot.state.state_type})")

# Print the players that are still in the game
print("\nNon-eliminated players:")
for snapshot in game.state.get_non_eliminated_players():
    print(f"{snapshot.name} is eligible for the next hand with {snapshot.state.stack} chips")
# Out:
# CallBot - Stack: 1010 (PlayerStateType.ACTIVE)
# AggroBot - Stack: 1020 (PlayerStateType.ACTIVE)
# FoldBot - Stack: 970 (PlayerStateType.FOLDED)
#
# Non-eliminated players:
# CallBot is eligible for the next hand with 1010 chips
# AggroBot is eligible for the next hand with 1020 chips
# FoldBot is eligible for the next hand with 970 chips

# %% [markdown]
# If the classes of the player instances are subclasses of the {class}`~maverick.player.Player` base class, then the state of a player is directly accessible through the `state` property of the instance:

# %%
for player in players:
    print(f"{player.name} - Stack: {player.state.stack} ({player.state.state_type})")
# Out:
# CallBot - Stack: 1010 (PlayerStateType.ACTIVE)
# AggroBot - Stack: 1020 (PlayerStateType.ACTIVE)
# FoldBot - Stack: 970 (PlayerStateType.FOLDED)

# %% [markdown]
# ## Inspecting the Event History

# %% [markdown]
# Games maintain a full history of events and it's accessible through the `history` property of an instance. It returns a dictionary with keys 'game', 'hand' and 'street', all mapping to a list of {class}`~maverick.events.GameEvent`. The three keys map to the full events and the events of the current hand and street respectively. The latter two are subsets of the first one and they are probably only interesting during the game.

# %%
# Show the first 10 events that occurred in the game
game.history[:10]
# Out:
# [GameEvent(uid='d67423200a2c46479293d0e996102a49', ts=1774698391.265322, type=<GameEventType.PLAYER_JOINED: 14>, hand_number=0, street=None, stage=<GameStage.WAITING_FOR_PLAYERS: 1>, player_uid='f896d25855234a058d640eac6fc7ad5b', action=None, payload={}),
#  GameEvent(uid='2c019a791aae4d7387f0bdabd800f42d', ts=1774698391.265433, type=<GameEventType.PLAYER_JOINED: 14>, hand_number=0, street=None, stage=<GameStage.READY: 2>, player_uid='4cc505d1e1c548bdacb75f4366088c7c', action=None, payload={}),
#  GameEvent(uid='d7f1955220904c30873aa6fe982ef3fe', ts=1774698391.2654688, type=<GameEventType.PLAYER_JOINED: 14>, hand_number=0, street=None, stage=<GameStage.READY: 2>, player_uid='04bf9610968b40e5a737c68396465ea5', action=None, payload={}),
#  GameEvent(uid='44a38c399016497d9166e8165dec73c5', ts=1774698391.279588, type=<GameEventType.GAME_STARTED: 1>, hand_number=0, street=None, stage=<GameStage.STARTED: 3>, player_uid=None, action=None, payload={}),
#  GameEvent(uid='3295accab740430c886256fd09c36313', ts=1774698391.2800808, type=<GameEventType.HAND_STARTED: 3>, hand_number=1, street=<Street.PRE_FLOP: 0>, stage=<GameStage.DEALING: 4>, player_uid=None, action=None, payload={}),
#  GameEvent(uid='cd99f3b108ac4f85abe0d17d1fdba2cb', ts=1774698391.28074, type=<GameEventType.HOLE_CARDS_DEALT: 7>, hand_number=1, street=<Street.PRE_FLOP: 0>, stage=<GameStage.DEALING: 4>, player_uid=None, action=None, payload={}),
#  GameEvent(uid='7d9de2a34090435c9ffd3d91f61f8ca7', ts=1774698391.281504, type=<GameEventType.BLINDS_POSTED: 17>, hand_number=1, street=<Street.PRE_FLOP: 0>, stage=<GameStage.DEALING: 4>, player_uid=None, action=None, payload={}),
#  GameEvent(uid='292d1202777b4512aa7106fae54734e8', ts=1774698391.2815208, type=<GameEventType.ANTES_POSTED: 18>, hand_number=1, street=<Street.PRE_FLOP: 0>, stage=<GameStage.DEALING: 4>, player_uid=None, action=None, payload={}),
#  GameEvent(uid='7329200b550346d6a4c80566d4eb2f58', ts=1774698391.281536, type=<GameEventType.BETTING_ROUND_STARTED: 19>, hand_number=1, street=<Street.PRE_FLOP: 0>, stage=<GameStage.PRE_FLOP: 5>, player_uid=None, action=None, payload={}),
#  GameEvent(uid='6298883f45f74c9a9ac5afd7f4d24920', ts=1774698391.282062, type=<GameEventType.PLAYER_ACTION_TAKEN: 11>, hand_number=1, street=<Street.PRE_FLOP: 0>, stage=<GameStage.PRE_FLOP: 5>, player_uid='f896d25855234a058d640eac6fc7ad5b', action=PlayerAction(player_uid='f896d25855234a058d640eac6fc7ad5b', action_type=<ActionType.CALL: 3>, amount=None, payload={}, decision_time_seconds=7.5409989221952856e-06), payload={})]

# %% [markdown]
# If you are only interested in the full game history, you can also use the `game_history` attribute of the instance and the following block is equivalent to the previous one.
