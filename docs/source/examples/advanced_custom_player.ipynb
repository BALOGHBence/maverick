# %% [markdown]
# # Create and Advanced Custom Player
#
# All the imports are centralized in the cell below.

# %%
from maverick import (
    Game,
    Player,
    ActionType,
    PlayerLike,
    Street,
    HandType,
    PlayerAction,
    PlayerState,
)
from maverick.players import FoldBot, AggressiveBot
from maverick.utils import estimate_holding_strength, score_hand
import logging
import sys

# %% [markdown]
# ## Custom Player

# %%
class ComplexPlayer(Player):
    """A custom player with a complex strategy."""

    def decide_action(
        self,
        game: Game,
        valid_actions: list[ActionType],
        min_raise: int
    ) -> PlayerAction:
        print(f"\n{self.name} is requested to take action.")
        
        # Information related to the game itself
        print("     Current street:", game.state.street.name)
        print("     Button position:", game.state.button_position)
        print("     Current pot:", game.state.pot)
        print("     Small blind:", game.state.small_blind)
        print("     Big blind:", game.state.big_blind)
        print("     Community cards:", game.state.community_cards)
        
        # Information related to the player
        print("     Player stack:", self.state.stack)
        print("     Current player bet:", self.state.current_bet)
        print("     Private cards:", self.state.holding.cards)
        
        # Information related to the actions available for the player
        print("     Valid actions:", [v.name for v in valid_actions])
        print("     Minimum raise:", min_raise)
        
        # Private and community cards
        private_cards = self.state.holding.cards
        community_cards = game.state.community_cards
        print("     Private cards:", private_cards)
        print("     Community cards:", community_cards)
        
        # Estimate the strongest possible hand of the player, considering
        # all community cards.
        strongest_hand, strongest_hand_prob = estimate_holding_strength(
            private_cards,
            community_cards=community_cards,
            n_private=None,
            n_simulations=1000,
            n_players=len(game.state.get_players_in_hand())
        )
        strongest_hand_type, strongest_hand_score = score_hand(strongest_hand)
        print("     Strongest hand:", strongest_hand)
        print("     Strongest hand type:", strongest_hand_type.name)
        print("     Strongest hand score:", strongest_hand_score)
        print("     Estimated strength:", strongest_hand_prob)
        
        # This is the players strategy
        match game.state.street:
            case Street.PRE_FLOP:
                if strongest_hand_prob < 0.2:
                    # This is the time to bluff if you want to
                    print("     Player decides to FOLD.\n")
                    return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)
                elif strongest_hand_prob > 0.4 and strongest_hand_type >= HandType.PAIR:
                    if ActionType.BET in valid_actions:
                        bet_amount = max(game.state.big_blind * 4, min_raise)
                        print(f"     Player decides to BET {bet_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.BET, amount=bet_amount)
                    elif ActionType.RAISE in valid_actions:
                        raise_amount = max(game.state.big_blind * 4, min_raise)
                        print(f"     Player decides to RAISE {raise_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.RAISE, amount=raise_amount)
                    elif ActionType.CALL in valid_actions:
                        call_amount = max(game.state.current_bet - self.state.current_bet, self.state.stack)
                        print(f"     Player decides to CALL {call_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CALL, amount=call_amount)
                    elif ActionType.CHECK in valid_actions:
                        print("     Player decides to CHECK.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                    else:
                        print("     Player decides to ALL IN.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.ALL_IN, amount=self.state.stack)           
                else:
                    if ActionType.CHECK in valid_actions:
                        print("     Player decides to CHECK.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                    else:
                        print("     Player decides to FOLD.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)
            
            case Street.FLOP:
                if strongest_hand_type in [
                    HandType.ROYAL_FLUSH, 
                    HandType.STRAIGHT_FLUSH, 
                    HandType.FOUR_OF_A_KIND, 
                    HandType.FULL_HOUSE
                ]:
                    if ActionType.CHECK in valid_actions:
                        print("     Player decides to CHECK.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                    assert ActionType.CALL in valid_actions
                    call_amount = max(game.state.current_bet - self.state.current_bet, self.state.stack)
                    print(f"     Player decides to CALL {call_amount}.\n")
                    return PlayerAction(player_id=self.id, action_type=ActionType.CALL, amount=call_amount)
                else:
                    if strongest_hand_prob < 0.3:
                        print("     Player decides to FOLD.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)
                    elif strongest_hand_prob > 0.6:
                        if ActionType.RAISE in valid_actions:
                            raise_amount = max(game.state.big_blind * 3, min_raise)
                            print(f"     Player decides to RAISE {raise_amount}.\n")
                            return PlayerAction(player_id=self.id, action_type=ActionType.RAISE, amount=raise_amount)
                        elif ActionType.CALL in valid_actions:
                            call_amount = max(game.state.current_bet - self.state.current_bet, self.state.stack)
                            print(f"     Player decides to CALL {call_amount}.\n")
                            return PlayerAction(player_id=self.id, action_type=ActionType.CALL, amount=call_amount)
                    else:
                        if ActionType.CHECK in valid_actions:
                            print("     Player decides to CHECK.\n")
                            return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                        else:
                            print("     Player decides to FOLD.\n")
                            return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)
                        
            case Street.TURN:
                to_call = max(0, game.state.current_bet - self.state.current_bet)

                # Very strong made hands: play safely (slowplay), but don't fold.
                if strongest_hand_type in [
                    HandType.ROYAL_FLUSH,
                    HandType.STRAIGHT_FLUSH,
                    HandType.FOUR_OF_A_KIND,
                    HandType.FULL_HOUSE,
                ]:
                    if ActionType.CHECK in valid_actions:
                        print("     Player decides to CHECK.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                    if ActionType.CALL in valid_actions:
                        call_amount = min(to_call, self.state.stack)
                        print(f"     Player decides to CALL {call_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CALL, amount=call_amount)
                # Weak: avoid putting more money in.
                if strongest_hand_prob < 0.25:
                    if ActionType.CHECK in valid_actions:
                        print("     Player decides to CHECK.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                    print("     Player decides to FOLD.\n")
                    return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)

                # Strong: value bet / raise.
                if strongest_hand_prob > 0.65:
                    if ActionType.BET in valid_actions:
                        bet_amount = min(self.state.stack, max(game.state.big_blind * 3, min_raise))
                        print(f"     Player decides to BET {bet_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.BET, amount=bet_amount)
                    if ActionType.RAISE in valid_actions:
                        raise_amount = min(self.state.stack, max(game.state.big_blind * 3, min_raise))
                        print(f"     Player decides to RAISE {raise_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.RAISE, amount=raise_amount)
                    if ActionType.CALL in valid_actions:
                        call_amount = min(to_call, self.state.stack)
                        print(f"     Player decides to CALL {call_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CALL, amount=call_amount)
                # Medium: prefer checking, otherwise call small commitments.
                if ActionType.CHECK in valid_actions:
                    print("     Player decides to CHECK.\n")
                    return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                if ActionType.CALL in valid_actions:
                    call_amount = min(to_call, self.state.stack)
                    print(f"     Player decides to CALL {call_amount}.\n")
                    return PlayerAction(player_id=self.id, action_type=ActionType.CALL, amount=call_amount)
                print("     Player decides to FOLD.\n")
                return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)

            case Street.RIVER:
                to_call = max(0, game.state.current_bet - self.state.current_bet)

                # On the river, be even more conservative with weak hands.
                if strongest_hand_prob < 0.35:
                    if ActionType.CHECK in valid_actions:
                        print("     Player decides to CHECK.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                    print("     Player decides to FOLD.\n")
                    return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)

                # Value bet thin only when strong.
                if strongest_hand_prob > 0.75:
                    if ActionType.BET in valid_actions:
                        bet_amount = min(self.state.stack, max(game.state.big_blind * 3, min_raise))
                        print(f"     Player decides to BET {bet_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.BET, amount=bet_amount)
                    if ActionType.RAISE in valid_actions:
                        raise_amount = min(self.state.stack, max(game.state.big_blind * 3, min_raise))
                        print(f"     Player decides to RAISE {raise_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.RAISE, amount=raise_amount)
                    if ActionType.CALL in valid_actions:
                        call_amount = min(to_call, self.state.stack)
                        print(f"     Player decides to CALL {call_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CALL, amount=call_amount)
                # Medium strength: check if possible, otherwise call.
                if ActionType.CHECK in valid_actions:
                    print("     Player decides to CHECK.\n")
                    return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                if ActionType.CALL in valid_actions:
                    call_amount = min(to_call, self.state.stack)
                    print(f"     Player decides to CALL {call_amount}.\n")
                    return PlayerAction(player_id=self.id, action_type=ActionType.CALL, amount=call_amount)
                print("     Player decides to FOLD.\n")
                return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)

        # Make sure to always return a valid action. Folding is always available.
        print("     Player decides to FOLD.\n")
        sys.stdout.flush()  # Ensure all prints are output before returning
        return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)

# %%
# Configure logging such that we only get the log messages of the game
logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s [%(levelname)s] %(name)s: %(message)s",
)
logging.getLogger().setLevel(logging.WARNING)  # Set root logger to WARNING
logging.getLogger("maverick").setLevel(logging.DEBUG)  # Only maverick logs at DEBUG

# Redirect maverick logs to stdout, so they appear in the correct event order
handler = logging.StreamHandler(sys.stdout)
logging.getLogger("maverick").handlers = [handler]
logging.getLogger("maverick").propagate = False

# Create game with blinds
game = Game(small_blind=10, big_blind=20, max_hands=2)

# Create and add players with different strategies
players: list[PlayerLike] = [
    ComplexPlayer(id="p1", name="ComplexPlayer", state=PlayerState(stack=1000, seat=0)),
    FoldBot(id="p2", name="FoldBot", state=PlayerState(stack=1000, seat=1)),
    AggressiveBot(id="p3", name="AggressiveBot", state=PlayerState(stack=1000, seat=2)),
]

for player in players:
    game.add_player(player)
    
game.start()
# Out:
# Player ComplexPlayer joined the game.
# Player FoldBot joined the game.
# Player AggressiveBot joined the game.
# Game started.
#
# ============================== Hand 1 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 990
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 980
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 0
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1000
#      Current player bet: 0
#      Private cards: [10♥, 8♦]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 40
#      Private cards: [10♥, 8♦]
#      Community cards: []
#      Strongest hand: [10♥, 8♦]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1008
#      Estimated strength: 0.332
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 2 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 1000
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 980
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 970.
# PRE_FLOP | Current pot: 60
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 60
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 980
#      Current player bet: 20
#      Private cards: [A♠, 6♥]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 60
#      Private cards: [A♠, 6♥]
#      Community cards: []
#      Strongest hand: [A♠, 6♥]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1406
#      Estimated strength: 0.673
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 60
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 60 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 3 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 970
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 970
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 990.
# PRE_FLOP | Current pot: 70
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 2
#      Current pot: 70
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 970
#      Current player bet: 10
#      Private cards: [3♠, 5♠]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 60
#      Private cards: [3♠, 5♠]
#      Community cards: []
#      Strongest hand: [3♠, 5♠]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.0503
#      Estimated strength: 0.236
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 70
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 70
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 70 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 4 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 960
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 1040
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 0
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 970
#      Current player bet: 0
#      Private cards: [7♣, 4♦]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 40
#      Private cards: [7♣, 4♦]
#      Community cards: []
#      Strongest hand: [7♣, 4♦]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.0704
#      Estimated strength: 0.227
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 5 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 1060
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 950
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 1030.
# PRE_FLOP | Current pot: 60
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 60
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 950
#      Current player bet: 20
#      Private cards: [5♣, 4♦]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 60
#      Private cards: [5♣, 4♦]
#      Community cards: []
#      Strongest hand: [5♣, 4♦]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.0504
#      Estimated strength: 0.338
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 60
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 60 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 6 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 940
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 940
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 1050.
# PRE_FLOP | Current pot: 70
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 2
#      Current pot: 70
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 940
#      Current player bet: 10
#      Private cards: [10♠, 8♠]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 60
#      Private cards: [10♠, 8♠]
#      Community cards: []
#      Strongest hand: [10♠, 8♠]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1008
#      Estimated strength: 0.345
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 70
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 70
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 70 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 7 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 930
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 1100
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 0
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 940
#      Current player bet: 0
#      Private cards: [A♦, J♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 40
#      Private cards: [A♦, J♣]
#      Community cards: []
#      Strongest hand: [A♦, J♣]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1411
#      Estimated strength: 0.563
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 8 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 1120
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 920
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 1090.
# PRE_FLOP | Current pot: 60
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 60
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 920
#      Current player bet: 20
#      Private cards: [6♣, Q♠]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 60
#      Private cards: [6♣, Q♠]
#      Community cards: []
#      Strongest hand: [6♣, Q♠]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1206
#      Estimated strength: 0.554
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 60
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 60 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 9 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 910
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 910
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 1110.
# PRE_FLOP | Current pot: 70
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 2
#      Current pot: 70
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 910
#      Current player bet: 10
#      Private cards: [5♥, 3♠]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 60
#      Private cards: [5♥, 3♠]
#      Community cards: []
#      Strongest hand: [5♥, 3♠]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.0503
#      Estimated strength: 0.23
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 70
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 70
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 70 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 10 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 900
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 1160
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 0
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 910
#      Current player bet: 0
#      Private cards: [3♣, J♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 40
#      Private cards: [3♣, J♣]
#      Community cards: []
#      Strongest hand: [3♣, J♣]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1103
#      Estimated strength: 0.307
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 11 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 1180
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 890
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 1150.
# PRE_FLOP | Current pot: 60
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 60
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 890
#      Current player bet: 20
#      Private cards: [10♠, 2♦]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 60
#      Private cards: [10♠, 2♦]
#      Community cards: []
#      Strongest hand: [10♠, 2♦]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1002
#      Estimated strength: 0.432
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 60
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 60 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 12 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 880
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 880
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 1170.
# PRE_FLOP | Current pot: 70
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 2
#      Current pot: 70
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 880
#      Current player bet: 10
#      Private cards: [2♣, 6♠]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 60
#      Private cards: [2♣, 6♠]
#      Community cards: []
#      Strongest hand: [2♣, 6♠]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.0602
#      Estimated strength: 0.202
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 70
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 70
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 70 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 13 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 870
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 1220
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 0
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 880
#      Current player bet: 0
#      Private cards: [6♥, A♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 40
#      Private cards: [6♥, A♣]
#      Community cards: []
#      Strongest hand: [6♥, A♣]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1406
#      Estimated strength: 0.465
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 14 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 1240
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 860
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 1210.
# PRE_FLOP | Current pot: 60
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 60
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 860
#      Current player bet: 20
#      Private cards: [2♠, 2♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 60
#      Private cards: [2♠, 2♣]
#      Community cards: []
#      Strongest hand: [2♠, 2♣]
#      Strongest hand type: PAIR
#      Strongest hand score: 202
#      Estimated strength: 0.721
#      Player decides to RAISE 80.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 80. Remaining stack: 800.
# PRE_FLOP | Current pot: 120
# PRE_FLOP | Player AggressiveBot raises to amount 100. Remaining stack: 1150.
# PRE_FLOP | Current pot: 180
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 180
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 800
#      Current player bet: 80
#      Private cards: [2♠, 2♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 120
#      Private cards: [2♠, 2♣]
#      Community cards: []
#      Strongest hand: [2♠, 2♣]
#      Strongest hand type: PAIR
#      Strongest hand score: 202
#      Estimated strength: 0.708
#      Player decides to RAISE 120.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 120. Remaining stack: 760.
# PRE_FLOP | Current pot: 220
# PRE_FLOP | Player AggressiveBot raises to amount 140. Remaining stack: 1110.
# PRE_FLOP | Current pot: 260
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 260
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 760
#      Current player bet: 120
#      Private cards: [2♠, 2♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 160
#      Private cards: [2♠, 2♣]
#      Community cards: []
#      Strongest hand: [2♠, 2♣]
#      Strongest hand type: PAIR
#      Strongest hand score: 202
#      Estimated strength: 0.703
#      Player decides to RAISE 160.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 160. Remaining stack: 720.
# PRE_FLOP | Current pot: 300
# PRE_FLOP | Player AggressiveBot raises to amount 180. Remaining stack: 1070.
# PRE_FLOP | Current pot: 340
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 340
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 720
#      Current player bet: 160
#      Private cards: [2♠, 2♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 200
#      Private cards: [2♠, 2♣]
#      Community cards: []
#      Strongest hand: [2♠, 2♣]
#      Strongest hand type: PAIR
#      Strongest hand score: 202
#      Estimated strength: 0.682
#      Player decides to RAISE 200.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 200. Remaining stack: 680.
# PRE_FLOP | Current pot: 380
# PRE_FLOP | Player AggressiveBot raises to amount 220. Remaining stack: 1030.
# PRE_FLOP | Current pot: 420
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 420
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 680
#      Current player bet: 200
#      Private cards: [2♠, 2♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 240
#      Private cards: [2♠, 2♣]
#      Community cards: []
#      Strongest hand: [2♠, 2♣]
#      Strongest hand type: PAIR
#      Strongest hand score: 202
#      Estimated strength: 0.709
#      Player decides to RAISE 240.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 240. Remaining stack: 640.
# PRE_FLOP | Current pot: 460
# PRE_FLOP | Player AggressiveBot raises to amount 260. Remaining stack: 990.
# PRE_FLOP | Current pot: 500
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 500
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 640
#      Current player bet: 240
#      Private cards: [2♠, 2♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 280
#      Private cards: [2♠, 2♣]
#      Community cards: []
#      Strongest hand: [2♠, 2♣]
#      Strongest hand type: PAIR
#      Strongest hand score: 202
#      Estimated strength: 0.714
#      Player decides to RAISE 280.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 280. Remaining stack: 600.
# PRE_FLOP | Current pot: 540
# PRE_FLOP | Player AggressiveBot raises to amount 300. Remaining stack: 950.
# PRE_FLOP | Current pot: 580
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 580
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 600
#      Current player bet: 280
#      Private cards: [2♠, 2♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 320
#      Private cards: [2♠, 2♣]
#      Community cards: []
#      Strongest hand: [2♠, 2♣]
#      Strongest hand type: PAIR
#      Strongest hand score: 202
#      Estimated strength: 0.69
#      Player decides to RAISE 320.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 320. Remaining stack: 560.
# PRE_FLOP | Current pot: 620
# PRE_FLOP | Player AggressiveBot raises to amount 340. Remaining stack: 910.
# PRE_FLOP | Current pot: 660
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 660
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 560
#      Current player bet: 320
#      Private cards: [2♠, 2♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 360
#      Private cards: [2♠, 2♣]
#      Community cards: []
#      Strongest hand: [2♠, 2♣]
#      Strongest hand type: PAIR
#      Strongest hand score: 202
#      Estimated strength: 0.697
#      Player decides to RAISE 360.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 360. Remaining stack: 520.
# PRE_FLOP | Current pot: 700
# PRE_FLOP | Player AggressiveBot raises to amount 380. Remaining stack: 870.
# PRE_FLOP | Current pot: 740
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 740
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 520
#      Current player bet: 360
#      Private cards: [2♠, 2♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 400
#      Private cards: [2♠, 2♣]
#      Community cards: []
#      Strongest hand: [2♠, 2♣]
#      Strongest hand type: PAIR
#      Strongest hand score: 202
#      Estimated strength: 0.696
#      Player decides to RAISE 400.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 400. Remaining stack: 480.
# PRE_FLOP | Current pot: 780
# PRE_FLOP | Player AggressiveBot raises to amount 420. Remaining stack: 830.
# PRE_FLOP | Current pot: 820
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 820
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 480
#      Current player bet: 400
#      Private cards: [2♠, 2♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 440
#      Private cards: [2♠, 2♣]
#      Community cards: []
#      Strongest hand: [2♠, 2♣]
#      Strongest hand type: PAIR
#      Strongest hand score: 202
#      Estimated strength: 0.725
#      Player decides to RAISE 440.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 440. Remaining stack: 440.
# PRE_FLOP | Current pot: 860
# PRE_FLOP | Player AggressiveBot raises to amount 460. Remaining stack: 790.
# PRE_FLOP | Current pot: 900
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 900
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 440
#      Current player bet: 440
#      Private cards: [2♠, 2♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 480
#      Private cards: [2♠, 2♣]
#      Community cards: []
#      Strongest hand: [2♠, 2♣]
#      Strongest hand type: PAIR
#      Strongest hand score: 202
#      Estimated strength: 0.702
#      Player decides to RAISE 480.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 480. Remaining stack: 400.
# PRE_FLOP | Current pot: 940
# PRE_FLOP | Player AggressiveBot raises to amount 500. Remaining stack: 750.
# PRE_FLOP | Current pot: 980
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 980
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 400
#      Current player bet: 480
#      Private cards: [2♠, 2♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 520
#      Private cards: [2♠, 2♣]
#      Community cards: []
#      Strongest hand: [2♠, 2♣]
#      Strongest hand type: PAIR
#      Strongest hand score: 202
#      Estimated strength: 0.699
#      Player decides to RAISE 520.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 520. Remaining stack: 360.
# PRE_FLOP | Current pot: 1020
# PRE_FLOP | Player AggressiveBot raises to amount 540. Remaining stack: 710.
# PRE_FLOP | Current pot: 1060
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 1060
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 360
#      Current player bet: 520
#      Private cards: [2♠, 2♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 560
#      Private cards: [2♠, 2♣]
#      Community cards: []
#      Strongest hand: [2♠, 2♣]
#      Strongest hand type: PAIR
#      Strongest hand score: 202
#      Estimated strength: 0.73
#      Player decides to RAISE 560.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 560. Remaining stack: 320.
# PRE_FLOP | Current pot: 1100
# PRE_FLOP | Player AggressiveBot raises to amount 580. Remaining stack: 670.
# PRE_FLOP | Current pot: 1140
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 1140
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 320
#      Current player bet: 560
#      Private cards: [2♠, 2♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 600
#      Private cards: [2♠, 2♣]
#      Community cards: []
#      Strongest hand: [2♠, 2♣]
#      Strongest hand type: PAIR
#      Strongest hand score: 202
#      Estimated strength: 0.696
#      Player decides to RAISE 600.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 600. Remaining stack: 280.
# PRE_FLOP | Current pot: 1180
# PRE_FLOP | Player AggressiveBot raises to amount 620. Remaining stack: 630.
# PRE_FLOP | Current pot: 1220
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 1
#      Current pot: 1220
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 280
#      Current player bet: 600
#      Private cards: [2♠, 2♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 640
#      Private cards: [2♠, 2♣]
#      Community cards: []
#      Strongest hand: [2♠, 2♣]
#      Strongest hand type: PAIR
#      Strongest hand score: 202
#      Estimated strength: 0.711
#      Player decides to RAISE 640.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 640. Remaining stack: 240.
# PRE_FLOP | Current pot: 1260
# PRE_FLOP | Player AggressiveBot calls with amount 20. Remaining stack: 610.
# PRE_FLOP | Current pot: 1280
# PRE_FLOP | Betting round complete
#
# FLOP | Dealt flop. Community cards: ['3♦', '7♦', '6♥']
# FLOP | Player AggressiveBot bets amount 40. Remaining stack: 570.
# FLOP | Current pot: 1320
#
# ComplexPlayer is requested to take action.
#      Current street: FLOP
#      Button position: 1
#      Current pot: 1320
#      Small blind: 10
#      Big blind: 20
#      Community cards: [3♦, 7♦, 6♥]
#      Player stack: 240
#      Current player bet: 0
#      Private cards: [2♠, 2♣]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 60
#      Private cards: [2♠, 2♣]
#      Community cards: [3♦, 7♦, 6♥]
#      Strongest hand: [2♠, 2♣, 3♦, 7♦, 6♥]
#      Strongest hand type: PAIR
#      Strongest hand score: 202.070603
#      Estimated strength: 0.506
#      Player decides to FOLD.
#
# FLOP | Player ComplexPlayer folds.
# FLOP | Current pot: 1320
# FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 1320 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 15 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 230
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 850
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 1850.
# PRE_FLOP | Current pot: 70
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 2
#      Current pot: 70
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 230
#      Current player bet: 10
#      Private cards: [3♦, 3♠]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 60
#      Private cards: [3♦, 3♠]
#      Community cards: []
#      Strongest hand: [3♦, 3♠]
#      Strongest hand type: PAIR
#      Strongest hand score: 203
#      Estimated strength: 0.558
#      Player decides to RAISE 80.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 80. Remaining stack: 160.
# PRE_FLOP | Current pot: 140
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 140
# PRE_FLOP | Player AggressiveBot raises to amount 100. Remaining stack: 1790.
# PRE_FLOP | Current pot: 200
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 2
#      Current pot: 200
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 160
#      Current player bet: 80
#      Private cards: [3♦, 3♠]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 120
#      Private cards: [3♦, 3♠]
#      Community cards: []
#      Strongest hand: [3♦, 3♠]
#      Strongest hand type: PAIR
#      Strongest hand score: 203
#      Estimated strength: 0.736
#      Player decides to RAISE 120.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 120. Remaining stack: 120.
# PRE_FLOP | Current pot: 240
# PRE_FLOP | Player AggressiveBot raises to amount 140. Remaining stack: 1750.
# PRE_FLOP | Current pot: 280
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 2
#      Current pot: 280
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 120
#      Current player bet: 120
#      Private cards: [3♦, 3♠]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 160
#      Private cards: [3♦, 3♠]
#      Community cards: []
#      Strongest hand: [3♦, 3♠]
#      Strongest hand type: PAIR
#      Strongest hand score: 203
#      Estimated strength: 0.715
#      Player decides to RAISE 160.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 160. Remaining stack: 80.
# PRE_FLOP | Current pot: 320
# PRE_FLOP | Player AggressiveBot raises to amount 180. Remaining stack: 1710.
# PRE_FLOP | Current pot: 360
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 2
#      Current pot: 360
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 80
#      Current player bet: 160
#      Private cards: [3♦, 3♠]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 200
#      Private cards: [3♦, 3♠]
#      Community cards: []
#      Strongest hand: [3♦, 3♠]
#      Strongest hand type: PAIR
#      Strongest hand score: 203
#      Estimated strength: 0.724
#      Player decides to RAISE 200.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 200. Remaining stack: 40.
# PRE_FLOP | Current pot: 400
# PRE_FLOP | Player AggressiveBot raises to amount 220. Remaining stack: 1670.
# PRE_FLOP | Current pot: 440
#
# ComplexPlayer is requested to take action.
#      Current street: PRE_FLOP
#      Button position: 2
#      Current pot: 440
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 40
#      Current player bet: 200
#      Private cards: [3♦, 3♠]
#      Valid actions: ['FOLD', 'CALL', 'RAISE', 'ALL_IN']
#      Minimum raise: 240
#      Private cards: [3♦, 3♠]
#      Community cards: []
#      Strongest hand: [3♦, 3♠]
#      Strongest hand type: PAIR
#      Strongest hand score: 203
#      Estimated strength: 0.736
#      Player decides to RAISE 240.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 240. Remaining stack: 0.
# PRE_FLOP | Current pot: 480
# PRE_FLOP | Player AggressiveBot raises to amount 260. Remaining stack: 1630.
# PRE_FLOP | Current pot: 520
# PRE_FLOP | Betting round complete
#
# FLOP | Dealt flop. Community cards: ['6♦', '6♣', '4♥']
# FLOP | Player AggressiveBot bets amount 40. Remaining stack: 1590.
# FLOP | Current pot: 560
# FLOP | Betting round complete
#
# TURN | Dealt turn. Community cards: ['6♦', '6♣', '4♥', '7♠']
# TURN | Player AggressiveBot bets amount 40. Remaining stack: 1550.
# TURN | Current pot: 600
# TURN | Betting round complete
#
# RIVER | Dealt river. Community cards: ['6♦', '6♣', '4♥', '7♠', '7♣']
# RIVER | Player AggressiveBot bets amount 40. Remaining stack: 1510.
# RIVER | Current pot: 640
# RIVER | Betting round complete
#
# SHOWDOWN | Player ComplexPlayer has hand TWO_PAIR with cards ['6♦', '6♣', '4♥', '7♠', '7♣'] (score: 307.06)
# SHOWDOWN | Player AggressiveBot has hand TWO_PAIR with cards ['Q♥', '6♦', '6♣', '7♠', '7♣'] (score: 307.061)
# SHOWDOWN | Player AggressiveBot wins 640 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 16 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 840
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 2130
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 2110.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 50 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 17 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 2150
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 820
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 18 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 810
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 2160
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 2140.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 50 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 19 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 2180
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 790
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 20 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 780
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 2190
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 2170.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 50 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 21 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 2210
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 760
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 22 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 750
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 2220
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 2200.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 50 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 23 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 2240
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 730
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 24 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 720
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 2250
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 2230.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 50 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 25 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 2270
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 700
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 26 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 690
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 2280
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 2260.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 50 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 27 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 2300
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 670
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 28 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 660
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 2310
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 2290.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 50 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 29 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 2330
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 640
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 30 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 630
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 2340
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 2320.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 50 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 31 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 2360
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 610
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 32 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 600
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 2370
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 2350.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 50 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 33 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 2390
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 580
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 34 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 570
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 2400
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 2380.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 50 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 35 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 2420
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 550
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 36 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 540
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 2430
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 2410.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 50 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 37 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 2450
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 520
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 38 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 510
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 2460
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 2440.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 50 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 39 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 2480
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 490
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# ============================== Hand 40 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 480
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 2490
# PRE_FLOP | Player AggressiveBot raises to amount 40. Remaining stack: 2470.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 50
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 50 from the pot.
# SHOWDOWN | SHOWDOWN_OCCURRED complete
#
# Hand ended
#
# Reached maximum number of hands, ending game.
# Game ended

# %%
for player in players:
    print(f"{player.name} - Stack: {player.state.stack}")
# Out:
# ComplexPlayer - Stack: 0
# FoldBot - Stack: 480
# AggressiveBot - Stack: 2520
