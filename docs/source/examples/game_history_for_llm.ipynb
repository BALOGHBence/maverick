# %% [markdown]
# # Create Game History for an LLM
#
# If you plan to register LLMs as players, you might want to pass the full game history. This way, the LLM can recognize behavioral patterns of players and make better decisions, perhaps even exploit the weaknesses of the players. In this notebook we define an `EventListener` class that maintains a game history that you can pass to an LLM.

# %%
from maverick.players import FoldBot, CallBot, AggressiveBot
from maverick import (
    PlayerLike,
    PlayerState,
    Game,
    GameEvent,
    GameEventType,
    PlayerAction,
    ActionType,
)

# %%
class EventListener:
    def __init__(self, game: Game=None):
        self.game = game
        self.events = []
        self.id_to_player = {}
        self.max_line_length = 80
        self.dump = []

        self.listen(game)
        
    def listen(self, game: Game=None) -> None:
        if game is None:
            return
        
        self.game = game
        self._subscribe_to_events()
        self._register_players()
            
    def _subscribe_to_events(self) -> None:
        for event_type in GameEventType:
            self.game.subscribe(event_type, self._handle_event)

    def _register_players(self) -> None:
        self.id_to_player = {player.id: player for player in self.game.state.players}
    
    @property
    def history(self) -> str:
        return "\n".join(self.events)
    
    def _log_betting_round_started(self) -> None:
        if len(self.game.state.community_cards) == 0:
            self.events.append("Community cards: None")
        else:
            self.events.append(f"Community cards: {[card.code() for card in self.game.state.community_cards]}")
        
        current_bet = self.game.state.current_bet
        current_pot = self.game.state.pot
        last_raise_size = self.game.state.last_raise_size
        self.events.append((
            f"Current pot size: {current_pot}. "
            f"Current bet: {current_bet}. "
            f"Minimum raise size: {last_raise_size}."
        ))
        
        self.events.append("")
    
    def _log_section_header(self, title: str, chr:str, *, add_empty_line:bool=True) -> None:
        len_title = len(title) + 2 if len(title) > 0 else 0
        len_prefix_suffix = (self.max_line_length - len_title) // 2
        title = f" {title} " if len_title > 0 else ""
        msg = chr * len_prefix_suffix + f"{title}" + chr * len_prefix_suffix
        if len(msg) < self.max_line_length:
            msg += chr
        elif len(msg) > self.max_line_length:
            msg = msg[:self.max_line_length]
        msg = msg[:self.max_line_length]
        self.events.append(msg)
        if add_empty_line:
            self.events.append("")
            
    def _handle_event(self, event: GameEvent, game: Game) -> None:
        """Count each type of event."""
        self.dump.append(event.model_dump(mode="json"))
        
        hand_number = game.state.hand_number

        match event.type:
            case GameEventType.GAME_STARTED:
                self._log_section_header("", "=", add_empty_line=False)
                self._log_section_header(f"Game Started", "=", add_empty_line=False)
                self._log_section_header("", "=")
                
                self.events.append("Game type: No-Limit Texas Hold'em")
                self.events.append(f"Small blind: {game.state.small_blind}")
                self.events.append(f"Big blind: {game.state.big_blind}")
                self.events.append(f"Ante: {game.state.ante}")
                self.events.append("")
                
                self.events.append("Players at the table:")
                for player in self.game.state.players:
                    self.events.append(f"    {player.name}: Starting stack {player.state.stack}")
                self.events.append("")
            
            case GameEventType.HAND_STARTED:
                if len(self.events) > 0 and len(self.events[-1].strip()) > 0:
                    self.events.append("")
                
                self._log_section_header(f"Hand {hand_number}", "=")
                
                num_players = len(game.state.players)
                
                button_position = game.state.button_position
                button_player = game.state.players[button_position]
                self.events.append(f"{button_player.name} is on the button.")
                
                small_blind_position = (button_position + 1) % num_players
                small_blind_player = game.state.players[small_blind_position]
                self.events.append(f"{small_blind_player.name} is the small blind.")
                
                big_blind_position = (button_position + 2) % num_players
                big_blind_player = game.state.players[big_blind_position]
                self.events.append(f"{big_blind_player.name} is the big blind.")
                
                utg_position = (button_position + 3) % num_players
                utg_player = game.state.players[utg_position]
                self.events.append(f"{utg_player.name} is under the gun.")
                
                self.events.append("")
                
                self.events.append(f"Player stacks at the beginning of hand {hand_number}:")
                for player in self.game.state.players:
                    self.events.append(f"    {player.name}: {player.state.stack}")
                self.events.append("")
                
            case GameEventType.BETTING_ROUND_STARTED:
                street_name = game.state.street.name
                self._log_section_header(f"Hand: {hand_number} | Street: {street_name}", "-")
                self._log_betting_round_started()

            case GameEventType.PLAYER_ACTION_TAKEN:
                action: PlayerAction = event.action
                player_id = event.player_id
                player = self.id_to_player[player_id]
                current_bet = game.state.current_bet
                current_pot = game.state.pot
                last_raise_size = game.state.last_raise_size

                match action.action_type:
                    case ActionType.FOLD:
                        self.events.append(f"[{player.name}] folds. Remaining stack: {player.state.stack}.")
                    case ActionType.CALL:
                        self.events.append(f"[{player.name}] calls. Remaining stack: {player.state.stack}.")
                    case ActionType.RAISE:
                        self.events.append(f"[{player.name}] raises bet to {current_bet}. Remaining stack: {player.state.stack}.")
                    case ActionType.CHECK:
                        self.events.append(f"[{player.name}] checks. Remaining stack: {player.state.stack}.")
                    case ActionType.BET:
                        self.events.append(f"[{player.name}] bets {action.amount}. Remaining stack: {player.state.stack}.")
                        
                self.events.append((
                    f"Current pot size: {current_pot}. "
                    f"Current bet: {current_bet}. "
                    f"Minimum raise size: {last_raise_size}."
                ))
                        
            case GameEventType.BETTING_ROUND_COMPLETED:
                self.events.append("")
                self.events.append(f"Player standings after the betting round:")
                for player in game.state.players:
                    player_pot = player.state.total_contributed
                    state_type = player.state.state_type.name
                    self.events.append(f"    {player.name}: State={state_type}, Pot={player_pot}, Stack={player.state.stack}")
                self.events.append("")

            case GameEventType.SHOWDOWN_STARTED:
                self._log_section_header(f"Hand: {hand_number} | SHOWDOWN", "-")
                
            case GameEventType.PLAYER_CARDS_REVEALED:
                player_id = event.player_id
                player = self.id_to_player[player_id]
                payload = event.payload
                self.events.append((
                    f"{player.name} reveals: {payload['holding']}. "
                    f"Best hand: {payload['best_hand']} ({payload['best_hand_type']}). "
                    f"Hand score: {payload['best_score']}."
                ))
            
            case GameEventType.SHOWDOWN_COMPLETED:
                self.events.append("")
                self.events.append(f"Player stacks after showdown:")
                for player in game.state.players:
                    self.events.append(f"    {player.name}: {player.state.stack}")
                self.events.append("")
                
            case GameEventType.POT_WON:
                player_id = event.player_id
                player = self.id_to_player[player_id]
                amount = event.payload.get("amount", 0)
                self.events.append(f"{player.name} wins {amount}.")
                
            case GameEventType.PLAYER_ELIMINATED:
                player_id = event.player_id
                player = self.id_to_player[player_id]
                self.events.append(f"{player.name} has been eliminated from the game.")

            case GameEventType.HAND_ENDED:
                pass

# %%
game = Game(small_blind=10, big_blind=20, max_hands=10)

players: list[PlayerLike] = [
    CallBot(name="CallBot", state=PlayerState(stack=1000)),
    AggressiveBot(name="AggroBot", state=PlayerState(stack=1000)),
    FoldBot(name="FoldBot", state=PlayerState(stack=1000)),
]

for player in players:
    game.add_player(player)


event_listener = EventListener(game)

game.start()

print(event_listener.history)
# Out:
# ================================================================================
# ================================= Game Started =================================
# ================================================================================
#
# Game type: No-Limit Texas Hold'em
# Small blind: 10
# Big blind: 20
# Ante: 0
#
# Players at the table:
#     CallBot: Starting stack 1000
#     AggroBot: Starting stack 1000
#     FoldBot: Starting stack 1000
#
# ==================================== Hand 1 ====================================
#
# FoldBot is on the button.
# CallBot is the small blind.
# AggroBot is the big blind.
# FoldBot is under the gun.
#
# Player stacks at the beginning of hand 1:
#     CallBot: 1000
#     AggroBot: 1000
#     FoldBot: 1000
#
# -------------------------- Hand: 1 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [FoldBot] folds. Remaining stack: 1000.
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 980.
# Current pot size: 40. Current bet: 20. Minimum raise size: 20.
# [AggroBot] raises bet to 40. Remaining stack: 960.
# Current pot size: 60. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 960.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=960
#     AggroBot: State=ACTIVE, Pot=40, Stack=960
#     FoldBot: State=FOLDED, Pot=0, Stack=1000
#
# ---------------------------- Hand: 1 | Street: FLOP ----------------------------
#
# Community cards: ['2c', 'Kc', '9d']
# Current pot size: 80. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 960.
# Current pot size: 80. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 920.
# Current pot size: 120. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 920.
# Current pot size: 160. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=920
#     AggroBot: State=ACTIVE, Pot=80, Stack=920
#     FoldBot: State=FOLDED, Pot=0, Stack=1000
#
# ---------------------------- Hand: 1 | Street: TURN ----------------------------
#
# Community cards: ['2c', 'Kc', '9d', '4s']
# Current pot size: 160. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 920.
# Current pot size: 160. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 880.
# Current pot size: 200. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 880.
# Current pot size: 240. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=880
#     AggroBot: State=ACTIVE, Pot=120, Stack=880
#     FoldBot: State=FOLDED, Pot=0, Stack=1000
#
# --------------------------- Hand: 1 | Street: RIVER ----------------------------
#
# Community cards: ['2c', 'Kc', '9d', '4s', '5h']
# Current pot size: 240. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 880.
# Current pot size: 240. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 840.
# Current pot size: 280. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 840.
# Current pot size: 320. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=840
#     AggroBot: State=ACTIVE, Pot=160, Stack=840
#     FoldBot: State=FOLDED, Pot=0, Stack=1000
#
# ------------------------------ Hand: 1 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['3c', '8s']. Best hand: ['8s', 'Kc', '9d', '4s', '5h'] (HIGH_CARD). Hand score: 100.1309080504.
# AggroBot reveals: ['Kh', 'Tc']. Best hand: ['Kh', 'Tc', 'Kc', '9d', '5h'] (PAIR). Hand score: 213.100905.
# AggroBot wins 320.
#
# Player stacks after showdown:
#     CallBot: 840
#     AggroBot: 1160
#     FoldBot: 1000
#
# ==================================== Hand 2 ====================================
#
# CallBot is on the button.
# AggroBot is the small blind.
# FoldBot is the big blind.
# CallBot is under the gun.
#
# Player stacks at the beginning of hand 2:
#     CallBot: 840
#     AggroBot: 1160
#     FoldBot: 1000
#
# -------------------------- Hand: 2 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [CallBot] calls. Remaining stack: 820.
# Current pot size: 50. Current bet: 20. Minimum raise size: 20.
# [AggroBot] raises bet to 40. Remaining stack: 1120.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
# [FoldBot] folds. Remaining stack: 980.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 800.
# Current pot size: 100. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=800
#     AggroBot: State=ACTIVE, Pot=40, Stack=1120
#     FoldBot: State=FOLDED, Pot=20, Stack=980
#
# ---------------------------- Hand: 2 | Street: FLOP ----------------------------
#
# Community cards: ['6s', 'Qh', 'Jd']
# Current pot size: 100. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1080.
# Current pot size: 140. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 760.
# Current pot size: 180. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=760
#     AggroBot: State=ACTIVE, Pot=80, Stack=1080
#     FoldBot: State=FOLDED, Pot=20, Stack=980
#
# ---------------------------- Hand: 2 | Street: TURN ----------------------------
#
# Community cards: ['6s', 'Qh', 'Jd', '7h']
# Current pot size: 180. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1040.
# Current pot size: 220. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 720.
# Current pot size: 260. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=720
#     AggroBot: State=ACTIVE, Pot=120, Stack=1040
#     FoldBot: State=FOLDED, Pot=20, Stack=980
#
# --------------------------- Hand: 2 | Street: RIVER ----------------------------
#
# Community cards: ['6s', 'Qh', 'Jd', '7h', '5s']
# Current pot size: 260. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 300. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 680.
# Current pot size: 340. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=680
#     AggroBot: State=ACTIVE, Pot=160, Stack=1000
#     FoldBot: State=FOLDED, Pot=20, Stack=980
#
# ------------------------------ Hand: 2 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['6h', '3c']. Best hand: ['6h', '6s', 'Qh', 'Jd', '7h'] (PAIR). Hand score: 206.121107.
# AggroBot reveals: ['9c', '5d']. Best hand: ['9c', '5d', 'Qh', 'Jd', '5s'] (PAIR). Hand score: 205.121109.
# CallBot wins 340.
#
# Player stacks after showdown:
#     CallBot: 1020
#     AggroBot: 1000
#     FoldBot: 980
#
# ==================================== Hand 3 ====================================
#
# AggroBot is on the button.
# FoldBot is the small blind.
# CallBot is the big blind.
# AggroBot is under the gun.
#
# Player stacks at the beginning of hand 3:
#     CallBot: 1020
#     AggroBot: 1000
#     FoldBot: 980
#
# -------------------------- Hand: 3 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [AggroBot] raises bet to 40. Remaining stack: 960.
# Current pot size: 70. Current bet: 40. Minimum raise size: 20.
# [FoldBot] folds. Remaining stack: 970.
# Current pot size: 70. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 980.
# Current pot size: 90. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=980
#     AggroBot: State=ACTIVE, Pot=40, Stack=960
#     FoldBot: State=FOLDED, Pot=10, Stack=970
#
# ---------------------------- Hand: 3 | Street: FLOP ----------------------------
#
# Community cards: ['Qd', 'Ts', 'As']
# Current pot size: 90. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 980.
# Current pot size: 90. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 920.
# Current pot size: 130. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 940.
# Current pot size: 170. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=940
#     AggroBot: State=ACTIVE, Pot=80, Stack=920
#     FoldBot: State=FOLDED, Pot=10, Stack=970
#
# ---------------------------- Hand: 3 | Street: TURN ----------------------------
#
# Community cards: ['Qd', 'Ts', 'As', '3h']
# Current pot size: 170. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 940.
# Current pot size: 170. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 880.
# Current pot size: 210. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 900.
# Current pot size: 250. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=900
#     AggroBot: State=ACTIVE, Pot=120, Stack=880
#     FoldBot: State=FOLDED, Pot=10, Stack=970
#
# --------------------------- Hand: 3 | Street: RIVER ----------------------------
#
# Community cards: ['Qd', 'Ts', 'As', '3h', '6s']
# Current pot size: 250. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 900.
# Current pot size: 250. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 840.
# Current pot size: 290. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 860.
# Current pot size: 330. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=860
#     AggroBot: State=ACTIVE, Pot=160, Stack=840
#     FoldBot: State=FOLDED, Pot=10, Stack=970
#
# ------------------------------ Hand: 3 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['7c', 'Kd']. Best hand: ['7c', 'Kd', 'Qd', 'Ts', 'As'] (HIGH_CARD). Hand score: 100.1413121007.
# AggroBot reveals: ['8c', '6c']. Best hand: ['6c', 'Qd', 'Ts', 'As', '6s'] (PAIR). Hand score: 206.14121.
# AggroBot wins 330.
#
# Player stacks after showdown:
#     CallBot: 860
#     AggroBot: 1170
#     FoldBot: 970
#
# ==================================== Hand 4 ====================================
#
# FoldBot is on the button.
# CallBot is the small blind.
# AggroBot is the big blind.
# FoldBot is under the gun.
#
# Player stacks at the beginning of hand 4:
#     CallBot: 860
#     AggroBot: 1170
#     FoldBot: 970
#
# -------------------------- Hand: 4 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [FoldBot] folds. Remaining stack: 970.
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 840.
# Current pot size: 40. Current bet: 20. Minimum raise size: 20.
# [AggroBot] raises bet to 40. Remaining stack: 1130.
# Current pot size: 60. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 820.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=820
#     AggroBot: State=ACTIVE, Pot=40, Stack=1130
#     FoldBot: State=FOLDED, Pot=0, Stack=970
#
# ---------------------------- Hand: 4 | Street: FLOP ----------------------------
#
# Community cards: ['6s', 'Ac', '5h']
# Current pot size: 80. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 820.
# Current pot size: 80. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1090.
# Current pot size: 120. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 780.
# Current pot size: 160. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=780
#     AggroBot: State=ACTIVE, Pot=80, Stack=1090
#     FoldBot: State=FOLDED, Pot=0, Stack=970
#
# ---------------------------- Hand: 4 | Street: TURN ----------------------------
#
# Community cards: ['6s', 'Ac', '5h', '8h']
# Current pot size: 160. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 780.
# Current pot size: 160. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1050.
# Current pot size: 200. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 740.
# Current pot size: 240. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=740
#     AggroBot: State=ACTIVE, Pot=120, Stack=1050
#     FoldBot: State=FOLDED, Pot=0, Stack=970
#
# --------------------------- Hand: 4 | Street: RIVER ----------------------------
#
# Community cards: ['6s', 'Ac', '5h', '8h', '2s']
# Current pot size: 240. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 740.
# Current pot size: 240. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1010.
# Current pot size: 280. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 700.
# Current pot size: 320. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=700
#     AggroBot: State=ACTIVE, Pot=160, Stack=1010
#     FoldBot: State=FOLDED, Pot=0, Stack=970
#
# ------------------------------ Hand: 4 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['6h', '9s']. Best hand: ['6h', '9s', '6s', 'Ac', '8h'] (PAIR). Hand score: 206.140908.
# AggroBot reveals: ['Kd', 'Js']. Best hand: ['Kd', 'Js', '6s', 'Ac', '8h'] (HIGH_CARD). Hand score: 100.1413110806.
# CallBot wins 320.
#
# Player stacks after showdown:
#     CallBot: 1020
#     AggroBot: 1010
#     FoldBot: 970
#
# ==================================== Hand 5 ====================================
#
# CallBot is on the button.
# AggroBot is the small blind.
# FoldBot is the big blind.
# CallBot is under the gun.
#
# Player stacks at the beginning of hand 5:
#     CallBot: 1020
#     AggroBot: 1010
#     FoldBot: 970
#
# -------------------------- Hand: 5 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 50. Current bet: 20. Minimum raise size: 20.
# [AggroBot] raises bet to 40. Remaining stack: 970.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
# [FoldBot] folds. Remaining stack: 950.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 980.
# Current pot size: 100. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=980
#     AggroBot: State=ACTIVE, Pot=40, Stack=970
#     FoldBot: State=FOLDED, Pot=20, Stack=950
#
# ---------------------------- Hand: 5 | Street: FLOP ----------------------------
#
# Community cards: ['Ac', 'Ks', '7d']
# Current pot size: 100. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 930.
# Current pot size: 140. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 940.
# Current pot size: 180. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=940
#     AggroBot: State=ACTIVE, Pot=80, Stack=930
#     FoldBot: State=FOLDED, Pot=20, Stack=950
#
# ---------------------------- Hand: 5 | Street: TURN ----------------------------
#
# Community cards: ['Ac', 'Ks', '7d', 'Ad']
# Current pot size: 180. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 890.
# Current pot size: 220. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 900.
# Current pot size: 260. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=900
#     AggroBot: State=ACTIVE, Pot=120, Stack=890
#     FoldBot: State=FOLDED, Pot=20, Stack=950
#
# --------------------------- Hand: 5 | Street: RIVER ----------------------------
#
# Community cards: ['Ac', 'Ks', '7d', 'Ad', '2s']
# Current pot size: 260. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 850.
# Current pot size: 300. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 860.
# Current pot size: 340. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=860
#     AggroBot: State=ACTIVE, Pot=160, Stack=850
#     FoldBot: State=FOLDED, Pot=20, Stack=950
#
# ------------------------------ Hand: 5 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['Qc', '5d']. Best hand: ['Qc', 'Ac', 'Ks', '7d', 'Ad'] (PAIR). Hand score: 214.131207.
# AggroBot reveals: ['7s', 'Ts']. Best hand: ['7s', 'Ac', 'Ks', '7d', 'Ad'] (TWO_PAIR). Hand score: 314.0713.
# AggroBot wins 340.
#
# Player stacks after showdown:
#     CallBot: 860
#     AggroBot: 1190
#     FoldBot: 950
#
# ==================================== Hand 6 ====================================
#
# AggroBot is on the button.
# FoldBot is the small blind.
# CallBot is the big blind.
# AggroBot is under the gun.
#
# Player stacks at the beginning of hand 6:
#     CallBot: 860
#     AggroBot: 1190
#     FoldBot: 950
#
# -------------------------- Hand: 6 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [AggroBot] raises bet to 40. Remaining stack: 1150.
# Current pot size: 70. Current bet: 40. Minimum raise size: 20.
# [FoldBot] folds. Remaining stack: 940.
# Current pot size: 70. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 820.
# Current pot size: 90. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=820
#     AggroBot: State=ACTIVE, Pot=40, Stack=1150
#     FoldBot: State=FOLDED, Pot=10, Stack=940
#
# ---------------------------- Hand: 6 | Street: FLOP ----------------------------
#
# Community cards: ['5d', 'Qh', '9h']
# Current pot size: 90. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 820.
# Current pot size: 90. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1110.
# Current pot size: 130. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 780.
# Current pot size: 170. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=780
#     AggroBot: State=ACTIVE, Pot=80, Stack=1110
#     FoldBot: State=FOLDED, Pot=10, Stack=940
#
# ---------------------------- Hand: 6 | Street: TURN ----------------------------
#
# Community cards: ['5d', 'Qh', '9h', '5h']
# Current pot size: 170. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 780.
# Current pot size: 170. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1070.
# Current pot size: 210. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 740.
# Current pot size: 250. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=740
#     AggroBot: State=ACTIVE, Pot=120, Stack=1070
#     FoldBot: State=FOLDED, Pot=10, Stack=940
#
# --------------------------- Hand: 6 | Street: RIVER ----------------------------
#
# Community cards: ['5d', 'Qh', '9h', '5h', 'Ac']
# Current pot size: 250. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 740.
# Current pot size: 250. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1030.
# Current pot size: 290. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 700.
# Current pot size: 330. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=700
#     AggroBot: State=ACTIVE, Pot=160, Stack=1030
#     FoldBot: State=FOLDED, Pot=10, Stack=940
#
# ------------------------------ Hand: 6 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['7h', 'Qs']. Best hand: ['Qs', '5d', 'Qh', '5h', 'Ac'] (TWO_PAIR). Hand score: 312.0514.
# AggroBot reveals: ['8c', '2h']. Best hand: ['5d', 'Qh', '9h', '5h', 'Ac'] (PAIR). Hand score: 205.141209.
# CallBot wins 330.
#
# Player stacks after showdown:
#     CallBot: 1030
#     AggroBot: 1030
#     FoldBot: 940
#
# ==================================== Hand 7 ====================================
#
# FoldBot is on the button.
# CallBot is the small blind.
# AggroBot is the big blind.
# FoldBot is under the gun.
#
# Player stacks at the beginning of hand 7:
#     CallBot: 1030
#     AggroBot: 1030
#     FoldBot: 940
#
# -------------------------- Hand: 7 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [FoldBot] folds. Remaining stack: 940.
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 1010.
# Current pot size: 40. Current bet: 20. Minimum raise size: 20.
# [AggroBot] raises bet to 40. Remaining stack: 990.
# Current pot size: 60. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 990.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=990
#     AggroBot: State=ACTIVE, Pot=40, Stack=990
#     FoldBot: State=FOLDED, Pot=0, Stack=940
#
# ---------------------------- Hand: 7 | Street: FLOP ----------------------------
#
# Community cards: ['4d', '9d', 'Ad']
# Current pot size: 80. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 990.
# Current pot size: 80. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 950.
# Current pot size: 120. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 950.
# Current pot size: 160. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=950
#     AggroBot: State=ACTIVE, Pot=80, Stack=950
#     FoldBot: State=FOLDED, Pot=0, Stack=940
#
# ---------------------------- Hand: 7 | Street: TURN ----------------------------
#
# Community cards: ['4d', '9d', 'Ad', '6d']
# Current pot size: 160. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 950.
# Current pot size: 160. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 910.
# Current pot size: 200. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 910.
# Current pot size: 240. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=910
#     AggroBot: State=ACTIVE, Pot=120, Stack=910
#     FoldBot: State=FOLDED, Pot=0, Stack=940
#
# --------------------------- Hand: 7 | Street: RIVER ----------------------------
#
# Community cards: ['4d', '9d', 'Ad', '6d', 'Jh']
# Current pot size: 240. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 910.
# Current pot size: 240. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 870.
# Current pot size: 280. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 870.
# Current pot size: 320. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=870
#     AggroBot: State=ACTIVE, Pot=160, Stack=870
#     FoldBot: State=FOLDED, Pot=0, Stack=940
#
# ------------------------------ Hand: 7 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['3d', '8c']. Best hand: ['3d', '4d', '9d', 'Ad', '6d'] (FLUSH). Hand score: 600.1409060403.
# AggroBot reveals: ['5d', '8s']. Best hand: ['5d', '4d', '9d', 'Ad', '6d'] (FLUSH). Hand score: 600.1409060504.
# AggroBot wins 320.
#
# Player stacks after showdown:
#     CallBot: 870
#     AggroBot: 1190
#     FoldBot: 940
#
# ==================================== Hand 8 ====================================
#
# CallBot is on the button.
# AggroBot is the small blind.
# FoldBot is the big blind.
# CallBot is under the gun.
#
# Player stacks at the beginning of hand 8:
#     CallBot: 870
#     AggroBot: 1190
#     FoldBot: 940
#
# -------------------------- Hand: 8 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [CallBot] calls. Remaining stack: 850.
# Current pot size: 50. Current bet: 20. Minimum raise size: 20.
# [AggroBot] raises bet to 40. Remaining stack: 1150.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
# [FoldBot] folds. Remaining stack: 920.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 830.
# Current pot size: 100. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=830
#     AggroBot: State=ACTIVE, Pot=40, Stack=1150
#     FoldBot: State=FOLDED, Pot=20, Stack=920
#
# ---------------------------- Hand: 8 | Street: FLOP ----------------------------
#
# Community cards: ['Jc', '8c', '8h']
# Current pot size: 100. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1110.
# Current pot size: 140. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 790.
# Current pot size: 180. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=790
#     AggroBot: State=ACTIVE, Pot=80, Stack=1110
#     FoldBot: State=FOLDED, Pot=20, Stack=920
#
# ---------------------------- Hand: 8 | Street: TURN ----------------------------
#
# Community cards: ['Jc', '8c', '8h', '5d']
# Current pot size: 180. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1070.
# Current pot size: 220. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 750.
# Current pot size: 260. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=750
#     AggroBot: State=ACTIVE, Pot=120, Stack=1070
#     FoldBot: State=FOLDED, Pot=20, Stack=920
#
# --------------------------- Hand: 8 | Street: RIVER ----------------------------
#
# Community cards: ['Jc', '8c', '8h', '5d', '7h']
# Current pot size: 260. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1030.
# Current pot size: 300. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 710.
# Current pot size: 340. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=710
#     AggroBot: State=ACTIVE, Pot=160, Stack=1030
#     FoldBot: State=FOLDED, Pot=20, Stack=920
#
# ------------------------------ Hand: 8 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['3d', '2s']. Best hand: ['Jc', '8c', '8h', '5d', '7h'] (PAIR). Hand score: 208.110705.
# AggroBot reveals: ['9h', '6c']. Best hand: ['9h', '6c', '8c', '5d', '7h'] (STRAIGHT). Hand score: 500.09.
# AggroBot wins 340.
#
# Player stacks after showdown:
#     CallBot: 710
#     AggroBot: 1370
#     FoldBot: 920
#
# ==================================== Hand 9 ====================================
#
# AggroBot is on the button.
# FoldBot is the small blind.
# CallBot is the big blind.
# AggroBot is under the gun.
#
# Player stacks at the beginning of hand 9:
#     CallBot: 710
#     AggroBot: 1370
#     FoldBot: 920
#
# -------------------------- Hand: 9 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [AggroBot] raises bet to 40. Remaining stack: 1330.
# Current pot size: 70. Current bet: 40. Minimum raise size: 20.
# [FoldBot] folds. Remaining stack: 910.
# Current pot size: 70. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 670.
# Current pot size: 90. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=670
#     AggroBot: State=ACTIVE, Pot=40, Stack=1330
#     FoldBot: State=FOLDED, Pot=10, Stack=910
#
# ---------------------------- Hand: 9 | Street: FLOP ----------------------------
#
# Community cards: ['3s', '5d', 'Ah']
# Current pot size: 90. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 670.
# Current pot size: 90. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1290.
# Current pot size: 130. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 630.
# Current pot size: 170. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=630
#     AggroBot: State=ACTIVE, Pot=80, Stack=1290
#     FoldBot: State=FOLDED, Pot=10, Stack=910
#
# ---------------------------- Hand: 9 | Street: TURN ----------------------------
#
# Community cards: ['3s', '5d', 'Ah', '2c']
# Current pot size: 170. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 630.
# Current pot size: 170. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1250.
# Current pot size: 210. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 590.
# Current pot size: 250. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=590
#     AggroBot: State=ACTIVE, Pot=120, Stack=1250
#     FoldBot: State=FOLDED, Pot=10, Stack=910
#
# --------------------------- Hand: 9 | Street: RIVER ----------------------------
#
# Community cards: ['3s', '5d', 'Ah', '2c', 'Tc']
# Current pot size: 250. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 590.
# Current pot size: 250. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1210.
# Current pot size: 290. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 550.
# Current pot size: 330. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=550
#     AggroBot: State=ACTIVE, Pot=160, Stack=1210
#     FoldBot: State=FOLDED, Pot=10, Stack=910
#
# ------------------------------ Hand: 9 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['Qh', '3c']. Best hand: ['Qh', '3c', '3s', 'Ah', 'Tc'] (PAIR). Hand score: 203.14121.
# AggroBot reveals: ['2s', '4c']. Best hand: ['2s', '4c', '3s', '5d', 'Ah'] (STRAIGHT). Hand score: 500.05.
# AggroBot wins 330.
#
# Player stacks after showdown:
#     CallBot: 550
#     AggroBot: 1540
#     FoldBot: 910
#
# =================================== Hand 10 ====================================
#
# FoldBot is on the button.
# CallBot is the small blind.
# AggroBot is the big blind.
# FoldBot is under the gun.
#
# Player stacks at the beginning of hand 10:
#     CallBot: 550
#     AggroBot: 1540
#     FoldBot: 910
#
# ------------------------- Hand: 10 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [FoldBot] folds. Remaining stack: 910.
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 530.
# Current pot size: 40. Current bet: 20. Minimum raise size: 20.
# [AggroBot] raises bet to 40. Remaining stack: 1500.
# Current pot size: 60. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 510.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=510
#     AggroBot: State=ACTIVE, Pot=40, Stack=1500
#     FoldBot: State=FOLDED, Pot=0, Stack=910
#
# --------------------------- Hand: 10 | Street: FLOP ----------------------------
#
# Community cards: ['Td', 'Js', 'Ks']
# Current pot size: 80. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 510.
# Current pot size: 80. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1460.
# Current pot size: 120. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 470.
# Current pot size: 160. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=470
#     AggroBot: State=ACTIVE, Pot=80, Stack=1460
#     FoldBot: State=FOLDED, Pot=0, Stack=910
#
# --------------------------- Hand: 10 | Street: TURN ----------------------------
#
# Community cards: ['Td', 'Js', 'Ks', '7s']
# Current pot size: 160. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 470.
# Current pot size: 160. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1420.
# Current pot size: 200. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 430.
# Current pot size: 240. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=430
#     AggroBot: State=ACTIVE, Pot=120, Stack=1420
#     FoldBot: State=FOLDED, Pot=0, Stack=910
#
# --------------------------- Hand: 10 | Street: RIVER ---------------------------
#
# Community cards: ['Td', 'Js', 'Ks', '7s', '7c']
# Current pot size: 240. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 430.
# Current pot size: 240. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1380.
# Current pot size: 280. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 390.
# Current pot size: 320. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=390
#     AggroBot: State=ACTIVE, Pot=160, Stack=1380
#     FoldBot: State=FOLDED, Pot=0, Stack=910
#
# ----------------------------- Hand: 10 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['3d', 'Th']. Best hand: ['Th', 'Td', 'Ks', '7s', '7c'] (TWO_PAIR). Hand score: 310.0713.
# AggroBot reveals: ['3h', '7h']. Best hand: ['7h', 'Js', 'Ks', '7s', '7c'] (THREE_OF_A_KIND). Hand score: 407.1311.
# AggroBot wins 320.
#
# Player stacks after showdown:
#     CallBot: 390
#     AggroBot: 1700
#     FoldBot: 910

# %% [markdown]
# You can turn the list of events that happened during the game as a Pandas DataFrame:

# %%
import uuid
import pandas as pd
from maverick import Street, GameEventType, GameStage

df = pd.DataFrame(event_listener.dump)
df["street"] = pd.to_numeric(df["street"], errors="coerce").astype("UInt8")
df["stage"] = pd.to_numeric(df["stage"], errors="coerce").astype("UInt8")
df["hand_number"] = pd.to_numeric(df["hand_number"], errors="coerce").astype("UInt8")
df.rename(
    columns={
        "type": "event_type_value",
        "stage": "stage_value",
        "street": "street_value",
        "ts": "event_ts",
        "id": "event_id",
    },
    inplace=True,
)

# Map enum values to names for better readability
street_map = {s.value: s.name for s in Street}
df["street_name"] = df["street_value"].map(street_map)

# Map enum values to names for better readability
event_type_map = {e.value: e.name for e in GameEventType}
df["event_type_name"] = df["event_type_value"].map(event_type_map)

# Map enum values to names for better readability
game_stage_map = {s.value: s.name for s in GameStage}
df["game_stage_name"] = df["stage_value"].map(game_stage_map)

# Add a unique game_id to group events from the same game together
game_id = uuid.uuid4().hex
df["game_id"] = game_id

df.head()
# Out:
#                            event_id      event_ts  event_type_value  \
# 0  20592ff26d944aa78bb37e48b04f54ce  1.770494e+09                 1
# 1  0f9df8f66f3840ea9a5d2864679b2eb5  1.770494e+09                 3
# 2  8d6c8469636c44d389ff9354a431ccbb  1.770494e+09                 7
# 3  d76c660932104fe1a73360a652a0e789  1.770494e+09                17
# 4  5242d1c37eb7470f9f41adacd5ce1f92  1.770494e+09                18
#
#    hand_number  street_value  stage_value player_id action payload  \
# 0            0          <NA>            3      None   None      {}
# 1            1             0            4      None   None      {}
# 2            1             0            4      None   None      {}
# 3            1             0            4      None   None      {}
# 4            1             0            4      None   None      {}
#
#   street_name   event_type_name game_stage_name  \
# 0         NaN      GAME_STARTED         STARTED
# 1    PRE_FLOP      HAND_STARTED         DEALING
# 2    PRE_FLOP  HOLE_CARDS_DEALT         DEALING
# 3    PRE_FLOP     BLINDS_POSTED         DEALING
# 4    PRE_FLOP      ANTES_POSTED         DEALING
#
#                             game_id
# 0  f279766732124413884413062a999348
# 1  f279766732124413884413062a999348
# 2  f279766732124413884413062a999348
# 3  f279766732124413884413062a999348
# 4  f279766732124413884413062a999348
