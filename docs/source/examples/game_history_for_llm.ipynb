# %% [markdown]
# # Create Game History for an LLM
#
# If you plan to register LLMs as players, you might want to pass the full game history. This way, the LLM can recognize behavioral patterns of players and make better decisions, perhaps even exploit the weaknesses of the players.
#
# You can use the built-in class {class}`~maverick.listeners.GameTranscriber` for this, that simply turns a series of events into a human readable string.

# %%
from maverick.players import FoldBot, CallBot, AggressiveBot
from maverick import PlayerLike, PlayerState, Game
from maverick.listeners import GameTranscriber

game = Game(small_blind=10, big_blind=20, max_hands=10)

players: list[PlayerLike] = [
    CallBot(name="CallBot"),
    AggressiveBot(name="AggroBot"),
    FoldBot(name="FoldBot"),
]

for player in players:
    game.add_player(player, state=PlayerState(stack=1000))


game_transcriber = GameTranscriber(game)

game.start()

# %% [markdown]
# You can turn the list of events that happened during the game into a human readable string by calling the `history` property:

# %%
print(game_transcriber.history)
# Out:
# ================================================================================
# ================================= Game Started =================================
# ================================================================================
#
# Game type: No-Limit Texas Hold'em
# Small blind: 10
# Big blind: 20
# Ante: 0
#
# Players at the table:
#     CallBot: Starting stack 1000
#     AggroBot: Starting stack 1000
#     FoldBot: Starting stack 1000
#
# ==================================== Hand 1 ====================================
#
# CallBot is on the button.
# AggroBot is the small blind.
# FoldBot is the big blind.
# CallBot is under the gun.
#
# Player stacks at the beginning of hand 1:
#     CallBot: 1000
#     AggroBot: 1000
#     FoldBot: 1000
#
# -------------------------- Hand: 1 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 50. Current bet: 20. Minimum raise size: 20.
# [AggroBot] raises bet to 40. Remaining stack: 1000.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
# [FoldBot] folds. Remaining stack: 1000.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 100. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=960
#     AggroBot: State=ACTIVE, Pot=40, Stack=960
#     FoldBot: State=FOLDED, Pot=20, Stack=980
#
# ---------------------------- Hand: 1 | Street: FLOP ----------------------------
#
# Community cards: ['Kh', 'Qs', '9d']
# Current pot size: 100. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 140. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 180. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=920
#     AggroBot: State=ACTIVE, Pot=80, Stack=920
#     FoldBot: State=FOLDED, Pot=20, Stack=980
#
# ---------------------------- Hand: 1 | Street: TURN ----------------------------
#
# Community cards: ['Kh', 'Qs', '9d', '5h']
# Current pot size: 180. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 220. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 260. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=880
#     AggroBot: State=ACTIVE, Pot=120, Stack=880
#     FoldBot: State=FOLDED, Pot=20, Stack=980
#
# --------------------------- Hand: 1 | Street: RIVER ----------------------------
#
# Community cards: ['Kh', 'Qs', '9d', '5h', 'Jh']
# Current pot size: 260. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 300. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 340. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=840
#     AggroBot: State=ACTIVE, Pot=160, Stack=840
#     FoldBot: State=FOLDED, Pot=20, Stack=980
#
# ------------------------------ Hand: 1 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['Ah', '7c']. Best hand: ['Ah', 'Kh', 'Qs', '9d', 'Jh'] (HIGH_CARD). Hand score: 100.1413121109.
# AggroBot reveals: ['Ks', '9s']. Best hand: ['Ks', '9s', 'Kh', 'Qs', '9d'] (TWO_PAIR). Hand score: 313.09119999999996.
# AggroBot wins 340.
#
# Player stacks after showdown:
#     CallBot: 840
#     AggroBot: 1180
#     FoldBot: 980
#
# ==================================== Hand 2 ====================================
#
# AggroBot is on the button.
# FoldBot is the small blind.
# CallBot is the big blind.
# AggroBot is under the gun.
#
# Player stacks at the beginning of hand 2:
#     CallBot: 840
#     AggroBot: 1180
#     FoldBot: 980
#
# -------------------------- Hand: 2 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [AggroBot] raises bet to 40. Remaining stack: 1000.
# Current pot size: 70. Current bet: 40. Minimum raise size: 20.
# [FoldBot] folds. Remaining stack: 1000.
# Current pot size: 70. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 90. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=800
#     AggroBot: State=ACTIVE, Pot=40, Stack=1140
#     FoldBot: State=FOLDED, Pot=10, Stack=970
#
# ---------------------------- Hand: 2 | Street: FLOP ----------------------------
#
# Community cards: ['8c', 'Th', '9h']
# Current pot size: 90. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 90. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 130. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 170. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=760
#     AggroBot: State=ACTIVE, Pot=80, Stack=1100
#     FoldBot: State=FOLDED, Pot=10, Stack=970
#
# ---------------------------- Hand: 2 | Street: TURN ----------------------------
#
# Community cards: ['8c', 'Th', '9h', '8s']
# Current pot size: 170. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 170. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 210. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 250. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=720
#     AggroBot: State=ACTIVE, Pot=120, Stack=1060
#     FoldBot: State=FOLDED, Pot=10, Stack=970
#
# --------------------------- Hand: 2 | Street: RIVER ----------------------------
#
# Community cards: ['8c', 'Th', '9h', '8s', 'As']
# Current pot size: 250. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 250. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 290. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 330. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=680
#     AggroBot: State=ACTIVE, Pot=160, Stack=1020
#     FoldBot: State=FOLDED, Pot=10, Stack=970
#
# ------------------------------ Hand: 2 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['2h', 'Js']. Best hand: ['Js', '8c', 'Th', '8s', 'As'] (PAIR). Hand score: 208.14111.
# AggroBot reveals: ['5d', '6d']. Best hand: ['8c', 'Th', '9h', '8s', 'As'] (PAIR). Hand score: 208.141009.
# CallBot wins 330.
#
# Player stacks after showdown:
#     CallBot: 1010
#     AggroBot: 1020
#     FoldBot: 970
#
# ==================================== Hand 3 ====================================
#
# FoldBot is on the button.
# CallBot is the small blind.
# AggroBot is the big blind.
# FoldBot is under the gun.
#
# Player stacks at the beginning of hand 3:
#     CallBot: 1010
#     AggroBot: 1020
#     FoldBot: 970
#
# -------------------------- Hand: 3 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [FoldBot] folds. Remaining stack: 1000.
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 40. Current bet: 20. Minimum raise size: 20.
# [AggroBot] raises bet to 40. Remaining stack: 1000.
# Current pot size: 60. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=970
#     AggroBot: State=ACTIVE, Pot=40, Stack=980
#     FoldBot: State=FOLDED, Pot=0, Stack=970
#
# ---------------------------- Hand: 3 | Street: FLOP ----------------------------
#
# Community cards: ['Tc', 'Td', 'Jc']
# Current pot size: 80. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 80. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 120. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 160. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=930
#     AggroBot: State=ACTIVE, Pot=80, Stack=940
#     FoldBot: State=FOLDED, Pot=0, Stack=970
#
# ---------------------------- Hand: 3 | Street: TURN ----------------------------
#
# Community cards: ['Tc', 'Td', 'Jc', '5h']
# Current pot size: 160. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 160. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 200. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 240. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=890
#     AggroBot: State=ACTIVE, Pot=120, Stack=900
#     FoldBot: State=FOLDED, Pot=0, Stack=970
#
# --------------------------- Hand: 3 | Street: RIVER ----------------------------
#
# Community cards: ['Tc', 'Td', 'Jc', '5h', '7s']
# Current pot size: 240. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 240. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 280. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 320. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=850
#     AggroBot: State=ACTIVE, Pot=160, Stack=860
#     FoldBot: State=FOLDED, Pot=0, Stack=970
#
# ------------------------------ Hand: 3 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['Qc', '8h']. Best hand: ['Qc', '8h', 'Tc', 'Td', 'Jc'] (PAIR). Hand score: 210.121108.
# AggroBot reveals: ['Qd', '2d']. Best hand: ['Qd', 'Tc', 'Td', 'Jc', '7s'] (PAIR). Hand score: 210.121107.
# CallBot wins 320.
#
# Player stacks after showdown:
#     CallBot: 1170
#     AggroBot: 860
#     FoldBot: 970
#
# ==================================== Hand 4 ====================================
#
# CallBot is on the button.
# AggroBot is the small blind.
# FoldBot is the big blind.
# CallBot is under the gun.
#
# Player stacks at the beginning of hand 4:
#     CallBot: 1170
#     AggroBot: 860
#     FoldBot: 970
#
# -------------------------- Hand: 4 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 50. Current bet: 20. Minimum raise size: 20.
# [AggroBot] raises bet to 40. Remaining stack: 1000.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
# [FoldBot] folds. Remaining stack: 1000.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 100. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=1130
#     AggroBot: State=ACTIVE, Pot=40, Stack=820
#     FoldBot: State=FOLDED, Pot=20, Stack=950
#
# ---------------------------- Hand: 4 | Street: FLOP ----------------------------
#
# Community cards: ['Qc', 'Qd', '6s']
# Current pot size: 100. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 140. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 180. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=1090
#     AggroBot: State=ACTIVE, Pot=80, Stack=780
#     FoldBot: State=FOLDED, Pot=20, Stack=950
#
# ---------------------------- Hand: 4 | Street: TURN ----------------------------
#
# Community cards: ['Qc', 'Qd', '6s', 'As']
# Current pot size: 180. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 220. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 260. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=1050
#     AggroBot: State=ACTIVE, Pot=120, Stack=740
#     FoldBot: State=FOLDED, Pot=20, Stack=950
#
# --------------------------- Hand: 4 | Street: RIVER ----------------------------
#
# Community cards: ['Qc', 'Qd', '6s', 'As', '5h']
# Current pot size: 260. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 300. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 340. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=1010
#     AggroBot: State=ACTIVE, Pot=160, Stack=700
#     FoldBot: State=FOLDED, Pot=20, Stack=950
#
# ------------------------------ Hand: 4 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['8d', '4c']. Best hand: ['8d', 'Qc', 'Qd', '6s', 'As'] (PAIR). Hand score: 212.140806.
# AggroBot reveals: ['6d', '5c']. Best hand: ['6d', 'Qc', 'Qd', '6s', 'As'] (TWO_PAIR). Hand score: 312.0614.
# AggroBot wins 340.
#
# Player stacks after showdown:
#     CallBot: 1010
#     AggroBot: 1040
#     FoldBot: 950
#
# ==================================== Hand 5 ====================================
#
# AggroBot is on the button.
# FoldBot is the small blind.
# CallBot is the big blind.
# AggroBot is under the gun.
#
# Player stacks at the beginning of hand 5:
#     CallBot: 1010
#     AggroBot: 1040
#     FoldBot: 950
#
# -------------------------- Hand: 5 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [AggroBot] raises bet to 40. Remaining stack: 1000.
# Current pot size: 70. Current bet: 40. Minimum raise size: 20.
# [FoldBot] folds. Remaining stack: 1000.
# Current pot size: 70. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 90. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=970
#     AggroBot: State=ACTIVE, Pot=40, Stack=1000
#     FoldBot: State=FOLDED, Pot=10, Stack=940
#
# ---------------------------- Hand: 5 | Street: FLOP ----------------------------
#
# Community cards: ['8s', 'Kh', '6h']
# Current pot size: 90. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 90. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 130. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 170. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=930
#     AggroBot: State=ACTIVE, Pot=80, Stack=960
#     FoldBot: State=FOLDED, Pot=10, Stack=940
#
# ---------------------------- Hand: 5 | Street: TURN ----------------------------
#
# Community cards: ['8s', 'Kh', '6h', 'Ad']
# Current pot size: 170. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 170. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 210. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 250. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=890
#     AggroBot: State=ACTIVE, Pot=120, Stack=920
#     FoldBot: State=FOLDED, Pot=10, Stack=940
#
# --------------------------- Hand: 5 | Street: RIVER ----------------------------
#
# Community cards: ['8s', 'Kh', '6h', 'Ad', '6c']
# Current pot size: 250. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 250. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 290. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 330. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=850
#     AggroBot: State=ACTIVE, Pot=160, Stack=880
#     FoldBot: State=FOLDED, Pot=10, Stack=940
#
# ------------------------------ Hand: 5 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['Ks', '7d']. Best hand: ['Ks', 'Kh', '6h', 'Ad', '6c'] (TWO_PAIR). Hand score: 313.0614.
# AggroBot reveals: ['Qs', 'Jh']. Best hand: ['Qs', 'Kh', '6h', 'Ad', '6c'] (PAIR). Hand score: 206.141312.
# CallBot wins 330.
#
# Player stacks after showdown:
#     CallBot: 1180
#     AggroBot: 880
#     FoldBot: 940
#
# ==================================== Hand 6 ====================================
#
# FoldBot is on the button.
# CallBot is the small blind.
# AggroBot is the big blind.
# FoldBot is under the gun.
#
# Player stacks at the beginning of hand 6:
#     CallBot: 1180
#     AggroBot: 880
#     FoldBot: 940
#
# -------------------------- Hand: 6 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [FoldBot] folds. Remaining stack: 1000.
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 40. Current bet: 20. Minimum raise size: 20.
# [AggroBot] raises bet to 40. Remaining stack: 1000.
# Current pot size: 60. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=1140
#     AggroBot: State=ACTIVE, Pot=40, Stack=840
#     FoldBot: State=FOLDED, Pot=0, Stack=940
#
# ---------------------------- Hand: 6 | Street: FLOP ----------------------------
#
# Community cards: ['Tc', 'Kc', '8c']
# Current pot size: 80. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 80. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 120. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 160. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=1100
#     AggroBot: State=ACTIVE, Pot=80, Stack=800
#     FoldBot: State=FOLDED, Pot=0, Stack=940
#
# ---------------------------- Hand: 6 | Street: TURN ----------------------------
#
# Community cards: ['Tc', 'Kc', '8c', '7s']
# Current pot size: 160. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 160. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 200. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 240. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=1060
#     AggroBot: State=ACTIVE, Pot=120, Stack=760
#     FoldBot: State=FOLDED, Pot=0, Stack=940
#
# --------------------------- Hand: 6 | Street: RIVER ----------------------------
#
# Community cards: ['Tc', 'Kc', '8c', '7s', '9d']
# Current pot size: 240. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 240. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 280. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 320. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=1020
#     AggroBot: State=ACTIVE, Pot=160, Stack=720
#     FoldBot: State=FOLDED, Pot=0, Stack=940
#
# ------------------------------ Hand: 6 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['Jc', '7d']. Best hand: ['Jc', '7d', 'Tc', '8c', '9d'] (STRAIGHT). Hand score: 500.11.
# AggroBot reveals: ['6s', '5s']. Best hand: ['6s', 'Tc', '8c', '7s', '9d'] (STRAIGHT). Hand score: 500.1.
# CallBot wins 320.
#
# Player stacks after showdown:
#     CallBot: 1340
#     AggroBot: 720
#     FoldBot: 940
#
# ==================================== Hand 7 ====================================
#
# CallBot is on the button.
# AggroBot is the small blind.
# FoldBot is the big blind.
# CallBot is under the gun.
#
# Player stacks at the beginning of hand 7:
#     CallBot: 1340
#     AggroBot: 720
#     FoldBot: 940
#
# -------------------------- Hand: 7 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 50. Current bet: 20. Minimum raise size: 20.
# [AggroBot] raises bet to 40. Remaining stack: 1000.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
# [FoldBot] folds. Remaining stack: 1000.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 100. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=1300
#     AggroBot: State=ACTIVE, Pot=40, Stack=680
#     FoldBot: State=FOLDED, Pot=20, Stack=920
#
# ---------------------------- Hand: 7 | Street: FLOP ----------------------------
#
# Community cards: ['Js', '6s', 'Qh']
# Current pot size: 100. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 140. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 180. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=1260
#     AggroBot: State=ACTIVE, Pot=80, Stack=640
#     FoldBot: State=FOLDED, Pot=20, Stack=920
#
# ---------------------------- Hand: 7 | Street: TURN ----------------------------
#
# Community cards: ['Js', '6s', 'Qh', '3s']
# Current pot size: 180. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 220. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 260. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=1220
#     AggroBot: State=ACTIVE, Pot=120, Stack=600
#     FoldBot: State=FOLDED, Pot=20, Stack=920
#
# --------------------------- Hand: 7 | Street: RIVER ----------------------------
#
# Community cards: ['Js', '6s', 'Qh', '3s', 'Ts']
# Current pot size: 260. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 300. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 340. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=1180
#     AggroBot: State=ACTIVE, Pot=160, Stack=560
#     FoldBot: State=FOLDED, Pot=20, Stack=920
#
# ------------------------------ Hand: 7 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['Kc', '7c']. Best hand: ['Kc', '7c', 'Js', 'Qh', 'Ts'] (HIGH_CARD). Hand score: 100.1312111007.
# AggroBot reveals: ['Jh', 'Td']. Best hand: ['Jh', 'Td', 'Js', 'Qh', 'Ts'] (TWO_PAIR). Hand score: 311.1012.
# AggroBot wins 340.
#
# Player stacks after showdown:
#     CallBot: 1180
#     AggroBot: 900
#     FoldBot: 920
#
# ==================================== Hand 8 ====================================
#
# AggroBot is on the button.
# FoldBot is the small blind.
# CallBot is the big blind.
# AggroBot is under the gun.
#
# Player stacks at the beginning of hand 8:
#     CallBot: 1180
#     AggroBot: 900
#     FoldBot: 920
#
# -------------------------- Hand: 8 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [AggroBot] raises bet to 40. Remaining stack: 1000.
# Current pot size: 70. Current bet: 40. Minimum raise size: 20.
# [FoldBot] folds. Remaining stack: 1000.
# Current pot size: 70. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 90. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=1140
#     AggroBot: State=ACTIVE, Pot=40, Stack=860
#     FoldBot: State=FOLDED, Pot=10, Stack=910
#
# ---------------------------- Hand: 8 | Street: FLOP ----------------------------
#
# Community cards: ['7h', '4s', '4h']
# Current pot size: 90. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 90. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 130. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 170. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=1100
#     AggroBot: State=ACTIVE, Pot=80, Stack=820
#     FoldBot: State=FOLDED, Pot=10, Stack=910
#
# ---------------------------- Hand: 8 | Street: TURN ----------------------------
#
# Community cards: ['7h', '4s', '4h', '9c']
# Current pot size: 170. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 170. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 210. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 250. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=1060
#     AggroBot: State=ACTIVE, Pot=120, Stack=780
#     FoldBot: State=FOLDED, Pot=10, Stack=910
#
# --------------------------- Hand: 8 | Street: RIVER ----------------------------
#
# Community cards: ['7h', '4s', '4h', '9c', 'Kc']
# Current pot size: 250. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 250. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 290. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 330. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=1020
#     AggroBot: State=ACTIVE, Pot=160, Stack=740
#     FoldBot: State=FOLDED, Pot=10, Stack=910
#
# ------------------------------ Hand: 8 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['Ah', '8s']. Best hand: ['Ah', '4s', '4h', '9c', 'Kc'] (PAIR). Hand score: 204.141309.
# AggroBot reveals: ['3d', 'Ac']. Best hand: ['Ac', '4s', '4h', '9c', 'Kc'] (PAIR). Hand score: 204.141309.
# CallBot wins 165.
# AggroBot wins 165.
#
# Player stacks after showdown:
#     CallBot: 1185
#     AggroBot: 905
#     FoldBot: 910
#
# ==================================== Hand 9 ====================================
#
# FoldBot is on the button.
# CallBot is the small blind.
# AggroBot is the big blind.
# FoldBot is under the gun.
#
# Player stacks at the beginning of hand 9:
#     CallBot: 1185
#     AggroBot: 905
#     FoldBot: 910
#
# -------------------------- Hand: 9 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [FoldBot] folds. Remaining stack: 1000.
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 40. Current bet: 20. Minimum raise size: 20.
# [AggroBot] raises bet to 40. Remaining stack: 1000.
# Current pot size: 60. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=1145
#     AggroBot: State=ACTIVE, Pot=40, Stack=865
#     FoldBot: State=FOLDED, Pot=0, Stack=910
#
# ---------------------------- Hand: 9 | Street: FLOP ----------------------------
#
# Community cards: ['2s', '3h', 'Jd']
# Current pot size: 80. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 80. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 120. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 160. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=1105
#     AggroBot: State=ACTIVE, Pot=80, Stack=825
#     FoldBot: State=FOLDED, Pot=0, Stack=910
#
# ---------------------------- Hand: 9 | Street: TURN ----------------------------
#
# Community cards: ['2s', '3h', 'Jd', 'Tc']
# Current pot size: 160. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 160. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 200. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 240. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=1065
#     AggroBot: State=ACTIVE, Pot=120, Stack=785
#     FoldBot: State=FOLDED, Pot=0, Stack=910
#
# --------------------------- Hand: 9 | Street: RIVER ----------------------------
#
# Community cards: ['2s', '3h', 'Jd', 'Tc', '8h']
# Current pot size: 240. Current bet: 0. Minimum raise size: 0.
#
# [CallBot] checks. Remaining stack: 1000.
# Current pot size: 240. Current bet: 0. Minimum raise size: 0.
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 280. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 320. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=1025
#     AggroBot: State=ACTIVE, Pot=160, Stack=745
#     FoldBot: State=FOLDED, Pot=0, Stack=910
#
# ------------------------------ Hand: 9 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['2d', 'Qc']. Best hand: ['2d', 'Qc', '2s', 'Jd', 'Tc'] (PAIR). Hand score: 202.12111.
# AggroBot reveals: ['Kc', '6d']. Best hand: ['Kc', '6d', 'Jd', 'Tc', '8h'] (HIGH_CARD). Hand score: 100.1311100806.
# CallBot wins 320.
#
# Player stacks after showdown:
#     CallBot: 1345
#     AggroBot: 745
#     FoldBot: 910
#
# =================================== Hand 10 ====================================
#
# CallBot is on the button.
# AggroBot is the small blind.
# FoldBot is the big blind.
# CallBot is under the gun.
#
# Player stacks at the beginning of hand 10:
#     CallBot: 1345
#     AggroBot: 745
#     FoldBot: 910
#
# ------------------------- Hand: 10 | Street: PRE_FLOP --------------------------
#
# Community cards: None
# Current pot size: 30. Current bet: 20. Minimum raise size: 20.
#
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 50. Current bet: 20. Minimum raise size: 20.
# [AggroBot] raises bet to 40. Remaining stack: 1000.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
# [FoldBot] folds. Remaining stack: 1000.
# Current pot size: 80. Current bet: 40. Minimum raise size: 20.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 100. Current bet: 40. Minimum raise size: 20.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=40, Stack=1305
#     AggroBot: State=ACTIVE, Pot=40, Stack=705
#     FoldBot: State=FOLDED, Pot=20, Stack=890
#
# --------------------------- Hand: 10 | Street: FLOP ----------------------------
#
# Community cards: ['8c', 'Ks', 'Qc']
# Current pot size: 100. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 140. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 180. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=80, Stack=1265
#     AggroBot: State=ACTIVE, Pot=80, Stack=665
#     FoldBot: State=FOLDED, Pot=20, Stack=890
#
# --------------------------- Hand: 10 | Street: TURN ----------------------------
#
# Community cards: ['8c', 'Ks', 'Qc', '7h']
# Current pot size: 180. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 220. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 260. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=120, Stack=1225
#     AggroBot: State=ACTIVE, Pot=120, Stack=625
#     FoldBot: State=FOLDED, Pot=20, Stack=890
#
# --------------------------- Hand: 10 | Street: RIVER ---------------------------
#
# Community cards: ['8c', 'Ks', 'Qc', '7h', '4d']
# Current pot size: 260. Current bet: 0. Minimum raise size: 0.
#
# [AggroBot] bets 40. Remaining stack: 1000.
# Current pot size: 300. Current bet: 40. Minimum raise size: 40.
# [CallBot] calls. Remaining stack: 1000.
# Current pot size: 340. Current bet: 40. Minimum raise size: 40.
#
# Player standings after the betting round:
#     CallBot: State=ACTIVE, Pot=160, Stack=1185
#     AggroBot: State=ACTIVE, Pot=160, Stack=585
#     FoldBot: State=FOLDED, Pot=20, Stack=890
#
# ----------------------------- Hand: 10 | SHOWDOWN ------------------------------
#
# CallBot reveals: ['Ts', '3s']. Best hand: ['Ts', '8c', 'Ks', 'Qc', '7h'] (HIGH_CARD). Hand score: 100.1312100807.
# AggroBot reveals: ['Js', 'Kd']. Best hand: ['Js', 'Kd', '8c', 'Ks', 'Qc'] (PAIR). Hand score: 213.121108.
# AggroBot wins 340.
#
# Player stacks after showdown:
#     CallBot: 1185
#     AggroBot: 925
#     FoldBot: 890

# %% [markdown]
# You can also turn the events into a Pandas DataFrame, using the `event_dump` attribute of the instance.

# %%
import pandas as pd
from maverick import Street, GameEventType, GameStage

df = pd.DataFrame(game_transcriber.event_dump)
df["street"] = pd.to_numeric(df["street"], errors="coerce").astype("UInt8")
df["stage"] = pd.to_numeric(df["stage"], errors="coerce").astype("UInt8")
df["hand_number"] = pd.to_numeric(df["hand_number"], errors="coerce").astype("UInt8")
df.rename(
    columns={
        "type": "event_type_value",
        "stage": "stage_value",
        "street": "street_value",
        "ts": "event_ts",
        "uid": "event_uid",
    },
    inplace=True,
)

# Map enum values to names for better readability
street_map = {s.value: s.name for s in Street}
df["street_name"] = df["street_value"].map(street_map)

# Map enum values to names for better readability
event_type_map = {e.value: e.name for e in GameEventType}
df["event_type_name"] = df["event_type_value"].map(event_type_map)

# Map enum values to names for better readability
game_stage_map = {s.value: s.name for s in GameStage}
df["game_stage_name"] = df["stage_value"].map(game_stage_map)

# Add a unique game_uid to group events from the same game together
df["game_uid"] = game.game_uid

df.head()
# Out:
#                           event_uid      event_ts  event_type_value  \
# 0  54741dd761d04ae0a36c5b7f8edcbd9a  1.774709e+09                21
# 1  3a63fecbbbbb422e94a9dd446abcb128  1.774709e+09                21
# 2  4c3ca229477f46e0a335777f8a0bace7  1.774709e+09                 1
# 3  3f9a707cecc64054b13f928393dab85b  1.774709e+09                21
# 4  29b80d8dec964979a3a02d5077513575  1.774709e+09                21
#
#    hand_number  street_value  stage_value player_uid action  \
# 0            0          <NA>            2       None   None
# 1            0          <NA>            3       None   None
# 2            0          <NA>            3       None   None
# 3            1          <NA>            3       None   None
# 4            1          <NA>            3       None   None
#
#                                              payload street_name  \
# 0  {'before': {'uid': 'cc27cf5696d3497ca6f1e95cc7...         NaN
# 1  {'before': {'uid': 'cc27cf5696d3497ca6f1e95cc7...         NaN
# 2                                                 {}         NaN
# 3  {'before': {'uid': 'cc27cf5696d3497ca6f1e95cc7...         NaN
# 4  {'before': {'uid': 'cc27cf5696d3497ca6f1e95cc7...         NaN
#
#       event_type_name game_stage_name                          game_uid
# 0  GAME_STATE_CHANGED           READY  b8fa4c6ff597427e84b2361354758545
# 1  GAME_STATE_CHANGED         STARTED  b8fa4c6ff597427e84b2361354758545
# 2        GAME_STARTED         STARTED  b8fa4c6ff597427e84b2361354758545
# 3  GAME_STATE_CHANGED         STARTED  b8fa4c6ff597427e84b2361354758545
# 4  GAME_STATE_CHANGED         STARTED  b8fa4c6ff597427e84b2361354758545
