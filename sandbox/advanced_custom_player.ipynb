# %% [markdown]
# # Create and Advanced Custom Player
#
# All the imports are centralized in the cell below.

# %%
from maverick import (
    Game,
    Player,
    ActionType,
    GameState,
    PlayerLike,
    Street,
    HandType,
    PlayerAction,
)
from maverick.players import FoldBot
from maverick.utils import estimate_strongest_hand, score_hand
import logging
import sys

# %% [markdown]
# ## Custom Players

# %%
class AggressiveBot(Player):
    """An aggressive bot that frequently bets and raises."""

    def decide_action(
        self,
        game_state: GameState,
        valid_actions: list[ActionType],
        min_raise: int
    ) -> PlayerAction:
        """Bet or raise aggressively."""
        # Try to raise if possible
        if ActionType.RAISE in valid_actions:
            raise_amount = min_raise
            if raise_amount <= self.stack:
                return PlayerAction(player_id=self.id, action_type=ActionType.RAISE, raise_amount=raise_amount)

        # Otherwise bet if possible
        if ActionType.BET in valid_actions:
            bet_amount = game_state.big_blind * 2
            if bet_amount <= self.stack:
                return PlayerAction(player_id=self.id, action_type=ActionType.BET, bet_amount=bet_amount)

        # Call if we can't bet/raise
        if ActionType.CALL in valid_actions:
            call_amount = game_state.current_bet - self.current_bet
            if call_amount <= self.stack:
                return PlayerAction(player_id=self.id, action_type=ActionType.CALL, call_amount=call_amount)

        # Check if possible
        if ActionType.CHECK in valid_actions:
            return PlayerAction(player_id=self.id, action_type=ActionType.CHECK, check_amount=0)
        
        # Otherwise fold
        return PlayerAction(player_id=self.id, action_type=ActionType.FOLD, fold_amount=0)

# %%
class ComplexPlayer(Player):
    """A custom player with a complex strategy."""

    def decide_action(
        self,
        game_state: GameState,
        valid_actions: list[ActionType],
        min_raise: int
    ) -> PlayerAction:
        print(f"\n{self.name} is requested to take action.")
        
        # Information related to the game state
        print("     Current street:", game_state.street)
        print("     Current pot:", game_state.pot)
        print("     Small blind:", game_state.small_blind)
        print("     Big blind:", game_state.big_blind)
        print("     Community cards:", game_state.community_cards)
        
        # Information related to the player
        print("     Player stack:", self.stack)
        print("     Current player bet:", self.current_bet)
        print("     Private cards:", self.holding.cards)
        
        # Information related to the available actions
        print("     Valid actions:", valid_actions)
        print("     Minimum raise:", min_raise)
        
        # Private and community cards
        private_cards = self.holding.cards
        community_cards = game_state.community_cards
        print("     Private cards:", private_cards)
        print("     Community cards:", community_cards)
        
        # Estimate the strongest possible hand of the player, considering
        # all community cards.
        strongest_hand, strongest_hand_prob = estimate_strongest_hand(
            private_cards,
            community_cards,
            n_min_private=0,
            n_simulations=1000,
            n_players=len(game_state.get_players_in_hand())
        )
        strongest_hand_type, strongest_hand_score = score_hand(strongest_hand)
        print("     Strongest hand:", strongest_hand)
        print("     Strongest hand type:", strongest_hand_type.name)
        print("     Strongest hand score:", strongest_hand_score)
        print("     Estimated strength:", strongest_hand_prob)
        
        # This is the players strategy
        match game_state.street:
            case Street.PRE_FLOP:
                if strongest_hand_prob < 0.2:
                    # This is the time to bluff if you want to
                    print("     Player decides to FOLD.\n")
                    return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)
                elif strongest_hand_prob > 0.4 and strongest_hand_type >= HandType.PAIR:
                    if ActionType.BET in valid_actions:
                        bet_amount = max(game_state.big_blind * 4, min_raise)
                        print(f"     Player decides to BET {bet_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.BET, amount=bet_amount)
                    elif ActionType.RAISE in valid_actions:
                        raise_amount = max(game_state.big_blind * 4, min_raise)
                        print(f"     Player decides to RAISE {raise_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.RAISE, amount=raise_amount)
                    elif ActionType.CALL in valid_actions:
                        call_amount = max(game_state.current_bet - self.current_bet, self.stack)
                        print(f"     Player decides to CALL {call_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CALL, amount=call_amount)
                    elif ActionType.CHECK in valid_actions:
                        print("     Player decides to CHECK.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                    else:
                        print("     Player decides to ALL IN.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.ALL_IN, amount=self.stack)           
                else:
                    if ActionType.CHECK in valid_actions:
                        print("     Player decides to CHECK.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                    else:
                        print("     Player decides to FOLD.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)
            
            case Street.FLOP:
                if strongest_hand_type in [
                    HandType.ROYAL_FLUSH, 
                    HandType.STRAIGHT_FLUSH, 
                    HandType.FOUR_OF_A_KIND, 
                    HandType.FULL_HOUSE
                ]:
                    if ActionType.CHECK in valid_actions:
                        print("     Player decides to CHECK.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                    assert ActionType.CALL in valid_actions
                    call_amount = max(game_state.current_bet - self.current_bet, self.stack)
                    print(f"     Player decides to CALL {call_amount}.\n")
                    return PlayerAction(player_id=self.id, action_type=ActionType.CALL, amount=call_amount)
                else:
                    if strongest_hand_prob < 0.3:
                        print("     Player decides to FOLD.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)
                    elif strongest_hand_prob > 0.6:
                        if ActionType.RAISE in valid_actions:
                            raise_amount = max(game_state.big_blind * 3, min_raise)
                            print(f"     Player decides to RAISE {raise_amount}.\n")
                            return PlayerAction(player_id=self.id, action_type=ActionType.RAISE, amount=raise_amount)
                        elif ActionType.CALL in valid_actions:
                            call_amount = max(game_state.current_bet - self.current_bet, self.stack)
                            print(f"     Player decides to CALL {call_amount}.\n")
                            return PlayerAction(player_id=self.id, action_type=ActionType.CALL, amount=call_amount)
                    else:
                        if ActionType.CHECK in valid_actions:
                            print("     Player decides to CHECK.\n")
                            return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                        else:
                            print("     Player decides to FOLD.\n")
                            return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)
                        
            case Street.TURN:
                to_call = max(0, game_state.current_bet - self.current_bet)

                # Very strong made hands: play safely (slowplay), but don't fold.
                if strongest_hand_type in [
                    HandType.ROYAL_FLUSH,
                    HandType.STRAIGHT_FLUSH,
                    HandType.FOUR_OF_A_KIND,
                    HandType.FULL_HOUSE,
                ]:
                    if ActionType.CHECK in valid_actions:
                        print("     Player decides to CHECK.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                    if ActionType.CALL in valid_actions:
                        call_amount = min(to_call, self.stack)
                        print(f"     Player decides to CALL {call_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CALL, amount=call_amount)
                # Weak: avoid putting more money in.
                if strongest_hand_prob < 0.25:
                    if ActionType.CHECK in valid_actions:
                        print("     Player decides to CHECK.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                    print("     Player decides to FOLD.\n")
                    return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)

                # Strong: value bet / raise.
                if strongest_hand_prob > 0.65:
                    if ActionType.BET in valid_actions:
                        bet_amount = min(self.stack, max(game_state.big_blind * 3, min_raise))
                        print(f"     Player decides to BET {bet_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.BET, amount=bet_amount)
                    if ActionType.RAISE in valid_actions:
                        raise_amount = min(self.stack, max(game_state.big_blind * 3, min_raise))
                        print(f"     Player decides to RAISE {raise_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.RAISE, amount=raise_amount)
                    if ActionType.CALL in valid_actions:
                        call_amount = min(to_call, self.stack)
                        print(f"     Player decides to CALL {call_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CALL, amount=call_amount)
                # Medium: prefer checking, otherwise call small commitments.
                if ActionType.CHECK in valid_actions:
                    print("     Player decides to CHECK.\n")
                    return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                if ActionType.CALL in valid_actions:
                    call_amount = min(to_call, self.stack)
                    print(f"     Player decides to CALL {call_amount}.\n")
                    return PlayerAction(player_id=self.id, action_type=ActionType.CALL, amount=call_amount)
                print("     Player decides to FOLD.\n")
                return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)

            case Street.RIVER:
                to_call = max(0, game_state.current_bet - self.current_bet)

                # On the river, be even more conservative with weak hands.
                if strongest_hand_prob < 0.35:
                    if ActionType.CHECK in valid_actions:
                        print("     Player decides to CHECK.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                    print("     Player decides to FOLD.\n")
                    return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)

                # Value bet thin only when strong.
                if strongest_hand_prob > 0.75:
                    if ActionType.BET in valid_actions:
                        bet_amount = min(self.stack, max(game_state.big_blind * 3, min_raise))
                        print(f"     Player decides to BET {bet_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.BET, amount=bet_amount)
                    if ActionType.RAISE in valid_actions:
                        raise_amount = min(self.stack, max(game_state.big_blind * 3, min_raise))
                        print(f"     Player decides to RAISE {raise_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.RAISE, amount=raise_amount)
                    if ActionType.CALL in valid_actions:
                        call_amount = min(to_call, self.stack)
                        print(f"     Player decides to CALL {call_amount}.\n")
                        return PlayerAction(player_id=self.id, action_type=ActionType.CALL, amount=call_amount)
                # Medium strength: check if possible, otherwise call.
                if ActionType.CHECK in valid_actions:
                    print("     Player decides to CHECK.\n")
                    return PlayerAction(player_id=self.id, action_type=ActionType.CHECK)
                if ActionType.CALL in valid_actions:
                    call_amount = min(to_call, self.stack)
                    print(f"     Player decides to CALL {call_amount}.\n")
                    return PlayerAction(player_id=self.id, action_type=ActionType.CALL, amount=call_amount)
                print("     Player decides to FOLD.\n")
                return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)

        # Make sure to always return a valid action. Folding is always available.
        print("     Player decides to FOLD.\n")
        sys.stdout.flush()  # Ensure all prints are output before returning
        return PlayerAction(player_id=self.id, action_type=ActionType.FOLD)

# %%
# Configure logging such that we only get the log messages of the game
logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s [%(levelname)s] %(name)s: %(message)s",
)
logging.getLogger().setLevel(logging.WARNING)  # Set root logger to WARNING
logging.getLogger("maverick").setLevel(logging.DEBUG)  # Only maverick logs at DEBUG

# Redirect maverick logs to stdout, so they appear in the correct event order
handler = logging.StreamHandler(sys.stdout)
logging.getLogger("maverick").handlers = [handler]
logging.getLogger("maverick").propagate = False

# Create game with blinds
game = Game(small_blind=10, big_blind=20, max_hands=40)

# Create and add players with different strategies
players: list[PlayerLike] = [
    ComplexPlayer(id="p1", name="ComplexPlayer", stack=1000, seat=0),
    FoldBot(id="p2", name="FoldBot", stack=1000, seat=1),
    AggressiveBot(id="p3", name="AggressiveBot", stack=1000, seat=2),
]

for player in players:
    game.add_player(player)
    
game.start()
# Out:
# Player ComplexPlayer joined the game.
# Player FoldBot joined the game.
# Player AggressiveBot joined the game.
# Game started.
#
# ============================== Hand 1 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 990
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 980
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1000
#      Current player bet: 0
#      Private cards: [9♦, 5♥]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [9♦, 5♥]
#      Community cards: []
#      Strongest hand: [9♦, 5♥]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.0905
#      Estimated strength: 0.302
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 2 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 1000
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 980
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player ComplexPlayer wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 3 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 1000
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 970
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1000
#      Current player bet: 10
#      Private cards: [8♣, 5♠]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [8♣, 5♠]
#      Community cards: []
#      Strongest hand: [8♣, 5♠]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.0805
#      Estimated strength: 0.401
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player FoldBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 4 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 990
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 980
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1000
#      Current player bet: 0
#      Private cards: [6♣, 7♥]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [6♣, 7♥]
#      Community cards: []
# /Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py:391: UserWarning: Player AggressiveBot action invalid, folding.
#   warn(f"Player {current_player.name} action invalid, folding.")
#      Strongest hand: [6♣, 7♥]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.0706
#      Estimated strength: 0.262
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 5 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 1000
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 980
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player ComplexPlayer wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 6 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 1000
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 970
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1000
#      Current player bet: 10
#      Private cards: [A♦, 2♦]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [A♦, 2♦]
#      Community cards: []
#      Strongest hand: [A♦, 2♦]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1402
#      Estimated strength: 0.663
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player FoldBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 7 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 990
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 980
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1000
#      Current player bet: 0
#      Private cards: [7♣, 7♠]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [7♣, 7♠]
#      Community cards: []
#      Strongest hand: [7♣, 7♠]
#      Strongest hand type: PAIR
#      Strongest hand score: 207
#      Estimated strength: 0.647
#      Player decides to RAISE 80.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 80. Remaining stack: 920.
# PRE_FLOP | Current pot: 110
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 110
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 100
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 110
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player ComplexPlayer wins 110 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 8 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 970
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 1010
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player ComplexPlayer wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 9 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 1030
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 970
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1030
#      Current player bet: 10
#      Private cards: [4♥, 3♣]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [4♥, 3♣]
#      Community cards: []
#      Strongest hand: [4♥, 3♣]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.0403
#      Estimated strength: 0.293
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player FoldBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 10 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 990
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 950
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1030
#      Current player bet: 0
#      Private cards: [2♥, 8♠]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [2♥, 8♠]
#      Community cards: []
#      Strongest hand: [2♥, 8♠]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.0802
#      Estimated strength: 0.226
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 11 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 970
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 1010
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player ComplexPlayer wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 12 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 1030
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 970
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1030
#      Current player bet: 10
#      Private cards: [2♠, K♥]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [2♠, K♥]
#      Community cards: []
#      Strongest hand: [2♠, K♥]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1302
#      Estimated strength: 0.597
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player FoldBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 13 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 990
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 950
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1030
#      Current player bet: 0
#      Private cards: [4♥, A♠]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [4♥, A♠]
#      Community cards: []
#      Strongest hand: [4♥, A♠]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1404
#      Estimated strength: 0.452
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 14 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 970
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 1010
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player ComplexPlayer wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 15 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 1030
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 970
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1030
#      Current player bet: 10
#      Private cards: [8♥, 10♠]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [8♥, 10♠]
#      Community cards: []
#      Strongest hand: [8♥, 10♠]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1008
#      Estimated strength: 0.526
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player FoldBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 16 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 990
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 950
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1030
#      Current player bet: 0
#      Private cards: [10♣, 5♥]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [10♣, 5♥]
#      Community cards: []
#      Strongest hand: [10♣, 5♥]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1005
#      Estimated strength: 0.277
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 17 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 970
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 1010
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player ComplexPlayer wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 18 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 1030
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 970
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1030
#      Current player bet: 10
#      Private cards: [7♣, Q♦]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [7♣, Q♦]
#      Community cards: []
#      Strongest hand: [7♣, Q♦]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1207
#      Estimated strength: 0.593
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player FoldBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 19 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 990
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 950
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1030
#      Current player bet: 0
#      Private cards: [6♠, 5♣]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [6♠, 5♣]
#      Community cards: []
#      Strongest hand: [6♠, 5♣]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.0605
#      Estimated strength: 0.229
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 20 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 970
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 1010
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player ComplexPlayer wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 21 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 1030
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 970
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1030
#      Current player bet: 10
#      Private cards: [5♠, 7♦]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [5♠, 7♦]
#      Community cards: []
#      Strongest hand: [5♠, 7♦]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.0705
#      Estimated strength: 0.376
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player FoldBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 22 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 990
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 950
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1030
#      Current player bet: 0
#      Private cards: [Q♠, 5♠]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [Q♠, 5♠]
#      Community cards: []
#      Strongest hand: [Q♠, 5♠]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1205
#      Estimated strength: 0.345
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 23 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 970
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 1010
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player ComplexPlayer wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 24 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 1030
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 970
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1030
#      Current player bet: 10
#      Private cards: [5♠, 6♠]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [5♠, 6♠]
#      Community cards: []
#      Strongest hand: [5♠, 6♠]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.0605
#      Estimated strength: 0.356
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player FoldBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 25 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 990
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 950
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1030
#      Current player bet: 0
#      Private cards: [Q♣, A♥]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [Q♣, A♥]
#      Community cards: []
#      Strongest hand: [Q♣, A♥]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1412
#      Estimated strength: 0.562
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 26 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 970
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 1010
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player ComplexPlayer wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 27 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 1030
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 970
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1030
#      Current player bet: 10
#      Private cards: [10♥, 9♥]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [10♥, 9♥]
#      Community cards: []
#      Strongest hand: [10♥, 9♥]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1009
#      Estimated strength: 0.496
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player FoldBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 28 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 990
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 950
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1030
#      Current player bet: 0
#      Private cards: [J♠, 4♣]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [J♠, 4♣]
#      Community cards: []
#      Strongest hand: [J♠, 4♣]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1104
#      Estimated strength: 0.308
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 29 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 970
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 1010
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player ComplexPlayer wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 30 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 1030
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 970
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1030
#      Current player bet: 10
#      Private cards: [4♥, 10♠]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [4♥, 10♠]
#      Community cards: []
#      Strongest hand: [4♥, 10♠]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1004
#      Estimated strength: 0.467
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player FoldBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 31 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 990
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 950
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1030
#      Current player bet: 0
#      Private cards: [6♥, 6♦]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [6♥, 6♦]
#      Community cards: []
#      Strongest hand: [6♥, 6♦]
#      Strongest hand type: PAIR
#      Strongest hand score: 206
#      Estimated strength: 0.652
#      Player decides to RAISE 80.
#
# PRE_FLOP | Player ComplexPlayer raises to amount 80. Remaining stack: 950.
# PRE_FLOP | Current pot: 110
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 110
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 100
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 110
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player ComplexPlayer wins 110 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 32 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 940
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 1040
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player ComplexPlayer wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 33 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 1060
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 970
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1060
#      Current player bet: 10
#      Private cards: [7♦, 4♠]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [7♦, 4♠]
#      Community cards: []
#      Strongest hand: [7♦, 4♠]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.0704
#      Estimated strength: 0.366
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player FoldBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 34 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 990
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 920
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1060
#      Current player bet: 0
#      Private cards: [Q♣, 5♦]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [Q♣, 5♦]
#      Community cards: []
#      Strongest hand: [Q♣, 5♦]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1205
#      Estimated strength: 0.317
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 35 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 940
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 1040
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player ComplexPlayer wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 36 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 1060
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 970
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1060
#      Current player bet: 10
#      Private cards: [4♦, 10♣]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [4♦, 10♣]
#      Community cards: []
#      Strongest hand: [4♦, 10♣]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1004
#      Estimated strength: 0.467
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player FoldBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 37 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 990
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 920
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1060
#      Current player bet: 0
#      Private cards: [3♥, 10♣]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [3♥, 10♣]
#      Community cards: []
#      Strongest hand: [3♥, 10♣]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1003
#      Estimated strength: 0.264
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 38 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: FoldBot
# PRE_FLOP | Posting small blind of 10 by player AggressiveBot. Remaining stack: 940
# PRE_FLOP | Posting big blind of 20 by player ComplexPlayer. Remaining stack: 1040
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player ComplexPlayer wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 39 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: AggressiveBot
# PRE_FLOP | Posting small blind of 10 by player ComplexPlayer. Remaining stack: 1060
# PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 970
# PRE_FLOP | Player AggressiveBot intended to take action: player_id='p3' action_type=<ActionType.RAISE: 5> amount=None.
# PRE_FLOP | Player AggressiveBot action invalid, folding.
# Traceback (most recent call last):
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 379, in _take_action_from_current_player
#     self._register_player_action(current_player, action)
#   File "/Users/baloghbence/Documents/Projects/maverick/src/maverick/game.py", line 537, in _register_player_action
#     raise ValueError(f"Raise must be at least {min_raise}")
# ValueError: Raise must be at least 40
# PRE_FLOP | Player AggressiveBot folds.
# PRE_FLOP | Current pot: 30
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1060
#      Current player bet: 10
#      Private cards: [4♠, Q♣]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [4♠, Q♣]
#      Community cards: []
#      Strongest hand: [4♠, Q♣]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.1204
#      Estimated strength: 0.553
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player FoldBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# ============================== Hand 40 ==============================
#
# PRE_FLOP | Dealing hole cards. Button: ComplexPlayer
# PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 990
# PRE_FLOP | Posting big blind of 20 by player AggressiveBot. Remaining stack: 920
#
# ComplexPlayer is requested to take action.
#      Current street: Street.PRE_FLOP
#      Current pot: 30
#      Small blind: 10
#      Big blind: 20
#      Community cards: []
#      Player stack: 1060
#      Current player bet: 0
#      Private cards: [8♠, 6♦]
#      Valid actions: [<ActionType.FOLD: 1>, <ActionType.CALL: 3>, <ActionType.RAISE: 5>, <ActionType.ALL_IN: 6>]
#      Minimum raise: 40
#      Private cards: [8♠, 6♦]
#      Community cards: []
#      Strongest hand: [8♠, 6♦]
#      Strongest hand type: HIGH_CARD
#      Strongest hand score: 100.0806
#      Estimated strength: 0.284
#      Player decides to FOLD.
#
# PRE_FLOP | Player ComplexPlayer folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Player FoldBot folds.
# PRE_FLOP | Current pot: 30
# PRE_FLOP | Betting round complete
#
# SHOWDOWN | Player AggressiveBot wins 30 from the pot.
# SHOWDOWN | Showdown complete
#
# Hand ended
#
# Reached maximum number of hands, ending game.
# Game ended

# %%
for player in players:
    print(f"{player.name} - Stack: {player.stack}")
# Out:
# ComplexPlayer - Stack: 1060
# FoldBot - Stack: 990
# AggressiveBot - Stack: 950

# %% [markdown]
# ## Best Practices
#
# - Always end `decide_action` with a FOLD action. Folding is always available as an action and it ensures a feasible decision among all circumstances.
# - Use as much information as possible.
