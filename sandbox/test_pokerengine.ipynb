# %%
from pypokerengine.players import BasePokerPlayer


class FishPlayer(BasePokerPlayer):  # Do not forget to make parent class as "BasePokerPlayer"

    #  we define the logic to make an action through this method. (so this method would be the core of your AI)
    def declare_action(self, valid_actions, hole_card, round_state):
        # valid_actions format => [raise_action_info, call_action_info, fold_action_info]
        call_action_info = valid_actions[1]
        action, amount = call_action_info["action"], call_action_info["amount"]
        return action, amount   # action returned here is sent to the poker engine

    def receive_game_start_message(self, game_info):
        pass

    def receive_round_start_message(self, round_count, hole_card, seats):
        pass

    def receive_street_start_message(self, street, round_state):
        pass

    def receive_game_update_message(self, action, round_state):
        pass

    def receive_round_result_message(self, winners, hand_info, round_state):
        pass

# %%
from pypokerengine.api.game import setup_config, start_poker

config = setup_config(max_round=10, initial_stack=100, small_blind_amount=5)
config.register_player(name="p1", algorithm=FishPlayer())
config.register_player(name="p2", algorithm=FishPlayer())
config.register_player(name="p3", algorithm=FishPlayer())
game_result = start_poker(config, verbose=1)
# Out:
# Started the round 1
# Street "preflop" started. (community card = [])
# "p1" declared "call:10"
# "p2" declared "call:10"
# "p3" declared "call:10"
# Street "flop" started. (community card = ['DT', 'CK', 'H8'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# Street "turn" started. (community card = ['DT', 'CK', 'H8', 'D4'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# Street "river" started. (community card = ['DT', 'CK', 'H8', 'D4', 'C8'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# "['p1']" won the round 1 (stack = {'p1': 120, 'p2': 90, 'p3': 90})
# Started the round 2
# Street "preflop" started. (community card = [])
# "p2" declared "call:10"
# "p3" declared "call:10"
# "p1" declared "call:10"
# Street "flop" started. (community card = ['SQ', 'C2', 'CA'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# Street "turn" started. (community card = ['SQ', 'C2', 'CA', 'C6'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# Street "river" started. (community card = ['SQ', 'C2', 'CA', 'C6', 'D3'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# "['p1']" won the round 2 (stack = {'p1': 140, 'p2': 80, 'p3': 80})
# Started the round 3
# Street "preflop" started. (community card = [])
# "p3" declared "call:10"
# "p1" declared "call:10"
# "p2" declared "call:10"
# Street "flop" started. (community card = ['S5', 'C8', 'D2'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# Street "turn" started. (community card = ['S5', 'C8', 'D2', 'C9'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# Street "river" started. (community card = ['S5', 'C8', 'D2', 'C9', 'H4'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# "['p1']" won the round 3 (stack = {'p1': 160, 'p2': 70, 'p3': 70})
# Started the round 4
# Street "preflop" started. (community card = [])
# "p1" declared "call:10"
# "p2" declared "call:10"
# "p3" declared "call:10"
# Street "flop" started. (community card = ['C8', 'DK', 'S6'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# Street "turn" started. (community card = ['C8', 'DK', 'S6', 'CJ'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# Street "river" started. (community card = ['C8', 'DK', 'S6', 'CJ', 'ST'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# "['p2']" won the round 4 (stack = {'p1': 150, 'p2': 90, 'p3': 60})
# Started the round 5
# Street "preflop" started. (community card = [])
# "p2" declared "call:10"
# "p3" declared "call:10"
# "p1" declared "call:10"
# Street "flop" started. (community card = ['ST', 'HJ', 'D9'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# Street "turn" started. (community card = ['ST', 'HJ', 'D9', 'S6'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# Street "river" started. (community card = ['ST', 'HJ', 'D9', 'S6', 'CA'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# "['p2']" won the round 5 (stack = {'p1': 140, 'p2': 110, 'p3': 50})
# Started the round 6
# Street "preflop" started. (community card = [])
# "p3" declared "call:10"
# "p1" declared "call:10"
# "p2" declared "call:10"
# Street "flop" started. (community card = ['HA', 'HJ', 'SA'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# Street "turn" started. (community card = ['HA', 'HJ', 'SA', 'S4'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# Street "river" started. (community card = ['HA', 'HJ', 'SA', 'S4', 'D4'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# "['p2']" won the round 6 (stack = {'p1': 130, 'p2': 130, 'p3': 40})
# Started the round 7
# Street "preflop" started. (community card = [])
# "p1" declared "call:10"
# "p2" declared "call:10"
# "p3" declared "call:10"
# Street "flop" started. (community card = ['C7', 'HK', 'DT'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# Street "turn" started. (community card = ['C7', 'HK', 'DT', 'D7'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# Street "river" started. (community card = ['C7', 'HK', 'DT', 'D7', 'S7'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# "['p1']" won the round 7 (stack = {'p1': 150, 'p2': 120, 'p3': 30})
# Started the round 8
# Street "preflop" started. (community card = [])
# "p2" declared "call:10"
# "p3" declared "call:10"
# "p1" declared "call:10"
# Street "flop" started. (community card = ['DK', 'SJ', 'S6'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# Street "turn" started. (community card = ['DK', 'SJ', 'S6', 'SA'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# Street "river" started. (community card = ['DK', 'SJ', 'S6', 'SA', 'D4'])
# "p3" declared "call:0"
# "p1" declared "call:0"
# "p2" declared "call:0"
# "['p3']" won the round 8 (stack = {'p1': 140, 'p2': 110, 'p3': 50})
# Started the round 9
# Street "preflop" started. (community card = [])
# "p3" declared "call:10"
# "p1" declared "call:10"
# "p2" declared "call:10"
# Street "flop" started. (community card = ['H8', 'D5', 'D6'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# Street "turn" started. (community card = ['H8', 'D5', 'D6', 'C3'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# Street "river" started. (community card = ['H8', 'D5', 'D6', 'C3', 'C7'])
# "p1" declared "call:0"
# "p2" declared "call:0"
# "p3" declared "call:0"
# "['p2']" won the round 9 (stack = {'p1': 130, 'p2': 130, 'p3': 40})
# Started the round 10
# Street "preflop" started. (community card = [])
# "p1" declared "call:10"
# "p2" declared "call:10"
# "p3" declared "call:10"
# Street "flop" started. (community card = ['H8', 'S7', 'CT'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# Street "turn" started. (community card = ['H8', 'S7', 'CT', 'C7'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# Street "river" started. (community card = ['H8', 'S7', 'CT', 'C7', 'H3'])
# "p2" declared "call:0"
# "p3" declared "call:0"
# "p1" declared "call:0"
# "['p1']" won the round 10 (stack = {'p1': 150, 'p2': 120, 'p3': 30})
