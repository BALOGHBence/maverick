# %%
from maverick import Game, Player, ActionType, GameState
import logging

logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s [%(levelname)s] %(name)s: %(message)s",
)

# %%
class CallBot(Player):
    """A passive bot that always calls or checks."""

    def decide_action(
        self,
        game_state: GameState,
        valid_actions: list[ActionType],
        min_raise: int
    ) -> tuple[ActionType, int]:
        """Always call or check if possible, otherwise fold."""
        if ActionType.CHECK in valid_actions:
            return (ActionType.CHECK, 0)
        elif ActionType.CALL in valid_actions:
            call_amount = game_state.current_bet - self.current_bet
            if call_amount <= self.stack:
                return (ActionType.CALL, call_amount)
        return (ActionType.FOLD, 0)

# %%
class AggressiveBot(Player):
    """An aggressive bot that frequently bets and raises."""

    def decide_action(
        self,
        game_state: GameState,
        valid_actions: list[ActionType],
        min_raise: int
    ) -> tuple[ActionType, int]:
        """Bet or raise aggressively."""
        # Try to raise if possible
        if ActionType.RAISE in valid_actions:
            raise_amount = min_raise
            if raise_amount <= self.stack:
                return (ActionType.RAISE, raise_amount)

        # Otherwise bet if possible
        if ActionType.BET in valid_actions:
            bet_amount = game_state.big_blind * 2
            if bet_amount <= self.stack:
                return (ActionType.BET, bet_amount)

        # Call if we can't bet/raise
        if ActionType.CALL in valid_actions:
            call_amount = game_state.current_bet - self.current_bet
            if call_amount <= self.stack:
                return (ActionType.CALL, call_amount)

        # Check if possible
        if ActionType.CHECK in valid_actions:
            return (ActionType.CHECK, 0)

        # Otherwise fold
        return (ActionType.FOLD, 0)

# %%
class SmartBot(Player):
    """A strategic bot that considers hand strength."""

    def decide_action(
        self,
        game_state: GameState,
        valid_actions: list[ActionType],
        min_raise: int
    ) -> tuple[ActionType, int]:
        """Make strategic decisions based on game state."""
        # Simple strategy: aggressive early, cautious later
        pot_size = game_state.pot

        # On pre-flop, be selective
        if len(game_state.community_cards) == 0:
            if ActionType.CHECK in valid_actions:
                return (ActionType.CHECK, 0)
            elif ActionType.CALL in valid_actions:
                call_amount = game_state.current_bet - self.current_bet
                # Only call small bets pre-flop
                if call_amount <= game_state.big_blind * 3:
                    if call_amount <= self.stack:
                        return (ActionType.CALL, call_amount)
            return (ActionType.FOLD, 0)

        # Post-flop, consider pot size
        if ActionType.BET in valid_actions and pot_size < game_state.big_blind * 10:
            bet_amount = pot_size // 2
            if bet_amount <= self.stack and bet_amount >= game_state.min_bet:
                return (ActionType.BET, bet_amount)

        if ActionType.CHECK in valid_actions:
            return (ActionType.CHECK, 0)

        if ActionType.CALL in valid_actions:
            call_amount = game_state.current_bet - self.current_bet
            # Use pot odds to decide
            if call_amount <= pot_size // 3 and call_amount <= self.stack:
                return (ActionType.CALL, call_amount)

        return (ActionType.FOLD, 0)

# %%
# Create game with blinds
game = Game(small_blind=10, big_blind=20, max_hands=2)

# Create and add players with different strategies
players = [
    CallBot(id="p1", name="CallBot", stack=1000, seat=0),
    AggressiveBot(id="p2", name="AggroBot", stack=1000, seat=1),
    SmartBot(id="p3", name="SmartBot", stack=1000, seat=2),
]

for player in players:
    game.add_player(player)
    
game.start()
# Out:
# 2026-01-08 19:15:38,902 [INFO] Game: PRE_FLOP | Player CallBot joined the game.
# 2026-01-08 19:15:38,902 [INFO] Game: PRE_FLOP | Player AggroBot joined the game.
# 2026-01-08 19:15:38,902 [INFO] Game: PRE_FLOP | Player SmartBot joined the game.
# 2026-01-08 19:15:38,903 [INFO] Game: PRE_FLOP | Game started.
# 2026-01-08 19:15:38,903 [INFO] Game: PRE_FLOP | Starting hand #1
# 2026-01-08 19:15:38,903 [INFO] Game: PRE_FLOP | Dealing hole cards
# 2026-01-08 19:15:38,903 [INFO] Game: PRE_FLOP | Posting small blind of 10 by player AggroBot
# 2026-01-08 19:15:38,904 [INFO] Game: PRE_FLOP | Posting big blind of 20 by player SmartBot
# 2026-01-08 19:15:38,904 [INFO] Game: PRE_FLOP | Player CallBot decided to CALL with amount 20
# 2026-01-08 19:15:38,904 [INFO] Game: PRE_FLOP | Player AggroBot decided to RAISE with amount 40
# 2026-01-08 19:15:38,904 [INFO] Game: PRE_FLOP | Player SmartBot decided to CALL with amount 20
# 2026-01-08 19:15:38,904 [INFO] Game: PRE_FLOP | Player CallBot decided to CALL with amount 20
# 2026-01-08 19:15:38,905 [INFO] Game: PRE_FLOP | Betting round complete
#
# 2026-01-08 19:15:38,905 [INFO] Game: FLOP | Dealt flop. Community cards: ['K♠', 'A♦', '2♦']
# 2026-01-08 19:15:38,905 [INFO] Game: FLOP | Player AggroBot decided to BET with amount 40
# 2026-01-08 19:15:38,905 [INFO] Game: FLOP | Player SmartBot decided to CALL with amount 40
# 2026-01-08 19:15:38,906 [INFO] Game: FLOP | Player CallBot decided to CALL with amount 40
# 2026-01-08 19:15:38,906 [INFO] Game: FLOP | Betting round complete
#
# 2026-01-08 19:15:38,906 [INFO] Game: TURN | Dealt turn. Community cards: ['K♠', 'A♦', '2♦', '6♠']
# 2026-01-08 19:15:38,906 [INFO] Game: TURN | Player AggroBot decided to BET with amount 40
# 2026-01-08 19:15:38,906 [INFO] Game: TURN | Player SmartBot decided to CALL with amount 40
# 2026-01-08 19:15:38,907 [INFO] Game: TURN | Player CallBot decided to CALL with amount 40
# 2026-01-08 19:15:38,907 [INFO] Game: TURN | Betting round complete
#
# 2026-01-08 19:15:38,907 [INFO] Game: RIVER | Dealt river. Community cards: ['K♠', 'A♦', '2♦', '6♠', 'J♠']
# 2026-01-08 19:15:38,907 [INFO] Game: RIVER | Player AggroBot decided to BET with amount 40
# 2026-01-08 19:15:38,907 [INFO] Game: RIVER | Player SmartBot decided to CALL with amount 40
# 2026-01-08 19:15:38,907 [INFO] Game: RIVER | Player CallBot decided to CALL with amount 40
# 2026-01-08 19:15:38,908 [INFO] Game: RIVER | Betting round complete
#
# 2026-01-08 19:15:38,908 [INFO] Game: SHOWDOWN | Player CallBot wins 480 from the pot.
# 2026-01-08 19:15:38,908 [INFO] Game: SHOWDOWN | Starting hand #2
# 2026-01-08 19:15:38,908 [INFO] Game: SHOWDOWN | Dealing hole cards
# 2026-01-08 19:15:38,909 [INFO] Game: SHOWDOWN | Posting small blind of 10 by player SmartBot
# 2026-01-08 19:15:38,909 [INFO] Game: SHOWDOWN | Posting big blind of 20 by player CallBot
# 2026-01-08 19:15:38,909 [INFO] Game: SHOWDOWN | Player AggroBot decided to RAISE with amount 40
# 2026-01-08 19:15:38,909 [INFO] Game: SHOWDOWN | Player SmartBot decided to CALL with amount 30
# 2026-01-08 19:15:38,910 [INFO] Game: SHOWDOWN | Player CallBot decided to CALL with amount 20
# 2026-01-08 19:15:38,910 [INFO] Game: SHOWDOWN | Betting round complete
#
# 2026-01-08 19:15:38,910 [INFO] Game: FLOP | Dealt flop. Community cards: ['8♦', '3♣', '2♥']
# 2026-01-08 19:15:38,911 [INFO] Game: FLOP | Player SmartBot decided to BET with amount 60
# 2026-01-08 19:15:38,911 [INFO] Game: FLOP | Player CallBot decided to CALL with amount 60
# 2026-01-08 19:15:38,911 [INFO] Game: FLOP | Player AggroBot decided to RAISE with amount 80
# 2026-01-08 19:15:38,912 [INFO] Game: FLOP | Player SmartBot decided to CALL with amount 20
# 2026-01-08 19:15:38,912 [INFO] Game: FLOP | Player CallBot decided to CALL with amount 20
# 2026-01-08 19:15:38,912 [INFO] Game: FLOP | Betting round complete
#
# 2026-01-08 19:15:38,912 [INFO] Game: TURN | Dealt turn. Community cards: ['8♦', '3♣', '2♥', '3♠']
# 2026-01-08 19:15:38,913 [INFO] Game: TURN | Player SmartBot decided to CHECK with amount 0
# 2026-01-08 19:15:38,913 [INFO] Game: TURN | Player CallBot decided to CHECK with amount 0
# 2026-01-08 19:15:38,913 [INFO] Game: TURN | Player AggroBot decided to BET with amount 40
# 2026-01-08 19:15:38,913 [INFO] Game: TURN | Player SmartBot decided to CALL with amount 40
# 2026-01-08 19:15:38,913 [INFO] Game: TURN | Player CallBot decided to CALL with amount 40
# 2026-01-08 19:15:38,913 [INFO] Game: TURN | Betting round complete
#
# 2026-01-08 19:15:38,914 [INFO] Game: RIVER | Dealt river. Community cards: ['8♦', '3♣', '2♥', '3♠', 'A♥']
# 2026-01-08 19:15:38,914 [INFO] Game: RIVER | Player SmartBot decided to CHECK with amount 0
# 2026-01-08 19:15:38,914 [INFO] Game: RIVER | Player CallBot decided to CHECK with amount 0
# 2026-01-08 19:15:38,914 [INFO] Game: RIVER | Player AggroBot decided to BET with amount 40
# 2026-01-08 19:15:38,915 [INFO] Game: RIVER | Player SmartBot decided to CALL with amount 40
# 2026-01-08 19:15:38,915 [INFO] Game: RIVER | Player CallBot decided to CALL with amount 40
# 2026-01-08 19:15:38,915 [INFO] Game: RIVER | Betting round complete
#
# 2026-01-08 19:15:38,916 [INFO] Game: SHOWDOWN | Player CallBot wins 600 from the pot.
# 2026-01-08 19:15:38,917 [INFO] Game: SHOWDOWN | Reached maximum number of hands, ending game.
# 2026-01-08 19:15:38,917 [INFO] Game: SHOWDOWN | Game ended
