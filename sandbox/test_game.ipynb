# %%
from maverick import Game, Player, ActionType, GameState, GameEventType, PlayerState, GameStateType
import pprint

# %%
class CallBot(Player):
    """A passive bot that always calls or checks."""

    def decide_action(
        self,
        game_state: GameState,
        valid_actions: list[ActionType],
        min_raise: int
    ) -> tuple[ActionType, int]:
        """Always call or check if possible, otherwise fold."""
        if ActionType.CHECK in valid_actions:
            return (ActionType.CHECK, 0)
        elif ActionType.CALL in valid_actions:
            call_amount = game_state.current_bet - self.current_bet
            if call_amount <= self.stack:
                return (ActionType.CALL, call_amount)
        return (ActionType.FOLD, 0)

# %%
class AggressiveBot(Player):
    """An aggressive bot that frequently bets and raises."""

    def decide_action(
        self,
        game_state: GameState,
        valid_actions: list[ActionType],
        min_raise: int
    ) -> tuple[ActionType, int]:
        """Bet or raise aggressively."""
        # Try to raise if possible
        if ActionType.RAISE in valid_actions:
            raise_amount = min_raise
            if raise_amount <= self.stack:
                return (ActionType.RAISE, raise_amount)

        # Otherwise bet if possible
        if ActionType.BET in valid_actions:
            bet_amount = game_state.big_blind * 2
            if bet_amount <= self.stack:
                return (ActionType.BET, bet_amount)

        # Call if we can't bet/raise
        if ActionType.CALL in valid_actions:
            call_amount = game_state.current_bet - self.current_bet
            if call_amount <= self.stack:
                return (ActionType.CALL, call_amount)

        # Check if possible
        if ActionType.CHECK in valid_actions:
            return (ActionType.CHECK, 0)

        # Otherwise fold
        return (ActionType.FOLD, 0)

# %%
class SmartBot(Player):
    """A strategic bot that considers hand strength."""

    def decide_action(
        self,
        game_state: GameState,
        valid_actions: list[ActionType],
        min_raise: int
    ) -> tuple[ActionType, int]:
        """Make strategic decisions based on game state."""
        # Simple strategy: aggressive early, cautious later
        pot_size = game_state.pot

        # On pre-flop, be selective
        if len(game_state.community_cards) == 0:
            if ActionType.CHECK in valid_actions:
                return (ActionType.CHECK, 0)
            elif ActionType.CALL in valid_actions:
                call_amount = game_state.current_bet - self.current_bet
                # Only call small bets pre-flop
                if call_amount <= game_state.big_blind * 3:
                    if call_amount <= self.stack:
                        return (ActionType.CALL, call_amount)
            return (ActionType.FOLD, 0)

        # Post-flop, consider pot size
        if ActionType.BET in valid_actions and pot_size < game_state.big_blind * 10:
            bet_amount = pot_size // 2
            if bet_amount <= self.stack and bet_amount >= game_state.min_bet:
                return (ActionType.BET, bet_amount)

        if ActionType.CHECK in valid_actions:
            return (ActionType.CHECK, 0)

        if ActionType.CALL in valid_actions:
            call_amount = game_state.current_bet - self.current_bet
            # Use pot odds to decide
            if call_amount <= pot_size // 3 and call_amount <= self.stack:
                return (ActionType.CALL, call_amount)

        return (ActionType.FOLD, 0)

# %%
def print_game_state(game: Game):
    """Print current game state."""
    state = game.state
    print(f"\n{'='*60}")
    print(f"Game State: {state.state_type.value}")
    print(f"Street: {state.street.value if hasattr(state.street, 'value') else state.street}")
    print(f"Pot: ${state.pot}")
    print(f"Current Bet: ${state.current_bet}")

    if state.community_cards:
        cards_str = " ".join([f"{c.rank.name}{c.suit.value}" for c in state.community_cards])
        print(f"Community Cards: {cards_str}")

    print(f"\nPlayers:")
    for player in state.players:
        status = player.state.value if hasattr(player.state, 'value') else player.state
        holding = ""
        if player.holding and player.holding.cards:
            holding = " ".join([f"{c.rank.name}{c.suit.value}" for c in player.holding.cards])
        print(f"  {player.name:12} - Stack: ${player.stack:4} | "
              f"Bet: ${player.current_bet:3} | Status: {status:8} | Cards: {holding}")
    print(f"{'='*60}\n")


def print_event(event):
    """Print a game event."""
    if event.event_type == GameEventType.PLAYER_ACTION:
        action = event.action.value if hasattr(event.action, 'value') else event.action
        print(f"  → {event.data.get('player_name', 'Player')} {action}s "
              f"${event.amount if event.amount else 0}")
    elif event.event_type == GameEventType.DEAL_FLOP:
        print(f"  → Flop dealt: {len(event.cards)} cards")
    elif event.event_type == GameEventType.DEAL_TURN:
        print(f"  → Turn dealt")
    elif event.event_type == GameEventType.DEAL_RIVER:
        print(f"  → River dealt")
    elif event.event_type == GameEventType.AWARD_POT:
        print(f"  → {event.data.get('player_name', 'Player')} wins ${event.amount}")


def play_hand(game: Game):
    """
    Play a complete hand by processing player actions.

    The game automatically transitions through states (PRE_FLOP → FLOP → TURN → RIVER → SHOWDOWN)
    as betting rounds complete. We just need to keep getting actions from players until
    the hand reaches SHOWDOWN state.
    """
    max_actions = 1000  # Safety limit
    action_count = 0
    current_street = None

    # Keep playing until hand reaches showdown
    while game.state.state_type not in [GameStateType.SHOWDOWN, GameStateType.HAND_COMPLETE, GameStateType.READY]:
        
        street = game.state.street
        if street != current_street:
            current_street = street
            print(f"\n============================== {current_street.name} ==============================\n")
        
        action_count += 1
        if action_count > max_actions:
            print("⚠ Exceeded maximum actions per hand!")
            break
        
        print("\n")
        print("-------- NEW ACTION")
        print("\n")
        pprint.pprint(game.get_game_info(), depth=4)
        print("\n")

        current_player = game.state.get_current_player()
        print("Current Player:", current_player.name if current_player else "None")

        # Skip if no current player or player cannot act
        if not current_player or current_player.state != PlayerState.ACTIVE:
            # Manually advance to next player
            print(f"  → Skipping {current_player.name if current_player else 'None'} (not active)")
            game._advance_to_next_player()
            continue

        # Get valid actions and min raise
        valid_actions = game._get_valid_actions(current_player)
        min_raise = game.state.current_bet + game.state.min_bet

        # Ask player to decide
        action, amount = current_player.decide_action(
            game.state, valid_actions, min_raise
        )
        print(f"  → {current_player.name} decides to {action.value} ${amount}")

        # Execute the action
        # (player_action automatically advances to next player and transitions states)
        try:
            game.player_action(current_player.id, action, amount)
            print(f"    ✔ Action executed: {action.value} ${amount}")
        except ValueError as e:
            print(f"  ⚠ Invalid action from {current_player.name}: {e}")
            # Fallback: fold
            game.player_action(current_player.id, ActionType.FOLD, 0)


def main():
    """Run a complete poker game."""
    print("Starting Texas Hold'em Poker Game")
    print("=" * 60)

    # Create game with blinds
    game = Game(small_blind=10, big_blind=20)

    # Create and add players with different strategies
    players = [
        CallBot(id="p1", name="CallBot", stack=1000, seat=0),
        AggressiveBot(id="p2", name="AggroBot", stack=1000, seat=1),
        SmartBot(id="p3", name="SmartBot", stack=1000, seat=2),
    ]

    for player in players:
        game.add_player(player)

    print(f"\nPlayers joined:")
    for p in players:
        print(f"  - {p.name} with ${p.stack}")

    # Start the game
    print("\n" + "=" * 60)
    print("Starting game...")
    game.start_game()

    hand_count = 0
    max_hands = 40  # Limit hands to keep example manageable

    # Play until not enough players or max hands reached
    while hand_count < max_hands:
        hand_count += 1
        print(f"\n{'#' * 60}")
        print(f"# HAND {hand_count}")
        print(f"{'#' * 60}")

        # Print initial state
        print_game_state(game)

        # Track events for this hand
        initial_event_count = len(game.event_history)

        # Play the hand (game auto-progresses through streets)
        play_hand(game)

        # Print events that occurred during the hand
        # print("\nHand Events:")
        # new_events = game.event_history[initial_event_count:]
        # for event in new_events:
        #     print_event(event)

        # Print final state after hand
        print("\nHand Complete!")
        print_game_state(game)

        # Check if we have enough players to continue
        active_players = [p for p in game.state.players if p.stack > 0]
        if len(active_players) < 2:
            print(f"\n{'='*60}")
            print("GAME OVER - Not enough players with chips!")
            break

        # Start next hand
        try:
            game.start_hand()
        except Exception as e:
            print(f"Could not start new hand: {e}")
            break

    # Print final results
    print(f"\n{'='*60}")
    print("FINAL RESULTS")
    print(f"{'='*60}")
    print(f"Hands played: {hand_count}")
    print(f"\nFinal chip counts:")
    sorted_players = sorted(game.state.players, key=lambda p: p.stack, reverse=True)
    for i, player in enumerate(sorted_players, 1):
        profit = player.stack - 1000
        profit_str = f"+${profit}" if profit > 0 else f"-${abs(profit)}"
        print(f"  {i}. {player.name:12} - ${player.stack:4} ({profit_str})")

    print(f"\nTotal events: {len(game.event_history)}")
    print("=" * 60)

# %%
main()
# Out:
# Starting Texas Hold'em Poker Game
# ============================================================
#
# Players joined:
#   - CallBot with $1000
#   - AggroBot with $1000
#   - SmartBot with $1000
#
# ============================================================
# Starting game...
#
# ############################################################
# # HAND 1
# ############################################################
#
# ============================================================
# Game State: pre_flop
# Street: 0
# Pot: $30
# Current Bet: $20
#
# Players:
#   CallBot      - Stack: $1000 | Bet: $  0 | Status: active   | Cards: FOURS THREED
#   AggroBot     - Stack: $ 990 | Bet: $ 10 | Status: active   | Cards: FIVES TWOD
#   SmartBot     - Stack: $ 980 | Bet: $ 20 | Status: active   | Cards: EIGHTH QUEEND
# ============================================================
#
#
# ============================== PRE_FLOP ==============================
#
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [],
#  'current_bet': 20,
#  'dealer_index': 0,
#  'hand_number': 1,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 1000,
#               'state': 'ACTIVE'},
#              {'current_bet': 10,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 990,
#               'state': 'ACTIVE'},
#              {'current_bet': 20,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 980,
#               'state': 'ACTIVE'}],
#  'pot': 30,
#  'state': 'PRE_FLOP',
#  'street': 'PRE_FLOP'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $20
#     ✔ Action executed: call $20
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [],
#  'current_bet': 20,
#  'dealer_index': 0,
#  'hand_number': 1,
#  'players': [{'current_bet': 20,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 980,
#               'state': 'ACTIVE'},
#              {'current_bet': 10,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 990,
#               'state': 'ACTIVE'},
#              {'current_bet': 20,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 980,
#               'state': 'ACTIVE'}],
#  'pot': 50,
#  'state': 'PRE_FLOP',
#  'street': 'PRE_FLOP'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to raise $40
#     ✔ Action executed: raise $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [],
#  'current_bet': 40,
#  'dealer_index': 0,
#  'hand_number': 1,
#  'players': [{'current_bet': 20,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 980,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 960,
#               'state': 'ACTIVE'},
#              {'current_bet': 20,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 980,
#               'state': 'ACTIVE'}],
#  'pot': 80,
#  'state': 'PRE_FLOP',
#  'street': 'PRE_FLOP'}
#
#
# Current Player: SmartBot
#   → SmartBot decides to call $20
#     ✔ Action executed: call $20
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [],
#  'current_bet': 40,
#  'dealer_index': 0,
#  'hand_number': 1,
#  'players': [{'current_bet': 20,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 980,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 960,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 960,
#               'state': 'ACTIVE'}],
#  'pot': 100,
#  'state': 'PRE_FLOP',
#  'street': 'PRE_FLOP'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $20
#     ✔ Action executed: call $20
#
# ============================== FLOP ==============================
#
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.SEVEN: 7>)],
#  'current_bet': 0,
#  'dealer_index': 0,
#  'hand_number': 1,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 960,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 960,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 960,
#               'state': 'ACTIVE'}],
#  'pot': 120,
#  'state': 'FLOP',
#  'street': 'FLOP'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to bet $40
#     ✔ Action executed: bet $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.SEVEN: 7>)],
#  'current_bet': 40,
#  'dealer_index': 0,
#  'hand_number': 1,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 960,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 920,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 960,
#               'state': 'ACTIVE'}],
#  'pot': 160,
#  'state': 'FLOP',
#  'street': 'FLOP'}
#
#
# Current Player: SmartBot
#   → SmartBot decides to call $40
#     ✔ Action executed: call $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.SEVEN: 7>)],
#  'current_bet': 40,
#  'dealer_index': 0,
#  'hand_number': 1,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 960,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 920,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 920,
#               'state': 'ACTIVE'}],
#  'pot': 200,
#  'state': 'FLOP',
#  'street': 'FLOP'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $40
#     ✔ Action executed: call $40
#
# ============================== TURN ==============================
#
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.TEN: 10>)],
#  'current_bet': 0,
#  'dealer_index': 0,
#  'hand_number': 1,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 920,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 920,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 920,
#               'state': 'ACTIVE'}],
#  'pot': 240,
#  'state': 'TURN',
#  'street': 'TURN'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to bet $40
#     ✔ Action executed: bet $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.TEN: 10>)],
#  'current_bet': 40,
#  'dealer_index': 0,
#  'hand_number': 1,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 920,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 880,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 920,
#               'state': 'ACTIVE'}],
#  'pot': 280,
#  'state': 'TURN',
#  'street': 'TURN'}
#
#
# Current Player: SmartBot
#   → SmartBot decides to call $40
#     ✔ Action executed: call $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.TEN: 10>)],
#  'current_bet': 40,
#  'dealer_index': 0,
#  'hand_number': 1,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 920,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 880,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 880,
#               'state': 'ACTIVE'}],
#  'pot': 320,
#  'state': 'TURN',
#  'street': 'TURN'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $40
#     ✔ Action executed: call $40
#
# ============================== RIVER ==============================
#
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.SEVEN: 7>)],
#  'current_bet': 0,
#  'dealer_index': 0,
#  'hand_number': 1,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 880,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 880,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 880,
#               'state': 'ACTIVE'}],
#  'pot': 360,
#  'state': 'RIVER',
#  'street': 'RIVER'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to bet $40
#     ✔ Action executed: bet $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.SEVEN: 7>)],
#  'current_bet': 40,
#  'dealer_index': 0,
#  'hand_number': 1,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 880,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 840,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 880,
#               'state': 'ACTIVE'}],
#  'pot': 400,
#  'state': 'RIVER',
#  'street': 'RIVER'}
#
#
# Current Player: SmartBot
#   → SmartBot decides to call $40
#     ✔ Action executed: call $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.SEVEN: 7>)],
#  'current_bet': 40,
#  'dealer_index': 0,
#  'hand_number': 1,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 880,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 840,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 840,
#               'state': 'ACTIVE'}],
#  'pot': 440,
#  'state': 'RIVER',
#  'street': 'RIVER'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $40
#     ✔ Action executed: call $40
#
# Hand Complete!
#
# ============================================================
# Game State: ready
# Street: 4
# Pot: $480
# Current Bet: $0
# Community Cards: TENC EIGHTS SEVENH TENH SEVENS
#
# Players:
#   CallBot      - Stack: $ 840 | Bet: $  0 | Status: active   | Cards: FOURS THREED
#   AggroBot     - Stack: $ 840 | Bet: $  0 | Status: active   | Cards: FIVES TWOD
#   SmartBot     - Stack: $1320 | Bet: $  0 | Status: active   | Cards: EIGHTH QUEEND
# ============================================================
#
#
# ############################################################
# # HAND 2
# ############################################################
#
# ============================================================
# Game State: pre_flop
# Street: 0
# Pot: $30
# Current Bet: $20
#
# Players:
#   CallBot      - Stack: $ 820 | Bet: $ 20 | Status: active   | Cards: ACEC SEVENH
#   AggroBot     - Stack: $ 840 | Bet: $  0 | Status: active   | Cards: JACKD SIXD
#   SmartBot     - Stack: $1310 | Bet: $ 10 | Status: active   | Cards: SEVENC KINGD
# ============================================================
#
#
# ============================== PRE_FLOP ==============================
#
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [],
#  'current_bet': 20,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 20,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 820,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 840,
#               'state': 'ACTIVE'},
#              {'current_bet': 10,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1310,
#               'state': 'ACTIVE'}],
#  'pot': 30,
#  'state': 'PRE_FLOP',
#  'street': 'PRE_FLOP'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to raise $40
#     ✔ Action executed: raise $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [],
#  'current_bet': 40,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 20,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 820,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 800,
#               'state': 'ACTIVE'},
#              {'current_bet': 10,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1310,
#               'state': 'ACTIVE'}],
#  'pot': 70,
#  'state': 'PRE_FLOP',
#  'street': 'PRE_FLOP'}
#
#
# Current Player: SmartBot
#   → SmartBot decides to call $30
#     ✔ Action executed: call $30
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [],
#  'current_bet': 40,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 20,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 820,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 800,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1280,
#               'state': 'ACTIVE'}],
#  'pot': 100,
#  'state': 'PRE_FLOP',
#  'street': 'PRE_FLOP'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $20
#     ✔ Action executed: call $20
#
# ============================== FLOP ==============================
#
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.JACK: 11>)],
#  'current_bet': 0,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 800,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 800,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1280,
#               'state': 'ACTIVE'}],
#  'pot': 120,
#  'state': 'FLOP',
#  'street': 'FLOP'}
#
#
# Current Player: SmartBot
#   → SmartBot decides to bet $60
#     ✔ Action executed: bet $60
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.JACK: 11>)],
#  'current_bet': 60,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 800,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 800,
#               'state': 'ACTIVE'},
#              {'current_bet': 60,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1220,
#               'state': 'ACTIVE'}],
#  'pot': 180,
#  'state': 'FLOP',
#  'street': 'FLOP'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $60
#     ✔ Action executed: call $60
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.JACK: 11>)],
#  'current_bet': 60,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 60,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 740,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 800,
#               'state': 'ACTIVE'},
#              {'current_bet': 60,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1220,
#               'state': 'ACTIVE'}],
#  'pot': 240,
#  'state': 'FLOP',
#  'street': 'FLOP'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to raise $80
#     ✔ Action executed: raise $80
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.JACK: 11>)],
#  'current_bet': 80,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 60,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 740,
#               'state': 'ACTIVE'},
#              {'current_bet': 80,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 720,
#               'state': 'ACTIVE'},
#              {'current_bet': 60,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1220,
#               'state': 'ACTIVE'}],
#  'pot': 320,
#  'state': 'FLOP',
#  'street': 'FLOP'}
#
#
# Current Player: SmartBot
#   → SmartBot decides to call $20
#     ✔ Action executed: call $20
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.JACK: 11>)],
#  'current_bet': 80,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 60,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 740,
#               'state': 'ACTIVE'},
#              {'current_bet': 80,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 720,
#               'state': 'ACTIVE'},
#              {'current_bet': 80,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1200,
#               'state': 'ACTIVE'}],
#  'pot': 340,
#  'state': 'FLOP',
#  'street': 'FLOP'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $20
#     ✔ Action executed: call $20
#
# ============================== TURN ==============================
#
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.NINE: 9>)],
#  'current_bet': 0,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 720,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 720,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1200,
#               'state': 'ACTIVE'}],
#  'pot': 360,
#  'state': 'TURN',
#  'street': 'TURN'}
#
#
# Current Player: SmartBot
#   → SmartBot decides to check $0
#     ✔ Action executed: check $0
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.NINE: 9>)],
#  'current_bet': 0,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 720,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 720,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1200,
#               'state': 'ACTIVE'}],
#  'pot': 360,
#  'state': 'TURN',
#  'street': 'TURN'}
#
#
# Current Player: CallBot
#   → CallBot decides to check $0
#     ✔ Action executed: check $0
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.NINE: 9>)],
#  'current_bet': 0,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 720,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 720,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1200,
#               'state': 'ACTIVE'}],
#  'pot': 360,
#  'state': 'TURN',
#  'street': 'TURN'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to bet $40
#     ✔ Action executed: bet $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.NINE: 9>)],
#  'current_bet': 40,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 720,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 680,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1200,
#               'state': 'ACTIVE'}],
#  'pot': 400,
#  'state': 'TURN',
#  'street': 'TURN'}
#
#
# Current Player: SmartBot
#   → SmartBot decides to call $40
#     ✔ Action executed: call $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.NINE: 9>)],
#  'current_bet': 40,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 720,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 680,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1160,
#               'state': 'ACTIVE'}],
#  'pot': 440,
#  'state': 'TURN',
#  'street': 'TURN'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $40
#     ✔ Action executed: call $40
#
# ============================== RIVER ==============================
#
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.NINE: 9>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.KING: 13>)],
#  'current_bet': 0,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 680,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 680,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1160,
#               'state': 'ACTIVE'}],
#  'pot': 480,
#  'state': 'RIVER',
#  'street': 'RIVER'}
#
#
# Current Player: SmartBot
#   → SmartBot decides to check $0
#     ✔ Action executed: check $0
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.NINE: 9>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.KING: 13>)],
#  'current_bet': 0,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 680,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 680,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1160,
#               'state': 'ACTIVE'}],
#  'pot': 480,
#  'state': 'RIVER',
#  'street': 'RIVER'}
#
#
# Current Player: CallBot
#   → CallBot decides to check $0
#     ✔ Action executed: check $0
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.NINE: 9>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.KING: 13>)],
#  'current_bet': 0,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 680,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 680,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1160,
#               'state': 'ACTIVE'}],
#  'pot': 480,
#  'state': 'RIVER',
#  'street': 'RIVER'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to bet $40
#     ✔ Action executed: bet $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.NINE: 9>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.KING: 13>)],
#  'current_bet': 40,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 680,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 640,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1160,
#               'state': 'ACTIVE'}],
#  'pot': 520,
#  'state': 'RIVER',
#  'street': 'RIVER'}
#
#
# Current Player: SmartBot
#   → SmartBot decides to call $40
#     ✔ Action executed: call $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.EIGHT: 8>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.JACK: 11>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.NINE: 9>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.KING: 13>)],
#  'current_bet': 40,
#  'dealer_index': 1,
#  'hand_number': 2,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 680,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 640,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': None,
#               'stack': 1120,
#               'state': 'ACTIVE'}],
#  'pot': 560,
#  'state': 'RIVER',
#  'street': 'RIVER'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $40
#     ✔ Action executed: call $40
#
# Hand Complete!
#
# ============================================================
# Game State: ready
# Street: 4
# Pot: $600
# Current Bet: $0
# Community Cards: JACKC EIGHTS JACKH NINED KINGS
#
# Players:
#   CallBot      - Stack: $ 640 | Bet: $  0 | Status: active   | Cards: ACEC SEVENH
#   AggroBot     - Stack: $1240 | Bet: $  0 | Status: active   | Cards: JACKD SIXD
#   SmartBot     - Stack: $1120 | Bet: $  0 | Status: active   | Cards: SEVENC KINGD
# ============================================================
#
#
# ############################################################
# # HAND 3
# ############################################################
#
# ============================================================
# Game State: pre_flop
# Street: 0
# Pot: $30
# Current Bet: $20
#
# Players:
#   CallBot      - Stack: $ 630 | Bet: $ 10 | Status: active   | Cards: KINGH QUEENS
#   AggroBot     - Stack: $1220 | Bet: $ 20 | Status: active   | Cards: NINES SEVENS
#   SmartBot     - Stack: $1120 | Bet: $  0 | Status: active   | Cards: TWOH FOURC
# ============================================================
#
#
# ============================== PRE_FLOP ==============================
#
#
#
# -------- NEW ACTION
#
#
# {'button_position': 2,
#  'community_cards': [],
#  'current_bet': 20,
#  'dealer_index': 2,
#  'hand_number': 3,
#  'players': [{'current_bet': 10,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 630,
#               'state': 'ACTIVE'},
#              {'current_bet': 20,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1220,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': 'BUTTON',
#               'stack': 1120,
#               'state': 'ACTIVE'}],
#  'pot': 30,
#  'state': 'PRE_FLOP',
#  'street': 'PRE_FLOP'}
#
#
# Current Player: SmartBot
#   → SmartBot decides to call $20
#     ✔ Action executed: call $20
#
#
# -------- NEW ACTION
#
#
# {'button_position': 2,
#  'community_cards': [],
#  'current_bet': 20,
#  'dealer_index': 2,
#  'hand_number': 3,
#  'players': [{'current_bet': 10,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 630,
#               'state': 'ACTIVE'},
#              {'current_bet': 20,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1220,
#               'state': 'ACTIVE'},
#              {'current_bet': 20,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': 'BUTTON',
#               'stack': 1100,
#               'state': 'ACTIVE'}],
#  'pot': 50,
#  'state': 'PRE_FLOP',
#  'street': 'PRE_FLOP'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $10
#     ✔ Action executed: call $10
#
#
# -------- NEW ACTION
#
#
# {'button_position': 2,
#  'community_cards': [],
#  'current_bet': 20,
#  'dealer_index': 2,
#  'hand_number': 3,
#  'players': [{'current_bet': 20,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 620,
#               'state': 'ACTIVE'},
#              {'current_bet': 20,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1220,
#               'state': 'ACTIVE'},
#              {'current_bet': 20,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': 'BUTTON',
#               'stack': 1100,
#               'state': 'ACTIVE'}],
#  'pot': 60,
#  'state': 'PRE_FLOP',
#  'street': 'PRE_FLOP'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to raise $40
#     ✔ Action executed: raise $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 2,
#  'community_cards': [],
#  'current_bet': 40,
#  'dealer_index': 2,
#  'hand_number': 3,
#  'players': [{'current_bet': 20,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 620,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1200,
#               'state': 'ACTIVE'},
#              {'current_bet': 20,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': 'BUTTON',
#               'stack': 1100,
#               'state': 'ACTIVE'}],
#  'pot': 80,
#  'state': 'PRE_FLOP',
#  'street': 'PRE_FLOP'}
#
#
# Current Player: SmartBot
#   → SmartBot decides to call $20
#     ✔ Action executed: call $20
#
#
# -------- NEW ACTION
#
#
# {'button_position': 2,
#  'community_cards': [],
#  'current_bet': 40,
#  'dealer_index': 2,
#  'hand_number': 3,
#  'players': [{'current_bet': 20,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 620,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1200,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': 'BUTTON',
#               'stack': 1080,
#               'state': 'ACTIVE'}],
#  'pot': 100,
#  'state': 'PRE_FLOP',
#  'street': 'PRE_FLOP'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $20
#     ✔ Action executed: call $20
#
# ============================== FLOP ==============================
#
#
#
# -------- NEW ACTION
#
#
# {'button_position': 2,
#  'community_cards': [Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.ACE: 14>)],
#  'current_bet': 0,
#  'dealer_index': 2,
#  'hand_number': 3,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 600,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1200,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': 'BUTTON',
#               'stack': 1080,
#               'state': 'ACTIVE'}],
#  'pot': 120,
#  'state': 'FLOP',
#  'street': 'FLOP'}
#
#
# Current Player: CallBot
#   → CallBot decides to check $0
#     ✔ Action executed: check $0
#
#
# -------- NEW ACTION
#
#
# {'button_position': 2,
#  'community_cards': [Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.ACE: 14>)],
#  'current_bet': 0,
#  'dealer_index': 2,
#  'hand_number': 3,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 600,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1200,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': 'BUTTON',
#               'stack': 1080,
#               'state': 'ACTIVE'}],
#  'pot': 120,
#  'state': 'FLOP',
#  'street': 'FLOP'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to bet $40
#     ✔ Action executed: bet $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 2,
#  'community_cards': [Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.ACE: 14>)],
#  'current_bet': 40,
#  'dealer_index': 2,
#  'hand_number': 3,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 600,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1160,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': 'BUTTON',
#               'stack': 1080,
#               'state': 'ACTIVE'}],
#  'pot': 160,
#  'state': 'FLOP',
#  'street': 'FLOP'}
#
#
# Current Player: SmartBot
#   → SmartBot decides to call $40
#     ✔ Action executed: call $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 2,
#  'community_cards': [Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.ACE: 14>)],
#  'current_bet': 40,
#  'dealer_index': 2,
#  'hand_number': 3,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 600,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1160,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': 'BUTTON',
#               'stack': 1040,
#               'state': 'ACTIVE'}],
#  'pot': 200,
#  'state': 'FLOP',
#  'street': 'FLOP'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $40
#     ✔ Action executed: call $40
#
# ============================== TURN ==============================
#
#
#
# -------- NEW ACTION
#
#
# {'button_position': 2,
#  'community_cards': [Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.ACE: 14>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.TWO: 2>)],
#  'current_bet': 0,
#  'dealer_index': 2,
#  'hand_number': 3,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 560,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1160,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': 'BUTTON',
#               'stack': 1040,
#               'state': 'ACTIVE'}],
#  'pot': 240,
#  'state': 'TURN',
#  'street': 'TURN'}
#
#
# Current Player: CallBot
#   → CallBot decides to check $0
#     ✔ Action executed: check $0
#
#
# -------- NEW ACTION
#
#
# {'button_position': 2,
#  'community_cards': [Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.ACE: 14>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.TWO: 2>)],
#  'current_bet': 0,
#  'dealer_index': 2,
#  'hand_number': 3,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 560,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1160,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': 'BUTTON',
#               'stack': 1040,
#               'state': 'ACTIVE'}],
#  'pot': 240,
#  'state': 'TURN',
#  'street': 'TURN'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to bet $40
#     ✔ Action executed: bet $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 2,
#  'community_cards': [Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.HEARTS: 'H'>, rank=<Rank.TEN: 10>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.ACE: 14>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.TWO: 2>)],
#  'current_bet': 40,
#  'dealer_index': 2,
#  'hand_number': 3,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 560,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1120,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p3',
#               'name': 'SmartBot',
#               'position': 'BUTTON',
#               'stack': 1040,
#               'state': 'ACTIVE'}],
#  'pot': 280,
#  'state': 'TURN',
#  'street': 'TURN'}
#
#
# Current Player: SmartBot
#   → SmartBot decides to call $40
#     ✔ Action executed: call $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 2,
#  'community_cards': [Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.SEVEN: 7>),
# ...
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 1480,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 1440,
#               'state': 'ACTIVE'}],
#  'pot': 80,
#  'state': 'FLOP',
#  'street': 'FLOP'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to bet $40
#     ✔ Action executed: bet $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.ACE: 14>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.FIVE: 5>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.TWO: 2>)],
#  'current_bet': 40,
#  'dealer_index': 1,
#  'hand_number': 39,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 1480,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 1400,
#               'state': 'ACTIVE'}],
#  'pot': 120,
#  'state': 'FLOP',
#  'street': 'FLOP'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $40
#     ✔ Action executed: call $40
#
# ============================== TURN ==============================
#
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.ACE: 14>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.FIVE: 5>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.TWO: 2>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.TWO: 2>)],
#  'current_bet': 0,
#  'dealer_index': 1,
#  'hand_number': 39,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 1440,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 1400,
#               'state': 'ACTIVE'}],
#  'pot': 160,
#  'state': 'TURN',
#  'street': 'TURN'}
#
#
# Current Player: CallBot
#   → CallBot decides to check $0
#     ✔ Action executed: check $0
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.ACE: 14>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.FIVE: 5>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.TWO: 2>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.TWO: 2>)],
#  'current_bet': 0,
#  'dealer_index': 1,
#  'hand_number': 39,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 1440,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 1400,
#               'state': 'ACTIVE'}],
#  'pot': 160,
#  'state': 'TURN',
#  'street': 'TURN'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to bet $40
#     ✔ Action executed: bet $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.ACE: 14>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.FIVE: 5>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.TWO: 2>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.TWO: 2>)],
#  'current_bet': 40,
#  'dealer_index': 1,
#  'hand_number': 39,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 1440,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 1360,
#               'state': 'ACTIVE'}],
#  'pot': 200,
#  'state': 'TURN',
#  'street': 'TURN'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $40
#     ✔ Action executed: call $40
#
# ============================== RIVER ==============================
#
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.ACE: 14>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.FIVE: 5>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.TWO: 2>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.TWO: 2>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.SEVEN: 7>)],
#  'current_bet': 0,
#  'dealer_index': 1,
#  'hand_number': 39,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 1400,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 1360,
#               'state': 'ACTIVE'}],
#  'pot': 240,
#  'state': 'RIVER',
#  'street': 'RIVER'}
#
#
# Current Player: CallBot
#   → CallBot decides to check $0
#     ✔ Action executed: check $0
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.ACE: 14>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.FIVE: 5>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.TWO: 2>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.TWO: 2>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.SEVEN: 7>)],
#  'current_bet': 0,
#  'dealer_index': 1,
#  'hand_number': 39,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 1400,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 1360,
#               'state': 'ACTIVE'}],
#  'pot': 240,
#  'state': 'RIVER',
#  'street': 'RIVER'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to bet $40
#     ✔ Action executed: bet $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 1,
#  'community_cards': [Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.ACE: 14>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.FIVE: 5>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.TWO: 2>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.TWO: 2>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.SEVEN: 7>)],
#  'current_bet': 40,
#  'dealer_index': 1,
#  'hand_number': 39,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': None,
#               'stack': 1400,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': 'BUTTON',
#               'stack': 1320,
#               'state': 'ACTIVE'}],
#  'pot': 280,
#  'state': 'RIVER',
#  'street': 'RIVER'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $40
#     ✔ Action executed: call $40
#
# Hand Complete!
#
# ============================================================
# Game State: ready
# Street: 4
# Pot: $320
# Current Bet: $0
# Community Cards: ACED FIVEC TWOD TWOC SEVENS
#
# Players:
#   CallBot      - Stack: $1680 | Bet: $  0 | Status: active   | Cards: FIVED SIXC
#   AggroBot     - Stack: $1320 | Bet: $  0 | Status: active   | Cards: QUEEND JACKH
# ============================================================
#
#
# ############################################################
# # HAND 40
# ############################################################
#
# ============================================================
# Game State: pre_flop
# Street: 0
# Pot: $30
# Current Bet: $20
#
# Players:
#   CallBot      - Stack: $1660 | Bet: $ 20 | Status: active   | Cards: QUEEND EIGHTD
#   AggroBot     - Stack: $1310 | Bet: $ 10 | Status: active   | Cards: JACKS TWOS
# ============================================================
#
#
# ============================== PRE_FLOP ==============================
#
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [],
#  'current_bet': 20,
#  'dealer_index': 0,
#  'hand_number': 40,
#  'players': [{'current_bet': 20,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': 'BUTTON',
#               'stack': 1660,
#               'state': 'ACTIVE'},
#              {'current_bet': 10,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1310,
#               'state': 'ACTIVE'}],
#  'pot': 30,
#  'state': 'PRE_FLOP',
#  'street': 'PRE_FLOP'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to raise $40
#     ✔ Action executed: raise $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [],
#  'current_bet': 40,
#  'dealer_index': 0,
#  'hand_number': 40,
#  'players': [{'current_bet': 20,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': 'BUTTON',
#               'stack': 1660,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1280,
#               'state': 'ACTIVE'}],
#  'pot': 60,
#  'state': 'PRE_FLOP',
#  'street': 'PRE_FLOP'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $20
#     ✔ Action executed: call $20
#
# ============================== FLOP ==============================
#
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.FOUR: 4>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.QUEEN: 12>)],
#  'current_bet': 0,
#  'dealer_index': 0,
#  'hand_number': 40,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': 'BUTTON',
#               'stack': 1640,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1280,
#               'state': 'ACTIVE'}],
#  'pot': 80,
#  'state': 'FLOP',
#  'street': 'FLOP'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to bet $40
#     ✔ Action executed: bet $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.FOUR: 4>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.QUEEN: 12>)],
#  'current_bet': 40,
#  'dealer_index': 0,
#  'hand_number': 40,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': 'BUTTON',
#               'stack': 1640,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1240,
#               'state': 'ACTIVE'}],
#  'pot': 120,
#  'state': 'FLOP',
#  'street': 'FLOP'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $40
#     ✔ Action executed: call $40
#
# ============================== TURN ==============================
#
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.FOUR: 4>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.QUEEN: 12>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.SIX: 6>)],
#  'current_bet': 0,
#  'dealer_index': 0,
#  'hand_number': 40,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': 'BUTTON',
#               'stack': 1600,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1240,
#               'state': 'ACTIVE'}],
#  'pot': 160,
#  'state': 'TURN',
#  'street': 'TURN'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to bet $40
#     ✔ Action executed: bet $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.FOUR: 4>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.QUEEN: 12>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.SIX: 6>)],
#  'current_bet': 40,
#  'dealer_index': 0,
#  'hand_number': 40,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': 'BUTTON',
#               'stack': 1600,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1200,
#               'state': 'ACTIVE'}],
#  'pot': 200,
#  'state': 'TURN',
#  'street': 'TURN'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $40
#     ✔ Action executed: call $40
#
# ============================== RIVER ==============================
#
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.FOUR: 4>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.QUEEN: 12>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.SIX: 6>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.FOUR: 4>)],
#  'current_bet': 0,
#  'dealer_index': 0,
#  'hand_number': 40,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': 'BUTTON',
#               'stack': 1560,
#               'state': 'ACTIVE'},
#              {'current_bet': 0,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1200,
#               'state': 'ACTIVE'}],
#  'pot': 240,
#  'state': 'RIVER',
#  'street': 'RIVER'}
#
#
# Current Player: AggroBot
#   → AggroBot decides to bet $40
#     ✔ Action executed: bet $40
#
#
# -------- NEW ACTION
#
#
# {'button_position': 0,
#  'community_cards': [Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.SEVEN: 7>),
#                      Card(suit=<Suit.CLUBS: 'C'>, rank=<Rank.FOUR: 4>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.QUEEN: 12>),
#                      Card(suit=<Suit.DIAMONDS: 'D'>, rank=<Rank.SIX: 6>),
#                      Card(suit=<Suit.SPADES: 'S'>, rank=<Rank.FOUR: 4>)],
#  'current_bet': 40,
#  'dealer_index': 0,
#  'hand_number': 40,
#  'players': [{'current_bet': 0,
#               'id': 'p1',
#               'name': 'CallBot',
#               'position': 'BUTTON',
#               'stack': 1560,
#               'state': 'ACTIVE'},
#              {'current_bet': 40,
#               'id': 'p2',
#               'name': 'AggroBot',
#               'position': None,
#               'stack': 1160,
#               'state': 'ACTIVE'}],
#  'pot': 280,
#  'state': 'RIVER',
#  'street': 'RIVER'}
#
#
# Current Player: CallBot
#   → CallBot decides to call $40
#     ✔ Action executed: call $40
#
# Hand Complete!
#
# ============================================================
# Game State: ready
# Street: 4
# Pot: $320
# Current Bet: $0
# Community Cards: SEVENS FOURC QUEENS SIXD FOURS
#
# Players:
#   CallBot      - Stack: $1520 | Bet: $  0 | Status: active   | Cards: QUEEND EIGHTD
#   AggroBot     - Stack: $1480 | Bet: $  0 | Status: active   | Cards: JACKS TWOS
# ============================================================
#
#
# ============================================================
# FINAL RESULTS
# ============================================================
# Hands played: 40
#
# Final chip counts:
#   1. CallBot      - $1510 (+$510)
#   2. AggroBot     - $1460 (+$460)
#
# Total events: 1025
# ============================================================
