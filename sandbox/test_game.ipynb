# %%
from maverick import Game, Player, ActionType, GameState, Street
from maverick.players import FoldBot
import logging

logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s [%(levelname)s] %(name)s: %(message)s",
)

# Get log messages only from the Game class
logging.getLogger().setLevel(logging.WARNING)  # Set root logger to WARNING
logging.getLogger("Game").setLevel(logging.DEBUG)  # Only maverick logs at DEBUG

# %%
class CallBot(Player):
    """A passive bot that always calls or checks."""

    def decide_action(
        self,
        game_state: GameState,
        valid_actions: list[ActionType],
        min_raise: int
    ) -> tuple[ActionType, int]:
        """Always call or check if possible, otherwise fold."""
        if ActionType.CHECK in valid_actions:
            return (ActionType.CHECK, 0)
        elif ActionType.CALL in valid_actions:
            call_amount = game_state.current_bet - self.current_bet
            if call_amount <= self.stack:
                return (ActionType.CALL, call_amount)
        return (ActionType.FOLD, 0)

# %%
class AggressiveBot(Player):
    """An aggressive bot that frequently bets and raises."""

    def decide_action(
        self,
        game_state: GameState,
        valid_actions: list[ActionType],
        min_raise: int
    ) -> tuple[ActionType, int]:
        """Bet or raise aggressively."""
        # Try to raise if possible
        if ActionType.RAISE in valid_actions:
            raise_amount = min_raise
            if raise_amount <= self.stack:
                return (ActionType.RAISE, raise_amount)

        # Otherwise bet if possible
        if ActionType.BET in valid_actions:
            bet_amount = game_state.big_blind * 2
            if bet_amount <= self.stack:
                return (ActionType.BET, bet_amount)

        # Call if we can't bet/raise
        if ActionType.CALL in valid_actions:
            call_amount = game_state.current_bet - self.current_bet
            if call_amount <= self.stack:
                return (ActionType.CALL, call_amount)

        # Check if possible
        if ActionType.CHECK in valid_actions:
            return (ActionType.CHECK, 0)

        # Otherwise fold
        return (ActionType.FOLD, 0)

# %%
class SmartBot(Player):
    """A strategic bot that considers hand strength."""

    def decide_action(
        self,
        game_state: GameState,
        valid_actions: list[ActionType],
        min_raise: int
    ) -> tuple[ActionType, int]:
        """Make strategic decisions based on game state."""
        # Simple strategy: aggressive early, cautious later
        pot_size = game_state.pot

        # On pre-flop, be selective
        if game_state.street == Street.PRE_FLOP:
            if ActionType.CHECK in valid_actions:
                return (ActionType.CHECK, 0)
            elif ActionType.CALL in valid_actions:
                call_amount = game_state.current_bet - self.current_bet
                # Only call small bets pre-flop
                if call_amount <= game_state.big_blind * 3:
                    if call_amount <= self.stack:
                        return (ActionType.CALL, call_amount)
            return (ActionType.FOLD, 0)

        # Post-flop, consider pot size
        if ActionType.BET in valid_actions and pot_size < game_state.big_blind * 10:
            bet_amount = pot_size // 2
            if bet_amount <= self.stack and bet_amount >= game_state.min_bet:
                return (ActionType.BET, bet_amount)

        if ActionType.CHECK in valid_actions:
            return (ActionType.CHECK, 0)

        if ActionType.CALL in valid_actions:
            call_amount = game_state.current_bet - self.current_bet
            # Use pot odds to decide
            if call_amount <= pot_size // 3 and call_amount <= self.stack:
                return (ActionType.CALL, call_amount)

        return (ActionType.FOLD, 0)

# %%
# Create game with blinds
game = Game(small_blind=10, big_blind=20, max_hands=10)

# Create and add players with different strategies
players = [
    CallBot(id="p1", name="CallBot", stack=1000, seat=0),
    AggressiveBot(id="p2", name="AggroBot", stack=1000, seat=1),
    SmartBot(id="p3", name="SmartBot", stack=1000, seat=2),
    FoldBot(id="p4", name="FoldBot", stack=1000, seat=3),
]

for player in players:
    game.add_player(player)
    
game.start()
# Out:
# 2026-01-08 20:50:08,509 [INFO] Game: Player CallBot joined the game.
# 2026-01-08 20:50:08,510 [INFO] Game: Player AggroBot joined the game.
# 2026-01-08 20:50:08,510 [INFO] Game: Player SmartBot joined the game.
# 2026-01-08 20:50:08,511 [INFO] Game: Player SmartBot2 joined the game.
# 2026-01-08 20:50:08,511 [INFO] Game: Player AggroBot2 joined the game.
# 2026-01-08 20:50:08,511 [INFO] Game: Player CallBot2 joined the game.
# 2026-01-08 20:50:08,512 [INFO] Game: Player FoldBot joined the game.
# 2026-01-08 20:50:08,512 [INFO] Game: Game started.
#
# 2026-01-08 20:50:08,512 [INFO] Game: ============================== Hand 1 ==============================
#
# 2026-01-08 20:50:08,512 [INFO] Game: PRE_FLOP | Dealing hole cards. Dealer: CallBot
# 2026-01-08 20:50:08,513 [INFO] Game: PRE_FLOP | Posting small blind of 10 by player AggroBot. Remaining stack: 990
# 2026-01-08 20:50:08,514 [INFO] Game: PRE_FLOP | Posting big blind of 20 by player SmartBot. Remaining stack: 980
# 2026-01-08 20:50:08,514 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 980.
# 2026-01-08 20:50:08,514 [INFO] Game: PRE_FLOP | Current pot: 50
# 2026-01-08 20:50:08,515 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 40. Remaining stack: 960.
# 2026-01-08 20:50:08,515 [INFO] Game: PRE_FLOP | Current pot: 90
# 2026-01-08 20:50:08,515 [INFO] Game: PRE_FLOP | Player CallBot2 calls with amount 40. Remaining stack: 960.
# 2026-01-08 20:50:08,515 [INFO] Game: PRE_FLOP | Current pot: 130
# 2026-01-08 20:50:08,516 [INFO] Game: PRE_FLOP | Player FoldBot folds.
# 2026-01-08 20:50:08,516 [INFO] Game: PRE_FLOP | Current pot: 130
# 2026-01-08 20:50:08,516 [INFO] Game: PRE_FLOP | Player CallBot calls with amount 40. Remaining stack: 960.
# 2026-01-08 20:50:08,516 [INFO] Game: PRE_FLOP | Current pot: 170
# 2026-01-08 20:50:08,516 [INFO] Game: PRE_FLOP | Player AggroBot raises to amount 60. Remaining stack: 940.
# 2026-01-08 20:50:08,516 [INFO] Game: PRE_FLOP | Current pot: 220
# 2026-01-08 20:50:08,517 [INFO] Game: PRE_FLOP | Player SmartBot calls with amount 40. Remaining stack: 940.
# 2026-01-08 20:50:08,517 [INFO] Game: PRE_FLOP | Current pot: 260
# 2026-01-08 20:50:08,517 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 940.
# 2026-01-08 20:50:08,517 [INFO] Game: PRE_FLOP | Current pot: 300
# 2026-01-08 20:50:08,517 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 80. Remaining stack: 920.
# 2026-01-08 20:50:08,517 [INFO] Game: PRE_FLOP | Current pot: 340
# 2026-01-08 20:50:08,518 [INFO] Game: PRE_FLOP | Player CallBot2 calls with amount 40. Remaining stack: 920.
# 2026-01-08 20:50:08,518 [INFO] Game: PRE_FLOP | Current pot: 380
# 2026-01-08 20:50:08,518 [INFO] Game: PRE_FLOP | Player CallBot calls with amount 40. Remaining stack: 920.
# 2026-01-08 20:50:08,518 [INFO] Game: PRE_FLOP | Current pot: 420
# 2026-01-08 20:50:08,518 [INFO] Game: PRE_FLOP | Player AggroBot raises to amount 100. Remaining stack: 900.
# 2026-01-08 20:50:08,518 [INFO] Game: PRE_FLOP | Current pot: 460
# 2026-01-08 20:50:08,519 [INFO] Game: PRE_FLOP | Player SmartBot calls with amount 40. Remaining stack: 900.
# 2026-01-08 20:50:08,519 [INFO] Game: PRE_FLOP | Current pot: 500
# 2026-01-08 20:50:08,519 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 900.
# 2026-01-08 20:50:08,519 [INFO] Game: PRE_FLOP | Current pot: 540
# 2026-01-08 20:50:08,519 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 120. Remaining stack: 880.
# 2026-01-08 20:50:08,519 [INFO] Game: PRE_FLOP | Current pot: 580
# 2026-01-08 20:50:08,519 [INFO] Game: PRE_FLOP | Player CallBot2 calls with amount 40. Remaining stack: 880.
# 2026-01-08 20:50:08,520 [INFO] Game: PRE_FLOP | Current pot: 620
# 2026-01-08 20:50:08,520 [INFO] Game: PRE_FLOP | Player CallBot calls with amount 40. Remaining stack: 880.
# 2026-01-08 20:50:08,520 [INFO] Game: PRE_FLOP | Current pot: 660
# 2026-01-08 20:50:08,520 [INFO] Game: PRE_FLOP | Player AggroBot raises to amount 140. Remaining stack: 860.
# 2026-01-08 20:50:08,520 [INFO] Game: PRE_FLOP | Current pot: 700
# 2026-01-08 20:50:08,520 [INFO] Game: PRE_FLOP | Player SmartBot calls with amount 40. Remaining stack: 860.
# 2026-01-08 20:50:08,521 [INFO] Game: PRE_FLOP | Current pot: 740
# 2026-01-08 20:50:08,521 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 860.
# 2026-01-08 20:50:08,521 [INFO] Game: PRE_FLOP | Current pot: 780
# 2026-01-08 20:50:08,521 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 160. Remaining stack: 840.
# 2026-01-08 20:50:08,521 [INFO] Game: PRE_FLOP | Current pot: 820
# 2026-01-08 20:50:08,521 [INFO] Game: PRE_FLOP | Player CallBot2 calls with amount 40. Remaining stack: 840.
# 2026-01-08 20:50:08,521 [INFO] Game: PRE_FLOP | Current pot: 860
# 2026-01-08 20:50:08,522 [INFO] Game: PRE_FLOP | Player CallBot calls with amount 40. Remaining stack: 840.
# 2026-01-08 20:50:08,522 [INFO] Game: PRE_FLOP | Current pot: 900
# 2026-01-08 20:50:08,522 [INFO] Game: PRE_FLOP | Player AggroBot raises to amount 180. Remaining stack: 820.
# 2026-01-08 20:50:08,522 [INFO] Game: PRE_FLOP | Current pot: 940
# 2026-01-08 20:50:08,522 [INFO] Game: PRE_FLOP | Player SmartBot calls with amount 40. Remaining stack: 820.
# 2026-01-08 20:50:08,522 [INFO] Game: PRE_FLOP | Current pot: 980
# 2026-01-08 20:50:08,522 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 820.
# 2026-01-08 20:50:08,523 [INFO] Game: PRE_FLOP | Current pot: 1020
# 2026-01-08 20:50:08,523 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 200. Remaining stack: 800.
# 2026-01-08 20:50:08,523 [INFO] Game: PRE_FLOP | Current pot: 1060
# 2026-01-08 20:50:08,523 [INFO] Game: PRE_FLOP | Player CallBot2 calls with amount 40. Remaining stack: 800.
# 2026-01-08 20:50:08,523 [INFO] Game: PRE_FLOP | Current pot: 1100
# 2026-01-08 20:50:08,523 [INFO] Game: PRE_FLOP | Player CallBot calls with amount 40. Remaining stack: 800.
# 2026-01-08 20:50:08,524 [INFO] Game: PRE_FLOP | Current pot: 1140
# 2026-01-08 20:50:08,524 [INFO] Game: PRE_FLOP | Player AggroBot raises to amount 220. Remaining stack: 780.
# 2026-01-08 20:50:08,524 [INFO] Game: PRE_FLOP | Current pot: 1180
# 2026-01-08 20:50:08,524 [INFO] Game: PRE_FLOP | Player SmartBot calls with amount 40. Remaining stack: 780.
# 2026-01-08 20:50:08,524 [INFO] Game: PRE_FLOP | Current pot: 1220
# 2026-01-08 20:50:08,525 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 780.
# 2026-01-08 20:50:08,525 [INFO] Game: PRE_FLOP | Current pot: 1260
# 2026-01-08 20:50:08,525 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 240. Remaining stack: 760.
# 2026-01-08 20:50:08,525 [INFO] Game: PRE_FLOP | Current pot: 1300
# 2026-01-08 20:50:08,525 [INFO] Game: PRE_FLOP | Player CallBot2 calls with amount 40. Remaining stack: 760.
# 2026-01-08 20:50:08,525 [INFO] Game: PRE_FLOP | Current pot: 1340
# 2026-01-08 20:50:08,526 [INFO] Game: PRE_FLOP | Player CallBot calls with amount 40. Remaining stack: 760.
# 2026-01-08 20:50:08,526 [INFO] Game: PRE_FLOP | Current pot: 1380
# 2026-01-08 20:50:08,526 [INFO] Game: PRE_FLOP | Player AggroBot raises to amount 260. Remaining stack: 740.
# 2026-01-08 20:50:08,526 [INFO] Game: PRE_FLOP | Current pot: 1420
# 2026-01-08 20:50:08,527 [INFO] Game: PRE_FLOP | Player SmartBot calls with amount 40. Remaining stack: 740.
# 2026-01-08 20:50:08,527 [INFO] Game: PRE_FLOP | Current pot: 1460
# 2026-01-08 20:50:08,527 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 740.
# 2026-01-08 20:50:08,528 [INFO] Game: PRE_FLOP | Current pot: 1500
# 2026-01-08 20:50:08,528 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 280. Remaining stack: 720.
# 2026-01-08 20:50:08,528 [INFO] Game: PRE_FLOP | Current pot: 1540
# 2026-01-08 20:50:08,528 [INFO] Game: PRE_FLOP | Player CallBot2 calls with amount 40. Remaining stack: 720.
# 2026-01-08 20:50:08,528 [INFO] Game: PRE_FLOP | Current pot: 1580
# 2026-01-08 20:50:08,529 [INFO] Game: PRE_FLOP | Player CallBot calls with amount 40. Remaining stack: 720.
# 2026-01-08 20:50:08,529 [INFO] Game: PRE_FLOP | Current pot: 1620
# 2026-01-08 20:50:08,529 [INFO] Game: PRE_FLOP | Player AggroBot raises to amount 300. Remaining stack: 700.
# 2026-01-08 20:50:08,529 [INFO] Game: PRE_FLOP | Current pot: 1660
# 2026-01-08 20:50:08,529 [INFO] Game: PRE_FLOP | Player SmartBot calls with amount 40. Remaining stack: 700.
# 2026-01-08 20:50:08,530 [INFO] Game: PRE_FLOP | Current pot: 1700
# 2026-01-08 20:50:08,530 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 700.
# 2026-01-08 20:50:08,530 [INFO] Game: PRE_FLOP | Current pot: 1740
# 2026-01-08 20:50:08,530 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 320. Remaining stack: 680.
# 2026-01-08 20:50:08,530 [INFO] Game: PRE_FLOP | Current pot: 1780
# 2026-01-08 20:50:08,530 [INFO] Game: PRE_FLOP | Player CallBot2 calls with amount 40. Remaining stack: 680.
# 2026-01-08 20:50:08,531 [INFO] Game: PRE_FLOP | Current pot: 1820
# 2026-01-08 20:50:08,531 [INFO] Game: PRE_FLOP | Player CallBot calls with amount 40. Remaining stack: 680.
# 2026-01-08 20:50:08,531 [INFO] Game: PRE_FLOP | Current pot: 1860
# 2026-01-08 20:50:08,531 [INFO] Game: PRE_FLOP | Player AggroBot raises to amount 340. Remaining stack: 660.
# 2026-01-08 20:50:08,531 [INFO] Game: PRE_FLOP | Current pot: 1900
# 2026-01-08 20:50:08,531 [INFO] Game: PRE_FLOP | Player SmartBot calls with amount 40. Remaining stack: 660.
# 2026-01-08 20:50:08,532 [INFO] Game: PRE_FLOP | Current pot: 1940
# 2026-01-08 20:50:08,532 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 660.
# 2026-01-08 20:50:08,532 [INFO] Game: PRE_FLOP | Current pot: 1980
# 2026-01-08 20:50:08,532 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 360. Remaining stack: 640.
# 2026-01-08 20:50:08,532 [INFO] Game: PRE_FLOP | Current pot: 2020
# 2026-01-08 20:50:08,533 [INFO] Game: PRE_FLOP | Player CallBot2 calls with amount 40. Remaining stack: 640.
# 2026-01-08 20:50:08,533 [INFO] Game: PRE_FLOP | Current pot: 2060
# 2026-01-08 20:50:08,534 [INFO] Game: PRE_FLOP | Player CallBot calls with amount 40. Remaining stack: 640.
# 2026-01-08 20:50:08,534 [INFO] Game: PRE_FLOP | Current pot: 2100
# 2026-01-08 20:50:08,534 [INFO] Game: PRE_FLOP | Player AggroBot raises to amount 380. Remaining stack: 620.
# 2026-01-08 20:50:08,534 [INFO] Game: PRE_FLOP | Current pot: 2140
# 2026-01-08 20:50:08,534 [INFO] Game: PRE_FLOP | Player SmartBot calls with amount 40. Remaining stack: 620.
# 2026-01-08 20:50:08,535 [INFO] Game: PRE_FLOP | Current pot: 2180
# 2026-01-08 20:50:08,535 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 620.
# 2026-01-08 20:50:08,535 [INFO] Game: PRE_FLOP | Current pot: 2220
# 2026-01-08 20:50:08,535 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 400. Remaining stack: 600.
# 2026-01-08 20:50:08,535 [INFO] Game: PRE_FLOP | Current pot: 2260
# 2026-01-08 20:50:08,536 [INFO] Game: PRE_FLOP | Player CallBot2 calls with amount 40. Remaining stack: 600.
# 2026-01-08 20:50:08,539 [INFO] Game: PRE_FLOP | Current pot: 2300
# 2026-01-08 20:50:08,547 [INFO] Game: PRE_FLOP | Player CallBot calls with amount 40. Remaining stack: 600.
# 2026-01-08 20:50:08,547 [INFO] Game: PRE_FLOP | Current pot: 2340
# 2026-01-08 20:50:08,547 [INFO] Game: PRE_FLOP | Player AggroBot raises to amount 420. Remaining stack: 580.
# 2026-01-08 20:50:08,548 [INFO] Game: PRE_FLOP | Current pot: 2380
# 2026-01-08 20:50:08,548 [INFO] Game: PRE_FLOP | Player SmartBot calls with amount 40. Remaining stack: 580.
# 2026-01-08 20:50:08,548 [INFO] Game: PRE_FLOP | Current pot: 2420
# 2026-01-08 20:50:08,548 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 580.
# 2026-01-08 20:50:08,548 [INFO] Game: PRE_FLOP | Current pot: 2460
# 2026-01-08 20:50:08,548 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 440. Remaining stack: 560.
# 2026-01-08 20:50:08,549 [INFO] Game: PRE_FLOP | Current pot: 2500
# 2026-01-08 20:50:08,549 [INFO] Game: PRE_FLOP | Player CallBot2 calls with amount 40. Remaining stack: 560.
# 2026-01-08 20:50:08,549 [INFO] Game: PRE_FLOP | Current pot: 2540
# 2026-01-08 20:50:08,549 [INFO] Game: PRE_FLOP | Player CallBot calls with amount 40. Remaining stack: 560.
# 2026-01-08 20:50:08,549 [INFO] Game: PRE_FLOP | Current pot: 2580
# 2026-01-08 20:50:08,549 [INFO] Game: PRE_FLOP | Player AggroBot raises to amount 460. Remaining stack: 540.
# 2026-01-08 20:50:08,549 [INFO] Game: PRE_FLOP | Current pot: 2620
# 2026-01-08 20:50:08,550 [INFO] Game: PRE_FLOP | Player SmartBot calls with amount 40. Remaining stack: 540.
# 2026-01-08 20:50:08,550 [INFO] Game: PRE_FLOP | Current pot: 2660
# 2026-01-08 20:50:08,550 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 540.
# 2026-01-08 20:50:08,550 [INFO] Game: PRE_FLOP | Current pot: 2700
# 2026-01-08 20:50:08,550 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 480. Remaining stack: 520.
# 2026-01-08 20:50:08,550 [INFO] Game: PRE_FLOP | Current pot: 2740
# 2026-01-08 20:50:08,551 [INFO] Game: PRE_FLOP | Player CallBot2 calls with amount 40. Remaining stack: 520.
# 2026-01-08 20:50:08,551 [INFO] Game: PRE_FLOP | Current pot: 2780
# 2026-01-08 20:50:08,551 [INFO] Game: PRE_FLOP | Player CallBot calls with amount 40. Remaining stack: 520.
# 2026-01-08 20:50:08,551 [INFO] Game: PRE_FLOP | Current pot: 2820
# 2026-01-08 20:50:08,552 [INFO] Game: PRE_FLOP | Player AggroBot raises to amount 500. Remaining stack: 500.
# 2026-01-08 20:50:08,552 [INFO] Game: PRE_FLOP | Current pot: 2860
# 2026-01-08 20:50:08,552 [INFO] Game: PRE_FLOP | Player SmartBot calls with amount 40. Remaining stack: 500.
# 2026-01-08 20:50:08,552 [INFO] Game: PRE_FLOP | Current pot: 2900
# 2026-01-08 20:50:08,552 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 500.
# 2026-01-08 20:50:08,552 [INFO] Game: PRE_FLOP | Current pot: 2940
# 2026-01-08 20:50:08,553 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 520. Remaining stack: 480.
# 2026-01-08 20:50:08,553 [INFO] Game: PRE_FLOP | Current pot: 2980
# 2026-01-08 20:50:08,553 [INFO] Game: PRE_FLOP | Player CallBot2 calls with amount 40. Remaining stack: 480.
# 2026-01-08 20:50:08,553 [INFO] Game: PRE_FLOP | Current pot: 3020
# 2026-01-08 20:50:08,553 [INFO] Game: PRE_FLOP | Player CallBot calls with amount 40. Remaining stack: 480.
# 2026-01-08 20:50:08,553 [INFO] Game: PRE_FLOP | Current pot: 3060
# 2026-01-08 20:50:08,554 [INFO] Game: PRE_FLOP | Player AggroBot calls with amount 20. Remaining stack: 480.
# 2026-01-08 20:50:08,554 [INFO] Game: PRE_FLOP | Current pot: 3080
# 2026-01-08 20:50:08,554 [INFO] Game: PRE_FLOP | Player SmartBot calls with amount 20. Remaining stack: 480.
# 2026-01-08 20:50:08,555 [INFO] Game: PRE_FLOP | Current pot: 3100
# 2026-01-08 20:50:08,555 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 480.
# 2026-01-08 20:50:08,556 [INFO] Game: PRE_FLOP | Current pot: 3120
# 2026-01-08 20:50:08,557 [INFO] Game: PRE_FLOP | Betting round complete
#
# 2026-01-08 20:50:08,558 [INFO] Game: FLOP | Dealt flop. Community cards: ['8♥', 'A♦', '9♦']
# 2026-01-08 20:50:08,558 [INFO] Game: FLOP | Player AggroBot bets amount 40. Remaining stack: 440.
# 2026-01-08 20:50:08,559 [INFO] Game: FLOP | Current pot: 3160
# 2026-01-08 20:50:08,559 [INFO] Game: FLOP | Player SmartBot calls with amount 40. Remaining stack: 440.
# 2026-01-08 20:50:08,560 [INFO] Game: FLOP | Current pot: 3200
# 2026-01-08 20:50:08,560 [INFO] Game: FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 440.
# 2026-01-08 20:50:08,561 [INFO] Game: FLOP | Current pot: 3240
# 2026-01-08 20:50:08,561 [INFO] Game: FLOP | Player AggroBot2 raises to amount 60. Remaining stack: 420.
# 2026-01-08 20:50:08,562 [INFO] Game: FLOP | Current pot: 3300
# 2026-01-08 20:50:08,562 [INFO] Game: FLOP | Player CallBot2 calls with amount 60. Remaining stack: 420.
# 2026-01-08 20:50:08,563 [INFO] Game: FLOP | Current pot: 3360
# 2026-01-08 20:50:08,563 [INFO] Game: FLOP | Player CallBot calls with amount 60. Remaining stack: 420.
# 2026-01-08 20:50:08,564 [INFO] Game: FLOP | Current pot: 3420
# 2026-01-08 20:50:08,569 [INFO] Game: FLOP | Player AggroBot raises to amount 80. Remaining stack: 400.
# 2026-01-08 20:50:08,570 [INFO] Game: FLOP | Current pot: 3460
# 2026-01-08 20:50:08,591 [INFO] Game: FLOP | Player SmartBot calls with amount 40. Remaining stack: 400.
# 2026-01-08 20:50:08,591 [INFO] Game: FLOP | Current pot: 3500
# 2026-01-08 20:50:08,592 [INFO] Game: FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 400.
# 2026-01-08 20:50:08,592 [INFO] Game: FLOP | Current pot: 3540
# 2026-01-08 20:50:08,592 [INFO] Game: FLOP | Player AggroBot2 raises to amount 100. Remaining stack: 380.
# 2026-01-08 20:50:08,592 [INFO] Game: FLOP | Current pot: 3580
# 2026-01-08 20:50:08,592 [INFO] Game: FLOP | Player CallBot2 calls with amount 40. Remaining stack: 380.
# 2026-01-08 20:50:08,593 [INFO] Game: FLOP | Current pot: 3620
# 2026-01-08 20:50:08,593 [INFO] Game: FLOP | Player CallBot calls with amount 40. Remaining stack: 380.
# 2026-01-08 20:50:08,593 [INFO] Game: FLOP | Current pot: 3660
# 2026-01-08 20:50:08,594 [INFO] Game: FLOP | Player AggroBot raises to amount 120. Remaining stack: 360.
# 2026-01-08 20:50:08,594 [INFO] Game: FLOP | Current pot: 3700
# 2026-01-08 20:50:08,594 [INFO] Game: FLOP | Player SmartBot calls with amount 40. Remaining stack: 360.
# 2026-01-08 20:50:08,595 [INFO] Game: FLOP | Current pot: 3740
# 2026-01-08 20:50:08,608 [INFO] Game: FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 360.
# 2026-01-08 20:50:08,608 [INFO] Game: FLOP | Current pot: 3780
# 2026-01-08 20:50:08,609 [INFO] Game: FLOP | Player AggroBot2 raises to amount 140. Remaining stack: 340.
# 2026-01-08 20:50:08,609 [INFO] Game: FLOP | Current pot: 3820
# 2026-01-08 20:50:08,610 [INFO] Game: FLOP | Player CallBot2 calls with amount 40. Remaining stack: 340.
# 2026-01-08 20:50:08,610 [INFO] Game: FLOP | Current pot: 3860
# 2026-01-08 20:50:08,610 [INFO] Game: FLOP | Player CallBot calls with amount 40. Remaining stack: 340.
# 2026-01-08 20:50:08,610 [INFO] Game: FLOP | Current pot: 3900
# 2026-01-08 20:50:08,610 [INFO] Game: FLOP | Player AggroBot raises to amount 160. Remaining stack: 320.
# 2026-01-08 20:50:08,611 [INFO] Game: FLOP | Current pot: 3940
# 2026-01-08 20:50:08,615 [INFO] Game: FLOP | Player SmartBot calls with amount 40. Remaining stack: 320.
# 2026-01-08 20:50:08,637 [INFO] Game: FLOP | Current pot: 3980
# 2026-01-08 20:50:08,646 [INFO] Game: FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 320.
# 2026-01-08 20:50:08,648 [INFO] Game: FLOP | Current pot: 4020
# 2026-01-08 20:50:08,661 [INFO] Game: FLOP | Player AggroBot2 raises to amount 180. Remaining stack: 300.
# 2026-01-08 20:50:08,666 [INFO] Game: FLOP | Current pot: 4060
# 2026-01-08 20:50:08,667 [INFO] Game: FLOP | Player CallBot2 calls with amount 40. Remaining stack: 300.
# 2026-01-08 20:50:08,668 [INFO] Game: FLOP | Current pot: 4100
# 2026-01-08 20:50:08,668 [INFO] Game: FLOP | Player CallBot calls with amount 40. Remaining stack: 300.
# 2026-01-08 20:50:08,668 [INFO] Game: FLOP | Current pot: 4140
# 2026-01-08 20:50:08,669 [INFO] Game: FLOP | Player AggroBot raises to amount 200. Remaining stack: 280.
# 2026-01-08 20:50:08,670 [INFO] Game: FLOP | Current pot: 4180
# 2026-01-08 20:50:08,671 [INFO] Game: FLOP | Player SmartBot calls with amount 40. Remaining stack: 280.
# 2026-01-08 20:50:08,676 [INFO] Game: FLOP | Current pot: 4220
# 2026-01-08 20:50:08,678 [INFO] Game: FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 280.
# 2026-01-08 20:50:08,682 [INFO] Game: FLOP | Current pot: 4260
# 2026-01-08 20:50:08,683 [INFO] Game: FLOP | Player AggroBot2 raises to amount 220. Remaining stack: 260.
# 2026-01-08 20:50:08,683 [INFO] Game: FLOP | Current pot: 4300
# 2026-01-08 20:50:08,684 [INFO] Game: FLOP | Player CallBot2 calls with amount 40. Remaining stack: 260.
# 2026-01-08 20:50:08,684 [INFO] Game: FLOP | Current pot: 4340
# 2026-01-08 20:50:08,684 [INFO] Game: FLOP | Player CallBot calls with amount 40. Remaining stack: 260.
# 2026-01-08 20:50:08,685 [INFO] Game: FLOP | Current pot: 4380
# 2026-01-08 20:50:08,685 [INFO] Game: FLOP | Player AggroBot raises to amount 240. Remaining stack: 240.
# 2026-01-08 20:50:08,685 [INFO] Game: FLOP | Current pot: 4420
# 2026-01-08 20:50:08,685 [INFO] Game: FLOP | Player SmartBot calls with amount 40. Remaining stack: 240.
# 2026-01-08 20:50:08,686 [INFO] Game: FLOP | Current pot: 4460
# 2026-01-08 20:50:08,686 [INFO] Game: FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 240.
# 2026-01-08 20:50:08,686 [INFO] Game: FLOP | Current pot: 4500
# 2026-01-08 20:50:08,686 [INFO] Game: FLOP | Player AggroBot2 raises to amount 260. Remaining stack: 220.
# 2026-01-08 20:50:08,686 [INFO] Game: FLOP | Current pot: 4540
# 2026-01-08 20:50:08,687 [INFO] Game: FLOP | Player CallBot2 calls with amount 40. Remaining stack: 220.
# 2026-01-08 20:50:08,687 [INFO] Game: FLOP | Current pot: 4580
# 2026-01-08 20:50:08,687 [INFO] Game: FLOP | Player CallBot calls with amount 40. Remaining stack: 220.
# 2026-01-08 20:50:08,687 [INFO] Game: FLOP | Current pot: 4620
# 2026-01-08 20:50:08,687 [INFO] Game: FLOP | Player AggroBot calls with amount 20. Remaining stack: 220.
# 2026-01-08 20:50:08,688 [INFO] Game: FLOP | Current pot: 4640
# 2026-01-08 20:50:08,688 [INFO] Game: FLOP | Player SmartBot calls with amount 20. Remaining stack: 220.
# 2026-01-08 20:50:08,689 [INFO] Game: FLOP | Current pot: 4660
# 2026-01-08 20:50:08,689 [INFO] Game: FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 220.
# 2026-01-08 20:50:08,689 [INFO] Game: FLOP | Current pot: 4680
# 2026-01-08 20:50:08,689 [INFO] Game: FLOP | Betting round complete
#
# 2026-01-08 20:50:08,689 [INFO] Game: TURN | Dealt turn. Community cards: ['8♥', 'A♦', '9♦', '4♦']
# 2026-01-08 20:50:08,690 [INFO] Game: TURN | Player AggroBot bets amount 40. Remaining stack: 180.
# 2026-01-08 20:50:08,690 [INFO] Game: TURN | Current pot: 4720
# 2026-01-08 20:50:08,690 [INFO] Game: TURN | Player SmartBot calls with amount 40. Remaining stack: 180.
# 2026-01-08 20:50:08,690 [INFO] Game: TURN | Current pot: 4760
# 2026-01-08 20:50:08,691 [INFO] Game: TURN | Player SmartBot2 calls with amount 40. Remaining stack: 180.
# 2026-01-08 20:50:08,691 [INFO] Game: TURN | Current pot: 4800
# 2026-01-08 20:50:08,691 [INFO] Game: TURN | Player AggroBot2 raises to amount 60. Remaining stack: 160.
# 2026-01-08 20:50:08,691 [INFO] Game: TURN | Current pot: 4860
# 2026-01-08 20:50:08,691 [INFO] Game: TURN | Player CallBot2 calls with amount 60. Remaining stack: 160.
# 2026-01-08 20:50:08,691 [INFO] Game: TURN | Current pot: 4920
# 2026-01-08 20:50:08,692 [INFO] Game: TURN | Player CallBot calls with amount 60. Remaining stack: 160.
# 2026-01-08 20:50:08,692 [INFO] Game: TURN | Current pot: 4980
# 2026-01-08 20:50:08,692 [INFO] Game: TURN | Player AggroBot raises to amount 80. Remaining stack: 140.
# 2026-01-08 20:50:08,692 [INFO] Game: TURN | Current pot: 5020
# 2026-01-08 20:50:08,692 [INFO] Game: TURN | Player SmartBot calls with amount 40. Remaining stack: 140.
# 2026-01-08 20:50:08,693 [INFO] Game: TURN | Current pot: 5060
# 2026-01-08 20:50:08,693 [INFO] Game: TURN | Player SmartBot2 calls with amount 40. Remaining stack: 140.
# 2026-01-08 20:50:08,693 [INFO] Game: TURN | Current pot: 5100
# 2026-01-08 20:50:08,693 [INFO] Game: TURN | Player AggroBot2 raises to amount 100. Remaining stack: 120.
# 2026-01-08 20:50:08,694 [INFO] Game: TURN | Current pot: 5140
# 2026-01-08 20:50:08,694 [INFO] Game: TURN | Player CallBot2 calls with amount 40. Remaining stack: 120.
# 2026-01-08 20:50:08,694 [INFO] Game: TURN | Current pot: 5180
# 2026-01-08 20:50:08,694 [INFO] Game: TURN | Player CallBot calls with amount 40. Remaining stack: 120.
# 2026-01-08 20:50:08,694 [INFO] Game: TURN | Current pot: 5220
# 2026-01-08 20:50:08,695 [INFO] Game: TURN | Player AggroBot raises to amount 120. Remaining stack: 100.
# 2026-01-08 20:50:08,695 [INFO] Game: TURN | Current pot: 5260
# 2026-01-08 20:50:08,695 [INFO] Game: TURN | Player SmartBot calls with amount 40. Remaining stack: 100.
# 2026-01-08 20:50:08,695 [INFO] Game: TURN | Current pot: 5300
# 2026-01-08 20:50:08,696 [INFO] Game: TURN | Player SmartBot2 calls with amount 40. Remaining stack: 100.
# 2026-01-08 20:50:08,696 [INFO] Game: TURN | Current pot: 5340
# 2026-01-08 20:50:08,696 [INFO] Game: TURN | Player AggroBot2 calls with amount 20. Remaining stack: 100.
# 2026-01-08 20:50:08,696 [INFO] Game: TURN | Current pot: 5360
# 2026-01-08 20:50:08,696 [INFO] Game: TURN | Player CallBot2 calls with amount 20. Remaining stack: 100.
# 2026-01-08 20:50:08,696 [INFO] Game: TURN | Current pot: 5380
# 2026-01-08 20:50:08,697 [INFO] Game: TURN | Player CallBot calls with amount 20. Remaining stack: 100.
# 2026-01-08 20:50:08,697 [INFO] Game: TURN | Current pot: 5400
# 2026-01-08 20:50:08,697 [INFO] Game: TURN | Betting round complete
#
# 2026-01-08 20:50:08,698 [INFO] Game: RIVER | Dealt river. Community cards: ['8♥', 'A♦', '9♦', '4♦', 'J♣']
# 2026-01-08 20:50:08,698 [INFO] Game: RIVER | Player AggroBot bets amount 40. Remaining stack: 60.
# 2026-01-08 20:50:08,699 [INFO] Game: RIVER | Current pot: 5440
# 2026-01-08 20:50:08,699 [INFO] Game: RIVER | Player SmartBot calls with amount 40. Remaining stack: 60.
# 2026-01-08 20:50:08,700 [INFO] Game: RIVER | Current pot: 5480
# 2026-01-08 20:50:08,700 [INFO] Game: RIVER | Player SmartBot2 calls with amount 40. Remaining stack: 60.
# 2026-01-08 20:50:08,701 [INFO] Game: RIVER | Current pot: 5520
# 2026-01-08 20:50:08,702 [INFO] Game: RIVER | Player AggroBot2 raises to amount 60. Remaining stack: 40.
# 2026-01-08 20:50:08,704 [INFO] Game: RIVER | Current pot: 5580
# 2026-01-08 20:50:08,705 [INFO] Game: RIVER | Player CallBot2 calls with amount 60. Remaining stack: 40.
# 2026-01-08 20:50:08,705 [INFO] Game: RIVER | Current pot: 5640
# 2026-01-08 20:50:08,706 [INFO] Game: RIVER | Player CallBot calls with amount 60. Remaining stack: 40.
# 2026-01-08 20:50:08,707 [INFO] Game: RIVER | Current pot: 5700
# 2026-01-08 20:50:08,708 [INFO] Game: RIVER | Player AggroBot calls with amount 20. Remaining stack: 40.
# 2026-01-08 20:50:08,709 [INFO] Game: RIVER | Current pot: 5720
# 2026-01-08 20:50:08,711 [INFO] Game: RIVER | Player SmartBot calls with amount 20. Remaining stack: 40.
# 2026-01-08 20:50:08,712 [INFO] Game: RIVER | Current pot: 5740
# 2026-01-08 20:50:08,712 [INFO] Game: RIVER | Player SmartBot2 calls with amount 20. Remaining stack: 40.
# 2026-01-08 20:50:08,712 [INFO] Game: RIVER | Current pot: 5760
# 2026-01-08 20:50:08,713 [INFO] Game: RIVER | Betting round complete
#
# 2026-01-08 20:50:08,713 [INFO] Game: SHOWDOWN | Player CallBot has hand HIGH_CARD with cards ['5♣', 'Q♣', 'A♦', '9♦', 'J♣'] (score: 14.1319)
# 2026-01-08 20:50:08,714 [INFO] Game: SHOWDOWN | Player AggroBot has hand PAIR with cards ['10♠', 'J♥', 'A♦', '9♦', 'J♣'] (score: 26.1509)
# 2026-01-08 20:50:08,714 [INFO] Game: SHOWDOWN | Player SmartBot has hand HIGH_CARD with cards ['5♦', 'K♠', 'A♦', '9♦', 'J♣'] (score: 14.1419)
# 2026-01-08 20:50:08,715 [INFO] Game: SHOWDOWN | Player SmartBot2 has hand PAIR with cards ['4♣', '6♣', 'A♦', '4♦', 'J♣'] (score: 19.1516)
# 2026-01-08 20:50:08,715 [INFO] Game: SHOWDOWN | Player AggroBot2 has hand TWO_PAIR with cards ['A♣', '4♠', 'A♦', '4♦', 'J♣'] (score: 44.051)
# 2026-01-08 20:50:08,715 [INFO] Game: SHOWDOWN | Player CallBot2 has hand PAIR with cards ['10♥', 'A♠', 'A♦', '9♦', 'J♣'] (score: 29.1209)
# 2026-01-08 20:50:08,715 [INFO] Game: SHOWDOWN | Player AggroBot2 wins 5760 from the pot.
# 2026-01-08 20:50:08,716 [INFO] Game: SHOWDOWN | Showdown complete
#
# 2026-01-08 20:50:08,716 [INFO] Game: Hand ended
#
# 2026-01-08 20:50:08,716 [INFO] Game: ============================== Hand 2 ==============================
#
# 2026-01-08 20:50:08,716 [INFO] Game: PRE_FLOP | Dealing hole cards. Dealer: AggroBot
# 2026-01-08 20:50:08,717 [INFO] Game: PRE_FLOP | Posting small blind of 10 by player SmartBot. Remaining stack: 30
# 2026-01-08 20:50:08,717 [INFO] Game: PRE_FLOP | Posting big blind of 20 by player SmartBot2. Remaining stack: 20
# 2026-01-08 20:50:08,717 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 40. Remaining stack: 5760.
# 2026-01-08 20:50:08,718 [INFO] Game: PRE_FLOP | Current pot: 70
# 2026-01-08 20:50:08,718 [INFO] Game: PRE_FLOP | Player CallBot2 calls with amount 40. Remaining stack: 0.
# 2026-01-08 20:50:08,718 [INFO] Game: PRE_FLOP | Current pot: 110
# 2026-01-08 20:50:08,718 [INFO] Game: PRE_FLOP | Player FoldBot folds.
# 2026-01-08 20:50:08,718 [INFO] Game: PRE_FLOP | Current pot: 110
# 2026-01-08 20:50:08,719 [INFO] Game: PRE_FLOP | Player CallBot calls with amount 40. Remaining stack: 0.
# 2026-01-08 20:50:08,719 [INFO] Game: PRE_FLOP | Current pot: 150
# 2026-01-08 20:50:08,719 [INFO] Game: PRE_FLOP | Player AggroBot calls with amount 40. Remaining stack: 0.
# 2026-01-08 20:50:08,719 [INFO] Game: PRE_FLOP | Current pot: 190
# 2026-01-08 20:50:08,719 [INFO] Game: PRE_FLOP | Player SmartBot calls with amount 30. Remaining stack: 0.
# 2026-01-08 20:50:08,720 [INFO] Game: PRE_FLOP | Current pot: 220
# 2026-01-08 20:50:08,720 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 0.
# 2026-01-08 20:50:08,720 [INFO] Game: PRE_FLOP | Current pot: 240
# 2026-01-08 20:50:08,720 [INFO] Game: PRE_FLOP | Betting round complete
#
# 2026-01-08 20:50:08,721 [INFO] Game: FLOP | Dealt flop. Community cards: ['3♥', '8♠', 'J♠']
# 2026-01-08 20:50:08,721 [INFO] Game: FLOP | Player AggroBot2 bets amount 40. Remaining stack: 5720.
# 2026-01-08 20:50:08,722 [INFO] Game: FLOP | Current pot: 280
# 2026-01-08 20:50:08,722 [INFO] Game: FLOP | Betting round complete
#
# 2026-01-08 20:50:08,722 [INFO] Game: TURN | Dealt turn. Community cards: ['3♥', '8♠', 'J♠', 'J♦']
# 2026-01-08 20:50:08,723 [INFO] Game: TURN | Player AggroBot2 bets amount 40. Remaining stack: 5680.
# 2026-01-08 20:50:08,723 [INFO] Game: TURN | Current pot: 320
# 2026-01-08 20:50:08,723 [INFO] Game: TURN | Betting round complete
#
# 2026-01-08 20:50:08,723 [INFO] Game: RIVER | Dealt river. Community cards: ['3♥', '8♠', 'J♠', 'J♦', '6♥']
# 2026-01-08 20:50:08,723 [INFO] Game: RIVER | Player AggroBot2 bets amount 40. Remaining stack: 5640.
# 2026-01-08 20:50:08,724 [INFO] Game: RIVER | Current pot: 360
# 2026-01-08 20:50:08,724 [INFO] Game: RIVER | Betting round complete
#
# 2026-01-08 20:50:08,724 [INFO] Game: SHOWDOWN | Player CallBot has hand PAIR with cards ['A♣', 'Q♣', '8♠', 'J♠', 'J♦'] (score: 26.1528)
# 2026-01-08 20:50:08,726 [INFO] Game: SHOWDOWN | Player AggroBot has hand PAIR with cards ['2♣', 'Q♠', '8♠', 'J♠', 'J♦'] (score: 26.1282)
# 2026-01-08 20:50:08,727 [INFO] Game: SHOWDOWN | Player SmartBot has hand TWO_PAIR with cards ['Q♥', '6♦', 'J♠', 'J♦', '6♥'] (score: 41.072)
# 2026-01-08 20:50:08,728 [INFO] Game: SHOWDOWN | Player SmartBot2 has hand FULL_HOUSE with cards ['3♦', '3♣', '3♥', 'J♠', 'J♦'] (score: 93.11)
# 2026-01-08 20:50:08,729 [INFO] Game: SHOWDOWN | Player AggroBot2 has hand TWO_PAIR with cards ['7♣', '6♠', 'J♠', 'J♦', '6♥'] (score: 41.067)
# 2026-01-08 20:50:08,730 [INFO] Game: SHOWDOWN | Player CallBot2 has hand TWO_PAIR with cards ['3♠', '2♦', '3♥', 'J♠', 'J♦'] (score: 41.032)
# 2026-01-08 20:50:08,730 [INFO] Game: SHOWDOWN | Player SmartBot2 wins 360 from the pot.
# 2026-01-08 20:50:08,730 [INFO] Game: SHOWDOWN | Showdown complete
#
# 2026-01-08 20:50:08,731 [INFO] Game: Hand ended
#
# 2026-01-08 20:50:08,731 [INFO] Game: ============================== Hand 3 ==============================
#
# 2026-01-08 20:50:08,731 [INFO] Game: PRE_FLOP | Dealing hole cards. Dealer: FoldBot
# 2026-01-08 20:50:08,731 [INFO] Game: PRE_FLOP | Posting small blind of 10 by player SmartBot2. Remaining stack: 350
# 2026-01-08 20:50:08,732 [INFO] Game: PRE_FLOP | Posting big blind of 20 by player AggroBot2. Remaining stack: 5620
# 2026-01-08 20:50:08,732 [INFO] Game: PRE_FLOP | Player FoldBot folds.
# 2026-01-08 20:50:08,732 [INFO] Game: PRE_FLOP | Current pot: 30
# 2026-01-08 20:50:08,733 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 10. Remaining stack: 340.
# 2026-01-08 20:50:08,733 [INFO] Game: PRE_FLOP | Current pot: 40
# 2026-01-08 20:50:08,733 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 40. Remaining stack: 5600.
# 2026-01-08 20:50:08,734 [INFO] Game: PRE_FLOP | Current pot: 60
# 2026-01-08 20:50:08,734 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 320.
# 2026-01-08 20:50:08,734 [INFO] Game: PRE_FLOP | Current pot: 80
# 2026-01-08 20:50:08,734 [INFO] Game: PRE_FLOP | Betting round complete
#
# 2026-01-08 20:50:08,735 [INFO] Game: FLOP | Dealt flop. Community cards: ['4♣', 'A♠', '7♦']
# 2026-01-08 20:50:08,735 [INFO] Game: FLOP | Player SmartBot2 bets amount 40. Remaining stack: 280.
# 2026-01-08 20:50:08,735 [INFO] Game: FLOP | Current pot: 120
# 2026-01-08 20:50:08,735 [INFO] Game: FLOP | Player AggroBot2 raises to amount 60. Remaining stack: 5540.
# 2026-01-08 20:50:08,736 [INFO] Game: FLOP | Current pot: 180
# 2026-01-08 20:50:08,736 [INFO] Game: FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 260.
# 2026-01-08 20:50:08,737 [INFO] Game: FLOP | Current pot: 200
# 2026-01-08 20:50:08,737 [INFO] Game: FLOP | Betting round complete
#
# 2026-01-08 20:50:08,737 [INFO] Game: TURN | Dealt turn. Community cards: ['4♣', 'A♠', '7♦', '2♠']
# 2026-01-08 20:50:08,737 [INFO] Game: TURN | Player SmartBot2 checks.
# 2026-01-08 20:50:08,737 [INFO] Game: TURN | Current pot: 200
# 2026-01-08 20:50:08,738 [INFO] Game: TURN | Player AggroBot2 bets amount 40. Remaining stack: 5500.
# 2026-01-08 20:50:08,738 [INFO] Game: TURN | Current pot: 240
# 2026-01-08 20:50:08,738 [INFO] Game: TURN | Player SmartBot2 calls with amount 40. Remaining stack: 220.
# 2026-01-08 20:50:08,739 [INFO] Game: TURN | Current pot: 280
# 2026-01-08 20:50:08,739 [INFO] Game: TURN | Betting round complete
#
# 2026-01-08 20:50:08,739 [INFO] Game: RIVER | Dealt river. Community cards: ['4♣', 'A♠', '7♦', '2♠', '2♣']
# 2026-01-08 20:50:08,739 [INFO] Game: RIVER | Player SmartBot2 checks.
# 2026-01-08 20:50:08,739 [INFO] Game: RIVER | Current pot: 280
# 2026-01-08 20:50:08,740 [INFO] Game: RIVER | Player AggroBot2 bets amount 40. Remaining stack: 5460.
# 2026-01-08 20:50:08,740 [INFO] Game: RIVER | Current pot: 320
# 2026-01-08 20:50:08,740 [INFO] Game: RIVER | Player SmartBot2 calls with amount 40. Remaining stack: 180.
# 2026-01-08 20:50:08,740 [INFO] Game: RIVER | Current pot: 360
# 2026-01-08 20:50:08,741 [INFO] Game: RIVER | Betting round complete
#
# 2026-01-08 20:50:08,741 [INFO] Game: SHOWDOWN | Player SmartBot2 has hand PAIR with cards ['5♠', 'J♥', 'A♠', '2♠', '2♣'] (score: 17.1515)
# 2026-01-08 20:50:08,741 [INFO] Game: SHOWDOWN | Player AggroBot2 has hand PAIR with cards ['3♦', 'K♦', 'A♠', '2♠', '2♣'] (score: 17.1533)
# 2026-01-08 20:50:08,741 [INFO] Game: SHOWDOWN | Player AggroBot2 wins 360 from the pot.
# 2026-01-08 20:50:08,742 [INFO] Game: SHOWDOWN | Showdown complete
#
# 2026-01-08 20:50:08,742 [INFO] Game: Hand ended
#
# 2026-01-08 20:50:08,742 [INFO] Game: ============================== Hand 4 ==============================
#
# 2026-01-08 20:50:08,743 [INFO] Game: PRE_FLOP | Dealing hole cards. Dealer: SmartBot2
# 2026-01-08 20:50:08,743 [INFO] Game: PRE_FLOP | Posting small blind of 10 by player AggroBot2. Remaining stack: 5810
# 2026-01-08 20:50:08,743 [INFO] Game: PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 980
# 2026-01-08 20:50:08,744 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 160.
# 2026-01-08 20:50:08,744 [INFO] Game: PRE_FLOP | Current pot: 50
# 2026-01-08 20:50:08,744 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 40. Remaining stack: 5780.
# 2026-01-08 20:50:08,744 [INFO] Game: PRE_FLOP | Current pot: 80
# 2026-01-08 20:50:08,744 [INFO] Game: PRE_FLOP | Player FoldBot folds.
# 2026-01-08 20:50:08,745 [INFO] Game: PRE_FLOP | Current pot: 80
# 2026-01-08 20:50:08,745 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 140.
# 2026-01-08 20:50:08,745 [INFO] Game: PRE_FLOP | Current pot: 100
# 2026-01-08 20:50:08,745 [INFO] Game: PRE_FLOP | Betting round complete
#
# 2026-01-08 20:50:08,745 [INFO] Game: FLOP | Dealt flop. Community cards: ['9♥', '9♣', 'Q♥']
# 2026-01-08 20:50:08,746 [INFO] Game: FLOP | Player AggroBot2 bets amount 40. Remaining stack: 5740.
# 2026-01-08 20:50:08,746 [INFO] Game: FLOP | Current pot: 140
# 2026-01-08 20:50:08,746 [INFO] Game: FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 100.
# 2026-01-08 20:50:08,746 [INFO] Game: FLOP | Current pot: 180
# 2026-01-08 20:50:08,746 [INFO] Game: FLOP | Betting round complete
#
# 2026-01-08 20:50:08,746 [INFO] Game: TURN | Dealt turn. Community cards: ['9♥', '9♣', 'Q♥', '8♥']
# 2026-01-08 20:50:08,747 [INFO] Game: TURN | Player AggroBot2 bets amount 40. Remaining stack: 5700.
# 2026-01-08 20:50:08,747 [INFO] Game: TURN | Current pot: 220
# 2026-01-08 20:50:08,747 [INFO] Game: TURN | Player SmartBot2 calls with amount 40. Remaining stack: 60.
# 2026-01-08 20:50:08,747 [INFO] Game: TURN | Current pot: 260
# 2026-01-08 20:50:08,747 [INFO] Game: TURN | Betting round complete
#
# 2026-01-08 20:50:08,748 [INFO] Game: RIVER | Dealt river. Community cards: ['9♥', '9♣', 'Q♥', '8♥', 'Q♣']
# 2026-01-08 20:50:08,748 [INFO] Game: RIVER | Player AggroBot2 bets amount 40. Remaining stack: 5660.
# 2026-01-08 20:50:08,748 [INFO] Game: RIVER | Current pot: 300
# 2026-01-08 20:50:08,748 [INFO] Game: RIVER | Player SmartBot2 calls with amount 40. Remaining stack: 20.
# 2026-01-08 20:50:08,749 [INFO] Game: RIVER | Current pot: 340
# 2026-01-08 20:50:08,749 [INFO] Game: RIVER | Betting round complete
#
# 2026-01-08 20:50:08,749 [INFO] Game: SHOWDOWN | Player SmartBot2 has hand THREE_OF_A_KIND with cards ['Q♦', '10♥', '9♥', 'Q♥', 'Q♣'] (score: 67.009)
# 2026-01-08 20:50:08,749 [INFO] Game: SHOWDOWN | Player AggroBot2 has hand THREE_OF_A_KIND with cards ['9♠', 'J♠', '9♥', '9♣', 'Q♥'] (score: 66.011)
# 2026-01-08 20:50:08,750 [INFO] Game: SHOWDOWN | Player SmartBot2 wins 340 from the pot.
# 2026-01-08 20:50:08,750 [INFO] Game: SHOWDOWN | Showdown complete
#
# 2026-01-08 20:50:08,750 [INFO] Game: Hand ended
#
# 2026-01-08 20:50:08,750 [INFO] Game: ============================== Hand 5 ==============================
#
# 2026-01-08 20:50:08,750 [INFO] Game: PRE_FLOP | Dealing hole cards. Dealer: AggroBot2
# 2026-01-08 20:50:08,751 [INFO] Game: PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 970
# 2026-01-08 20:50:08,751 [INFO] Game: PRE_FLOP | Posting big blind of 20 by player SmartBot2. Remaining stack: 340
# 2026-01-08 20:50:08,751 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 40. Remaining stack: 5620.
# 2026-01-08 20:50:08,751 [INFO] Game: PRE_FLOP | Current pot: 70
# 2026-01-08 20:50:08,751 [INFO] Game: PRE_FLOP | Player FoldBot folds.
# 2026-01-08 20:50:08,752 [INFO] Game: PRE_FLOP | Current pot: 70
# 2026-01-08 20:50:08,752 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 320.
# 2026-01-08 20:50:08,752 [INFO] Game: PRE_FLOP | Current pot: 90
# 2026-01-08 20:50:08,752 [INFO] Game: PRE_FLOP | Betting round complete
#
# 2026-01-08 20:50:08,752 [INFO] Game: FLOP | Dealt flop. Community cards: ['3♥', '5♦', '8♠']
# 2026-01-08 20:50:08,753 [INFO] Game: FLOP | Player SmartBot2 bets amount 45. Remaining stack: 275.
# 2026-01-08 20:50:08,753 [INFO] Game: FLOP | Current pot: 135
# 2026-01-08 20:50:08,754 [INFO] Game: FLOP | Player AggroBot2 raises to amount 65. Remaining stack: 5555.
# 2026-01-08 20:50:08,754 [INFO] Game: FLOP | Current pot: 200
# 2026-01-08 20:50:08,754 [INFO] Game: FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 255.
# 2026-01-08 20:50:08,754 [INFO] Game: FLOP | Current pot: 220
# 2026-01-08 20:50:08,755 [INFO] Game: FLOP | Betting round complete
#
# 2026-01-08 20:50:08,755 [INFO] Game: TURN | Dealt turn. Community cards: ['3♥', '5♦', '8♠', '6♥']
# 2026-01-08 20:50:08,755 [INFO] Game: TURN | Player SmartBot2 checks.
# 2026-01-08 20:50:08,755 [INFO] Game: TURN | Current pot: 220
# 2026-01-08 20:50:08,756 [INFO] Game: TURN | Player AggroBot2 bets amount 40. Remaining stack: 5515.
# 2026-01-08 20:50:08,756 [INFO] Game: TURN | Current pot: 260
# 2026-01-08 20:50:08,756 [INFO] Game: TURN | Player SmartBot2 calls with amount 40. Remaining stack: 215.
# 2026-01-08 20:50:08,756 [INFO] Game: TURN | Current pot: 300
# 2026-01-08 20:50:08,756 [INFO] Game: TURN | Betting round complete
#
# 2026-01-08 20:50:08,757 [INFO] Game: RIVER | Dealt river. Community cards: ['3♥', '5♦', '8♠', '6♥', '9♣']
# 2026-01-08 20:50:08,757 [INFO] Game: RIVER | Player SmartBot2 checks.
# 2026-01-08 20:50:08,757 [INFO] Game: RIVER | Current pot: 300
# 2026-01-08 20:50:08,757 [INFO] Game: RIVER | Player AggroBot2 bets amount 40. Remaining stack: 5475.
# 2026-01-08 20:50:08,757 [INFO] Game: RIVER | Current pot: 340
# 2026-01-08 20:50:08,757 [INFO] Game: RIVER | Player SmartBot2 calls with amount 40. Remaining stack: 175.
# 2026-01-08 20:50:08,758 [INFO] Game: RIVER | Current pot: 380
# 2026-01-08 20:50:08,758 [INFO] Game: RIVER | Betting round complete
#
# 2026-01-08 20:50:08,758 [INFO] Game: SHOWDOWN | Player SmartBot2 has hand PAIR with cards ['10♥', '9♥', '8♠', '6♥', '9♣'] (score: 24.1086)
# 2026-01-08 20:50:08,759 [INFO] Game: SHOWDOWN | Player AggroBot2 has hand HIGH_CARD with cards ['7♠', '2♦', '8♠', '6♥', '9♣'] (score: 9.08762)
# 2026-01-08 20:50:08,759 [INFO] Game: SHOWDOWN | Player SmartBot2 wins 380 from the pot.
# 2026-01-08 20:50:08,759 [INFO] Game: SHOWDOWN | Showdown complete
#
# 2026-01-08 20:50:08,760 [INFO] Game: Hand ended
#
# 2026-01-08 20:50:08,760 [INFO] Game: ============================== Hand 6 ==============================
#
# 2026-01-08 20:50:08,760 [INFO] Game: PRE_FLOP | Dealing hole cards. Dealer: FoldBot
# 2026-01-08 20:50:08,760 [INFO] Game: PRE_FLOP | Posting small blind of 10 by player SmartBot2. Remaining stack: 545
# 2026-01-08 20:50:08,760 [INFO] Game: PRE_FLOP | Posting big blind of 20 by player AggroBot2. Remaining stack: 5455
# 2026-01-08 20:50:08,761 [INFO] Game: PRE_FLOP | Player FoldBot folds.
# 2026-01-08 20:50:08,761 [INFO] Game: PRE_FLOP | Current pot: 30
# 2026-01-08 20:50:08,761 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 10. Remaining stack: 535.
# 2026-01-08 20:50:08,761 [INFO] Game: PRE_FLOP | Current pot: 40
# 2026-01-08 20:50:08,762 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 40. Remaining stack: 5435.
# 2026-01-08 20:50:08,762 [INFO] Game: PRE_FLOP | Current pot: 60
# 2026-01-08 20:50:08,762 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 515.
# 2026-01-08 20:50:08,762 [INFO] Game: PRE_FLOP | Current pot: 80
# 2026-01-08 20:50:08,762 [INFO] Game: PRE_FLOP | Betting round complete
#
# 2026-01-08 20:50:08,762 [INFO] Game: FLOP | Dealt flop. Community cards: ['7♥', '3♣', '7♠']
# 2026-01-08 20:50:08,763 [INFO] Game: FLOP | Player SmartBot2 bets amount 40. Remaining stack: 475.
# 2026-01-08 20:50:08,763 [INFO] Game: FLOP | Current pot: 120
# 2026-01-08 20:50:08,763 [INFO] Game: FLOP | Player AggroBot2 raises to amount 60. Remaining stack: 5375.
# 2026-01-08 20:50:08,763 [INFO] Game: FLOP | Current pot: 180
# 2026-01-08 20:50:08,763 [INFO] Game: FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 455.
# 2026-01-08 20:50:08,763 [INFO] Game: FLOP | Current pot: 200
# 2026-01-08 20:50:08,763 [INFO] Game: FLOP | Betting round complete
#
# 2026-01-08 20:50:08,764 [INFO] Game: TURN | Dealt turn. Community cards: ['7♥', '3♣', '7♠', 'A♥']
# 2026-01-08 20:50:08,764 [INFO] Game: TURN | Player SmartBot2 checks.
# 2026-01-08 20:50:08,764 [INFO] Game: TURN | Current pot: 200
# 2026-01-08 20:50:08,764 [INFO] Game: TURN | Player AggroBot2 bets amount 40. Remaining stack: 5335.
# 2026-01-08 20:50:08,765 [INFO] Game: TURN | Current pot: 240
# 2026-01-08 20:50:08,765 [INFO] Game: TURN | Player SmartBot2 calls with amount 40. Remaining stack: 415.
# 2026-01-08 20:50:08,765 [INFO] Game: TURN | Current pot: 280
# 2026-01-08 20:50:08,765 [INFO] Game: TURN | Betting round complete
#
# 2026-01-08 20:50:08,766 [INFO] Game: RIVER | Dealt river. Community cards: ['7♥', '3♣', '7♠', 'A♥', '4♦']
# 2026-01-08 20:50:08,766 [INFO] Game: RIVER | Player SmartBot2 checks.
# 2026-01-08 20:50:08,766 [INFO] Game: RIVER | Current pot: 280
# 2026-01-08 20:50:08,766 [INFO] Game: RIVER | Player AggroBot2 bets amount 40. Remaining stack: 5295.
# 2026-01-08 20:50:08,766 [INFO] Game: RIVER | Current pot: 320
# 2026-01-08 20:50:08,767 [INFO] Game: RIVER | Player SmartBot2 calls with amount 40. Remaining stack: 375.
# 2026-01-08 20:50:08,767 [INFO] Game: RIVER | Current pot: 360
# 2026-01-08 20:50:08,767 [INFO] Game: RIVER | Betting round complete
#
# 2026-01-08 20:50:08,767 [INFO] Game: SHOWDOWN | Player SmartBot2 has hand TWO_PAIR with cards ['Q♣', 'Q♥', '7♥', '7♠', 'A♥'] (score: 42.084)
# 2026-01-08 20:50:08,768 [INFO] Game: SHOWDOWN | Player AggroBot2 has hand FULL_HOUSE with cards ['4♠', '7♦', '7♥', '7♠', '4♦'] (score: 97.04)
# 2026-01-08 20:50:08,768 [INFO] Game: SHOWDOWN | Player AggroBot2 wins 360 from the pot.
# 2026-01-08 20:50:08,768 [INFO] Game: SHOWDOWN | Showdown complete
#
# 2026-01-08 20:50:08,768 [INFO] Game: Hand ended
#
# 2026-01-08 20:50:08,768 [INFO] Game: ============================== Hand 7 ==============================
#
# 2026-01-08 20:50:08,768 [INFO] Game: PRE_FLOP | Dealing hole cards. Dealer: SmartBot2
# 2026-01-08 20:50:08,769 [INFO] Game: PRE_FLOP | Posting small blind of 10 by player AggroBot2. Remaining stack: 5645
# 2026-01-08 20:50:08,769 [INFO] Game: PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 950
# 2026-01-08 20:50:08,769 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 355.
# 2026-01-08 20:50:08,770 [INFO] Game: PRE_FLOP | Current pot: 50
# 2026-01-08 20:50:08,770 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 40. Remaining stack: 5615.
# 2026-01-08 20:50:08,770 [INFO] Game: PRE_FLOP | Current pot: 80
# 2026-01-08 20:50:08,770 [INFO] Game: PRE_FLOP | Player FoldBot folds.
# 2026-01-08 20:50:08,770 [INFO] Game: PRE_FLOP | Current pot: 80
# 2026-01-08 20:50:08,770 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 335.
# 2026-01-08 20:50:08,771 [INFO] Game: PRE_FLOP | Current pot: 100
# 2026-01-08 20:50:08,771 [INFO] Game: PRE_FLOP | Betting round complete
#
# 2026-01-08 20:50:08,771 [INFO] Game: FLOP | Dealt flop. Community cards: ['J♦', '5♣', '3♠']
# 2026-01-08 20:50:08,771 [INFO] Game: FLOP | Player AggroBot2 bets amount 40. Remaining stack: 5575.
# 2026-01-08 20:50:08,771 [INFO] Game: FLOP | Current pot: 140
# 2026-01-08 20:50:08,771 [INFO] Game: FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 295.
# 2026-01-08 20:50:08,771 [INFO] Game: FLOP | Current pot: 180
# 2026-01-08 20:50:08,772 [INFO] Game: FLOP | Betting round complete
#
# 2026-01-08 20:50:08,772 [INFO] Game: TURN | Dealt turn. Community cards: ['J♦', '5♣', '3♠', '4♥']
# 2026-01-08 20:50:08,772 [INFO] Game: TURN | Player AggroBot2 bets amount 40. Remaining stack: 5535.
# 2026-01-08 20:50:08,772 [INFO] Game: TURN | Current pot: 220
# 2026-01-08 20:50:08,772 [INFO] Game: TURN | Player SmartBot2 calls with amount 40. Remaining stack: 255.
# 2026-01-08 20:50:08,772 [INFO] Game: TURN | Current pot: 260
# 2026-01-08 20:50:08,773 [INFO] Game: TURN | Betting round complete
#
# 2026-01-08 20:50:08,773 [INFO] Game: RIVER | Dealt river. Community cards: ['J♦', '5♣', '3♠', '4♥', '2♦']
# 2026-01-08 20:50:08,773 [INFO] Game: RIVER | Player AggroBot2 bets amount 40. Remaining stack: 5495.
# 2026-01-08 20:50:08,773 [INFO] Game: RIVER | Current pot: 300
# 2026-01-08 20:50:08,773 [INFO] Game: RIVER | Player SmartBot2 calls with amount 40. Remaining stack: 215.
# 2026-01-08 20:50:08,773 [INFO] Game: RIVER | Current pot: 340
# 2026-01-08 20:50:08,774 [INFO] Game: RIVER | Betting round complete
#
# 2026-01-08 20:50:08,774 [INFO] Game: SHOWDOWN | Player SmartBot2 has hand HIGH_CARD with cards ['A♦', '7♥', 'J♦', '5♣', '4♥'] (score: 14.1175)
# 2026-01-08 20:50:08,774 [INFO] Game: SHOWDOWN | Player AggroBot2 has hand PAIR with cards ['K♥', 'J♥', 'J♦', '5♣', '4♥'] (score: 26.1354)
# 2026-01-08 20:50:08,775 [INFO] Game: SHOWDOWN | Player AggroBot2 wins 340 from the pot.
# 2026-01-08 20:50:08,776 [INFO] Game: SHOWDOWN | Showdown complete
#
# 2026-01-08 20:50:08,776 [INFO] Game: Hand ended
#
# 2026-01-08 20:50:08,776 [INFO] Game: ============================== Hand 8 ==============================
#
# 2026-01-08 20:50:08,777 [INFO] Game: PRE_FLOP | Dealing hole cards. Dealer: AggroBot2
# 2026-01-08 20:50:08,777 [INFO] Game: PRE_FLOP | Posting small blind of 10 by player FoldBot. Remaining stack: 940
# 2026-01-08 20:50:08,777 [INFO] Game: PRE_FLOP | Posting big blind of 20 by player SmartBot2. Remaining stack: 195
# 2026-01-08 20:50:08,778 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 40. Remaining stack: 5795.
# 2026-01-08 20:50:08,778 [INFO] Game: PRE_FLOP | Current pot: 70
# 2026-01-08 20:50:08,778 [INFO] Game: PRE_FLOP | Player FoldBot folds.
# 2026-01-08 20:50:08,778 [INFO] Game: PRE_FLOP | Current pot: 70
# 2026-01-08 20:50:08,779 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 175.
# 2026-01-08 20:50:08,779 [INFO] Game: PRE_FLOP | Current pot: 90
# 2026-01-08 20:50:08,779 [INFO] Game: PRE_FLOP | Betting round complete
#
# 2026-01-08 20:50:08,779 [INFO] Game: FLOP | Dealt flop. Community cards: ['6♠', '10♥', '8♣']
# 2026-01-08 20:50:08,780 [INFO] Game: FLOP | Player SmartBot2 bets amount 45. Remaining stack: 130.
# 2026-01-08 20:50:08,780 [INFO] Game: FLOP | Current pot: 135
# 2026-01-08 20:50:08,780 [INFO] Game: FLOP | Player AggroBot2 raises to amount 65. Remaining stack: 5730.
# 2026-01-08 20:50:08,780 [INFO] Game: FLOP | Current pot: 200
# 2026-01-08 20:50:08,781 [INFO] Game: FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 110.
# 2026-01-08 20:50:08,781 [INFO] Game: FLOP | Current pot: 220
# 2026-01-08 20:50:08,781 [INFO] Game: FLOP | Betting round complete
#
# 2026-01-08 20:50:08,781 [INFO] Game: TURN | Dealt turn. Community cards: ['6♠', '10♥', '8♣', '8♥']
# 2026-01-08 20:50:08,781 [INFO] Game: TURN | Player SmartBot2 checks.
# 2026-01-08 20:50:08,781 [INFO] Game: TURN | Current pot: 220
# 2026-01-08 20:50:08,782 [INFO] Game: TURN | Player AggroBot2 bets amount 40. Remaining stack: 5690.
# 2026-01-08 20:50:08,782 [INFO] Game: TURN | Current pot: 260
# 2026-01-08 20:50:08,782 [INFO] Game: TURN | Player SmartBot2 calls with amount 40. Remaining stack: 70.
# 2026-01-08 20:50:08,782 [INFO] Game: TURN | Current pot: 300
# 2026-01-08 20:50:08,782 [INFO] Game: TURN | Betting round complete
#
# 2026-01-08 20:50:08,782 [INFO] Game: RIVER | Dealt river. Community cards: ['6♠', '10♥', '8♣', '8♥', '3♦']
# 2026-01-08 20:50:08,783 [INFO] Game: RIVER | Player SmartBot2 checks.
# 2026-01-08 20:50:08,783 [INFO] Game: RIVER | Current pot: 300
# 2026-01-08 20:50:08,783 [INFO] Game: RIVER | Player AggroBot2 bets amount 40. Remaining stack: 5650.
# 2026-01-08 20:50:08,783 [INFO] Game: RIVER | Current pot: 340
# 2026-01-08 20:50:08,783 [INFO] Game: RIVER | Player SmartBot2 calls with amount 40. Remaining stack: 30.
# 2026-01-08 20:50:08,784 [INFO] Game: RIVER | Current pot: 380
# 2026-01-08 20:50:08,784 [INFO] Game: RIVER | Betting round complete
#
# 2026-01-08 20:50:08,784 [INFO] Game: SHOWDOWN | Player SmartBot2 has hand TWO_PAIR with cards ['6♦', '10♣', '10♥', '8♣', '8♥'] (score: 40.086)
# 2026-01-08 20:50:08,784 [INFO] Game: SHOWDOWN | Player AggroBot2 has hand PAIR with cards ['K♣', '5♥', '10♥', '8♣', '8♥'] (score: 23.1405)
# 2026-01-08 20:50:08,785 [INFO] Game: SHOWDOWN | Player SmartBot2 wins 380 from the pot.
# 2026-01-08 20:50:08,785 [INFO] Game: SHOWDOWN | Showdown complete
#
# 2026-01-08 20:50:08,785 [INFO] Game: Hand ended
#
# 2026-01-08 20:50:08,785 [INFO] Game: ============================== Hand 9 ==============================
#
# 2026-01-08 20:50:08,785 [INFO] Game: PRE_FLOP | Dealing hole cards. Dealer: FoldBot
# 2026-01-08 20:50:08,786 [INFO] Game: PRE_FLOP | Posting small blind of 10 by player SmartBot2. Remaining stack: 400
# 2026-01-08 20:50:08,786 [INFO] Game: PRE_FLOP | Posting big blind of 20 by player AggroBot2. Remaining stack: 5630
# 2026-01-08 20:50:08,786 [INFO] Game: PRE_FLOP | Player FoldBot folds.
# 2026-01-08 20:50:08,786 [INFO] Game: PRE_FLOP | Current pot: 30
# 2026-01-08 20:50:08,787 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 10. Remaining stack: 390.
# 2026-01-08 20:50:08,787 [INFO] Game: PRE_FLOP | Current pot: 40
# 2026-01-08 20:50:08,787 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 40. Remaining stack: 5610.
# 2026-01-08 20:50:08,787 [INFO] Game: PRE_FLOP | Current pot: 60
# 2026-01-08 20:50:08,787 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 370.
# 2026-01-08 20:50:08,788 [INFO] Game: PRE_FLOP | Current pot: 80
# 2026-01-08 20:50:08,788 [INFO] Game: PRE_FLOP | Betting round complete
#
# 2026-01-08 20:50:08,788 [INFO] Game: FLOP | Dealt flop. Community cards: ['5♣', 'Q♣', 'A♣']
# 2026-01-08 20:50:08,789 [INFO] Game: FLOP | Player SmartBot2 bets amount 40. Remaining stack: 330.
# 2026-01-08 20:50:08,789 [INFO] Game: FLOP | Current pot: 120
# 2026-01-08 20:50:08,789 [INFO] Game: FLOP | Player AggroBot2 raises to amount 60. Remaining stack: 5550.
# 2026-01-08 20:50:08,789 [INFO] Game: FLOP | Current pot: 180
# 2026-01-08 20:50:08,789 [INFO] Game: FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 310.
# 2026-01-08 20:50:08,789 [INFO] Game: FLOP | Current pot: 200
# 2026-01-08 20:50:08,790 [INFO] Game: FLOP | Betting round complete
#
# 2026-01-08 20:50:08,790 [INFO] Game: TURN | Dealt turn. Community cards: ['5♣', 'Q♣', 'A♣', '2♠']
# 2026-01-08 20:50:08,790 [INFO] Game: TURN | Player SmartBot2 checks.
# 2026-01-08 20:50:08,790 [INFO] Game: TURN | Current pot: 200
# 2026-01-08 20:50:08,791 [INFO] Game: TURN | Player AggroBot2 bets amount 40. Remaining stack: 5510.
# 2026-01-08 20:50:08,791 [INFO] Game: TURN | Current pot: 240
# 2026-01-08 20:50:08,791 [INFO] Game: TURN | Player SmartBot2 calls with amount 40. Remaining stack: 270.
# 2026-01-08 20:50:08,791 [INFO] Game: TURN | Current pot: 280
# 2026-01-08 20:50:08,791 [INFO] Game: TURN | Betting round complete
#
# 2026-01-08 20:50:08,792 [INFO] Game: RIVER | Dealt river. Community cards: ['5♣', 'Q♣', 'A♣', '2♠', '4♠']
# 2026-01-08 20:50:08,792 [INFO] Game: RIVER | Player SmartBot2 checks.
# 2026-01-08 20:50:08,792 [INFO] Game: RIVER | Current pot: 280
# 2026-01-08 20:50:08,865 [INFO] Game: RIVER | Player AggroBot2 bets amount 40. Remaining stack: 5470.
# 2026-01-08 20:50:08,865 [INFO] Game: RIVER | Current pot: 320
# 2026-01-08 20:50:08,865 [INFO] Game: RIVER | Player SmartBot2 calls with amount 40. Remaining stack: 230.
# 2026-01-08 20:50:08,866 [INFO] Game: RIVER | Current pot: 360
# 2026-01-08 20:50:08,866 [INFO] Game: RIVER | Betting round complete
#
# 2026-01-08 20:50:08,866 [INFO] Game: SHOWDOWN | Player SmartBot2 has hand HIGH_CARD with cards ['K♠', '6♥', '5♣', 'Q♣', 'A♣'] (score: 14.1427)
# 2026-01-08 20:50:08,866 [INFO] Game: SHOWDOWN | Player AggroBot2 has hand PAIR with cards ['4♦', 'K♥', 'Q♣', 'A♣', '4♠'] (score: 19.1542)
# 2026-01-08 20:50:08,867 [INFO] Game: SHOWDOWN | Player AggroBot2 wins 360 from the pot.
# 2026-01-08 20:50:08,867 [INFO] Game: SHOWDOWN | Showdown complete
#
# 2026-01-08 20:50:08,867 [INFO] Game: Hand ended
#
# 2026-01-08 20:50:08,867 [INFO] Game: ============================== Hand 10 ==============================
#
# 2026-01-08 20:50:08,867 [INFO] Game: PRE_FLOP | Dealing hole cards. Dealer: SmartBot2
# 2026-01-08 20:50:08,868 [INFO] Game: PRE_FLOP | Posting small blind of 10 by player AggroBot2. Remaining stack: 5820
# 2026-01-08 20:50:08,868 [INFO] Game: PRE_FLOP | Posting big blind of 20 by player FoldBot. Remaining stack: 920
# 2026-01-08 20:50:08,868 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 210.
# 2026-01-08 20:50:08,868 [INFO] Game: PRE_FLOP | Current pot: 50
# 2026-01-08 20:50:08,868 [INFO] Game: PRE_FLOP | Player AggroBot2 raises to amount 40. Remaining stack: 5790.
# 2026-01-08 20:50:08,869 [INFO] Game: PRE_FLOP | Current pot: 80
# 2026-01-08 20:50:08,869 [INFO] Game: PRE_FLOP | Player FoldBot folds.
# 2026-01-08 20:50:08,869 [INFO] Game: PRE_FLOP | Current pot: 80
# 2026-01-08 20:50:08,869 [INFO] Game: PRE_FLOP | Player SmartBot2 calls with amount 20. Remaining stack: 190.
# 2026-01-08 20:50:08,870 [INFO] Game: PRE_FLOP | Current pot: 100
# 2026-01-08 20:50:08,870 [INFO] Game: PRE_FLOP | Betting round complete
#
# 2026-01-08 20:50:08,870 [INFO] Game: FLOP | Dealt flop. Community cards: ['4♥', '2♣', '3♦']
# 2026-01-08 20:50:08,870 [INFO] Game: FLOP | Player AggroBot2 bets amount 40. Remaining stack: 5750.
# 2026-01-08 20:50:08,870 [INFO] Game: FLOP | Current pot: 140
# 2026-01-08 20:50:08,870 [INFO] Game: FLOP | Player SmartBot2 calls with amount 40. Remaining stack: 150.
# 2026-01-08 20:50:08,871 [INFO] Game: FLOP | Current pot: 180
# 2026-01-08 20:50:08,871 [INFO] Game: FLOP | Betting round complete
#
# 2026-01-08 20:50:08,871 [INFO] Game: TURN | Dealt turn. Community cards: ['4♥', '2♣', '3♦', '2♦']
# 2026-01-08 20:50:08,871 [INFO] Game: TURN | Player AggroBot2 bets amount 40. Remaining stack: 5710.
# 2026-01-08 20:50:08,871 [INFO] Game: TURN | Current pot: 220
# 2026-01-08 20:50:08,872 [INFO] Game: TURN | Player SmartBot2 calls with amount 40. Remaining stack: 110.
# 2026-01-08 20:50:08,872 [INFO] Game: TURN | Current pot: 260
# 2026-01-08 20:50:08,872 [INFO] Game: TURN | Betting round complete
#
# 2026-01-08 20:50:08,872 [INFO] Game: RIVER | Dealt river. Community cards: ['4♥', '2♣', '3♦', '2♦', 'K♠']
# 2026-01-08 20:50:08,872 [INFO] Game: RIVER | Player AggroBot2 bets amount 40. Remaining stack: 5670.
# 2026-01-08 20:50:08,872 [INFO] Game: RIVER | Current pot: 300
# 2026-01-08 20:50:08,873 [INFO] Game: RIVER | Player SmartBot2 calls with amount 40. Remaining stack: 70.
# 2026-01-08 20:50:08,873 [INFO] Game: RIVER | Current pot: 340
# 2026-01-08 20:50:08,873 [INFO] Game: RIVER | Betting round complete
#
# 2026-01-08 20:50:08,873 [INFO] Game: SHOWDOWN | Player SmartBot2 has hand PAIR with cards ['A♣', 'Q♦', '2♣', '2♦', 'K♠'] (score: 17.1542)
# 2026-01-08 20:50:08,874 [INFO] Game: SHOWDOWN | Player AggroBot2 has hand TWO_PAIR with cards ['3♥', '6♦', '2♣', '3♦', '2♦'] (score: 33.026)
# 2026-01-08 20:50:08,874 [INFO] Game: SHOWDOWN | Player AggroBot2 wins 340 from the pot.
# 2026-01-08 20:50:08,874 [INFO] Game: SHOWDOWN | Showdown complete
#
# 2026-01-08 20:50:08,874 [INFO] Game: Hand ended
#
# 2026-01-08 20:50:08,874 [INFO] Game: Reached maximum number of hands, ending game.
# 2026-01-08 20:50:08,874 [INFO] Game: Game ended
